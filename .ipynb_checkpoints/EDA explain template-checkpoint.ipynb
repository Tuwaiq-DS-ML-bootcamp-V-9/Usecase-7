# %%
# To ignore warnings
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

from scipy.stats import zscore
import dtale




## This statement allows the visuals to render within your Jupyter Notebook.
# %matplotlib inline

# %%
# !pip install xgboost

# %% [markdown]
# ## Loading the data
# We can now load the dataset into pandas using the read_csv() function. This converts the CSV file into a Pandas dataframe.

# %%
football_df = pd.read_csv('Data/final_data.csv')

# %% [markdown]
# # Preprocess the Data

# %% [markdown]
# ### Viewing the dataframe
# We can get a quick sense of the size of our dataset by using the shape method. This returns a tuple with the number of rows and columns in the dataset.

# %%
football_df_report=dtale.show(football_df)
football_df_report
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://LAPTOP-8L6R58JJ:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # EDA

# %% [markdown]
# ## 1. Data Profiling:
# Data profiling is a comprehensive process of examining the data available in an existing dataset and collecting statistics and information about that data.

# %%
football_df.head()
# Out:
#                                      player               team  \
# 0        /david-de-gea/profil/spieler/59377  Manchester United
# 1       /jack-butland/profil/spieler/128899  Manchester United
# 2          /tom-heaton/profil/spieler/34130  Manchester United
# 3  /lisandro-martinez/profil/spieler/480762  Manchester United
# 4     /raphael-varane/profil/spieler/164770  Manchester United
#
#                 name              position  height   age  appearance  \
# 0       David de Gea            Goalkeeper   189.0  32.0         104
# 1       Jack Butland            Goalkeeper   196.0  30.0          15
# 2         Tom Heaton            Goalkeeper   188.0  37.0           4
# 3  Lisandro Martínez  Defender Centre-Back   175.0  25.0          82
# 4     Raphaël Varane  Defender Centre-Back   191.0  30.0          63
#
#       goals   assists  yellow cards  ...  goals conceded  clean sheets  \
# 0  0.000000  0.000000      0.009585  ...        1.217252      0.335463
# 1  0.000000  0.000000      0.069018  ...        1.242331      0.207055
# 2  0.000000  0.000000      0.000000  ...        0.616438      0.924658
# 3  0.028090  0.056180      0.224719  ...        0.000000      0.000000
# 4  0.017889  0.017889      0.053667  ...        0.000000      0.000000
#
#    minutes played  days_injured  games_injured  award  current_value  \
# 0            9390            42              5     13       15000000
# 1            1304           510             58      1        1500000
# 2             292           697             84      4         600000
# 3            6408           175             22      9       50000000
# 4            5031           238             51     21       40000000
#
#    highest_value  position_encoded  winger
# 0       70000000                 1       0
# 1       22000000                 1       0
# 2        6000000                 1       0
# 3       50000000                 2       0
# 4       80000000                 2       0
#
# [5 rows x 22 columns]

# %%
# NO NULL VALUES
football_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10754 entries, 0 to 10753
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   player               10754 non-null  object
#  1   team                 10754 non-null  object
#  2   name                 10754 non-null  object
#  3   position             10754 non-null  object
#  4   height               10754 non-null  float64
#  5   age                  10754 non-null  float64
#  6   appearance           10754 non-null  int64
#  7   goals                10754 non-null  float64
#  8   assists              10754 non-null  float64
#  9   yellow cards         10754 non-null  float64
#  10  second yellow cards  10754 non-null  float64
#  11  red cards            10754 non-null  float64
#  12  goals conceded       10754 non-null  float64
#  13  clean sheets         10754 non-null  float64
#  14  minutes played       10754 non-null  int64
#  15  days_injured         10754 non-null  int64
#  16  games_injured        10754 non-null  int64
#  17  award                10754 non-null  int64
#  18  current_value        10754 non-null  int64
#  19  highest_value        10754 non-null  int64
#  20  position_encoded     10754 non-null  int64
#  21  winger               10754 non-null  int64
# dtypes: float64(9), int64(9), object(4)
# memory usage: 1.8+ MB

# %%
football_df.duplicated().sum()
# Out:
# 0

# %%
football_df
# Out:
#                                           player                      team  \
# 0             /david-de-gea/profil/spieler/59377         Manchester United
# 1            /jack-butland/profil/spieler/128899         Manchester United
# 2               /tom-heaton/profil/spieler/34130         Manchester United
# 3       /lisandro-martinez/profil/spieler/480762         Manchester United
# 4          /raphael-varane/profil/spieler/164770         Manchester United
# ...                                          ...                       ...
# 10749       /aidan-simmons/profil/spieler/867763  Western Sydney Wanderers
# 10750        /kusini-yengi/profil/spieler/708099  Western Sydney Wanderers
# 10751    /nathanael-blair/profil/spieler/1023268  Western Sydney Wanderers
# 10752    /zachary-sapsford/profil/spieler/703657  Western Sydney Wanderers
# 10753  /alexander-badolato/profil/spieler/957230  Western Sydney Wanderers
#
#                      name               position      height   age  \
# 0            David de Gea             Goalkeeper  189.000000  32.0
# 1            Jack Butland             Goalkeeper  196.000000  30.0
# 2              Tom Heaton             Goalkeeper  188.000000  37.0
# 3       Lisandro Martínez   Defender Centre-Back  175.000000  25.0
# 4          Raphaël Varane   Defender Centre-Back  191.000000  30.0
# ...                   ...                    ...         ...   ...
# 10749       Aidan Simmons     Attack-RightWinger  181.240353  20.0
# 10750        Kusini Yengi  Attack Centre-Forward  190.000000  24.0
# 10751     Nathanael Blair  Attack Centre-Forward  181.240353  19.0
# 10752    Zachary Sapsford  Attack Centre-Forward  181.240353  20.0
# 10753  Alexander Badolato  Attack Centre-Forward  170.000000  18.0
#
#        appearance     goals   assists  yellow cards  ...  goals conceded  \
# 0             104  0.000000  0.000000      0.009585  ...        1.217252
# 1              15  0.000000  0.000000      0.069018  ...        1.242331
# 2               4  0.000000  0.000000      0.000000  ...        0.616438
# 3              82  0.028090  0.056180      0.224719  ...        0.000000
# 4              63  0.017889  0.017889      0.053667  ...        0.000000
# ...           ...       ...       ...           ...  ...             ...
# 10749          16  0.175953  0.087977      0.263930  ...        0.000000
# 10750          26  0.372671  0.186335      0.186335  ...        0.000000
# 10751          20  0.375000  0.000000      0.187500  ...        0.000000
# 10752          17  0.312139  0.104046      0.000000  ...        0.000000
# 10753          21  0.000000  0.000000      0.086042  ...        0.000000
#
#        clean sheets  minutes played  days_injured  games_injured  award  \
# 0          0.335463            9390            42              5     13
# 1          0.207055            1304           510             58      1
# 2          0.924658             292           697             84      4
# 3          0.000000            6408           175             22      9
# 4          0.000000            5031           238             51     21
# ...             ...             ...           ...            ...    ...
# 10749      0.000000            1023             0              0      0
# 10750      0.000000            1449           102             18      0
# 10751      0.000000             960             0              0      0
# 10752      0.000000             865             0              0      0
# 10753      0.000000            1046             0              0      0
#
#        current_value  highest_value  position_encoded  winger
# 0           15000000       70000000                 1       0
# 1            1500000       22000000                 1       0
# 2             600000        6000000                 1       0
# 3           50000000       50000000                 2       0
# 4           40000000       80000000                 2       0
# ...              ...            ...               ...     ...
# 10749          75000          75000                 4       1
# 10750         300000         300000                 4       0
# 10751          50000          50000                 4       0
# 10752          50000          50000                 4       0
# 10753          25000          25000                 4       0
#
# [10754 rows x 22 columns]

# %%
# position_encoded --> 1- Goalkeeper, 2- Defender, 3- midfield, 4- Attack
# winger --> 1: winger, 0: not a winger

# %%
# Apperentlly "goals," "assists," "yellow cards," "second yellow cards," 
# "red cards," "goals conceded," and "clean sheets" were transformed to a per 90-minute basis.

# %%
football_df.dtypes
# Out:
# player                  object
# team                    object
# name                    object
# position                object
# height                 float64
# age                    float64
# appearance               int64
# goals                  float64
# assists                float64
# yellow cards           float64
# second yellow cards    float64
# red cards              float64
# goals conceded         float64
# clean sheets           float64
# minutes played           int64
# days_injured             int64
# games_injured            int64
# award                    int64
# current_value            int64
# highest_value            int64
# position_encoded         int64
# winger                   int64
# dtype: object

# %%
football_df['team'].unique()
# Out:
# array(['Manchester United', 'West Ham United', 'Leicester City',
#        'Aston Villa', 'Wolverhampton Wanderers', 'Southampton FC',
#        'Brighton &amp; Hove Albion', 'Everton FC', 'Nottingham Forest',
#        'Leeds United', 'Crystal Palace', 'Fulham FC', 'AFC Bournemouth',
#        'Brentford FC', 'Liverpool FC', 'Newcastle United',
#        'Manchester City', 'Arsenal FC', 'Tottenham Hotspur', 'Chelsea FC',
#        'Borussia Mönchengladbach', 'VfL Wolfsburg', 'TSG 1899 Hoffenheim',
#        '1.FC Union Berlin', 'FC Augsburg', 'VfB Stuttgart',
#        '1.FSV Mainz 05', '1.FC Köln', 'Hertha BSC', 'FC Schalke 04',
#        'VfL Bochum', 'SV Werder Bremen', 'Eintracht Frankfurt',
#        'SC Freiburg', 'Borussia Dortmund', 'Bayer 04 Leverkusen',
#        'Bayern Munich', 'RB Leipzig', 'Real Sociedad', 'Villarreal CF',
#        'Real Betis Balompié', 'Athletic Bilbao', 'Valencia CF',
#        'Sevilla FC', 'Celta de Vigo', 'CA Osasuna', 'Girona FC',
#        'Rayo Vallecano', 'RCD Mallorca', 'UD Almería',
#        'Real Valladolid CF', 'Cádiz CF', 'Elche CF',
#        'RCD Espanyol Barcelona', 'Getafe CF', 'Atlético de Madrid',
#        'Real Madrid', 'FC Barcelona', 'AS Roma', 'SS Lazio',
#        'ACF Fiorentina', 'US Sassuolo', 'Torino FC', 'Udinese Calcio',
#        'Bologna FC 1909', 'AC Monza', 'FC Empoli', 'US Lecce',
#        'Spezia Calcio', 'Hellas Verona', 'UC Sampdoria', 'US Cremonese',
#        'US Salernitana 1919', 'Atalanta BC', 'SSC Napoli', 'Inter Milan',
#        'AC Milan', 'Juventus FC', 'AS Monaco', 'Stade Rennais FC',
#        'Olympique Marseille', 'OGC Nice', 'RC Lens', 'FC Nantes',
#        'Montpellier HSC', 'FC Lorient', 'FC Toulouse', 'ESTAC Troyes',
#        'Stade Brestois 29', 'Angers SCO', 'AJ Auxerre',
#        'Clermont Foot 63', 'AC Ajaccio', 'Olympique Lyon', 'LOSC Lille',
#        'Stade Reims', 'RC Strasbourg Alsace', 'Paris Saint-Germain',
#        'AZ Alkmaar', 'Twente Enschede FC', 'Vitesse Arnhem',
#        'FC Groningen', 'Fortuna Sittard', 'NEC Nijmegen',
#        'Sparta Rotterdam', 'SC Cambuur Leeuwarden', 'Excelsior Rotterdam',
#        'FC Volendam', 'RKC Waalwijk', 'FC Emmen', 'Go Ahead Eagles',
#        'FC Utrecht', 'SC Heerenveen', 'Ajax Amsterdam', 'PSV Eindhoven',
#        'Feyenoord Rotterdam', 'Club Athletico Paranaense',
#        'Red Bull Bragantino', 'Santos FC',
#        'Clube de Regatas Vasco da Gama', 'Fluminense Football Club',
#        'Sport Club Internacional', 'Esporte Clube Bahia',
#        'Grêmio Foot-Ball Porto Alegrense', 'Coritiba Foot Ball Club',
#        'Fortaleza Esporte Clube', 'Cruzeiro Esporte Clube',
#        'Goiás Esporte Clube', 'Cuiabá Esporte Clube (MT)',
#        'Botafogo de Futebol e Regatas', 'Clube Atlético Mineiro',
#        'São Paulo Futebol Clube', 'América Futebol Clube (MG)',
#        'Sociedade Esportiva Palmeiras', 'CR Flamengo',
#        'Sport Club Corinthians Paulista', 'SC Braga', 'FC Famalicão',
#        'Vitória Guimarães SC', 'CD Santa Clara', 'GD Estoril Praia',
#        'Boavista FC', 'Portimonense SC', 'CS Marítimo', 'Casa Pia AC',
#        'FC Paços de Ferreira', 'FC Arouca', 'FC Vizela', 'Rio Ave FC',
#        'GD Chaves', 'Gil Vicente FC', 'FC Porto', 'Sporting CP',
#        'SL Benfica', 'Santos Laguna', 'Club León FC', 'FC Juárez',
#        'Club Tijuana', 'Atlético de San Luis', 'Club Necaxa', 'Puebla FC',
#        'Mazatlán FC', 'Querétaro FC', 'CF América', 'CF Monterrey',
#        'Atlas Guadalajara', 'UNAM Pumas', 'Deportivo Toluca',
#        'Tigres UANL', 'Deportivo Guadalajara', 'CD Cruz Azul',
#        'CF Pachuca', 'Dynamo Moscow', 'Lokomotiv Moscow', 'FK Rostov',
#        'Krylya Sovetov Samara', 'FC Sochi', 'Akhmat Grozny',
#        'Ural Yekaterinburg', 'FK Orenburg', 'FC Pari Nizhniy Novgorod',
#        'FK Khimki', 'Torpedo Moscow', 'Fakel Voronezh', 'Spartak Moscow',
#        'CSKA Moscow', 'FK Krasnodar', 'Zenit St. Petersburg',
#        'West Bromwich Albion', 'Sunderland AFC', 'Hull City',
#        'Preston North End', 'Stoke City', 'Queens Park Rangers',
#        'Birmingham City', 'Cardiff City', 'Millwall FC', 'Reading FC',
#        'Blackpool FC', 'Bristol City', 'Huddersfield Town',
#        'Rotherham United', 'Wigan Athletic', 'Middlesbrough FC',
#        'Coventry City', 'Luton Town', 'Swansea City', 'Burnley FC',
#        'Watford FC', 'Sheffield United', 'Blackburn Rovers',
#        'Norwich City', 'Trabzonspor', 'Besiktas JK', 'Basaksehir FK',
#        'Antalyaspor', 'Adana Demirspor', 'Alanyaspor', 'Kasimpasa',
#        'Konyaspor', 'MKE Ankaragücü', 'Sivasspor', 'Kayserispor',
#        'Giresunspor', 'Istanbulspor', 'Hatayspor', 'Gaziantep FK',
#        'Fatih Karagümrük', 'Ümraniyespor', 'Fenerbahce', 'Galatasaray',
#        'SK Sturm Graz', 'LASK', 'SCR Altach', 'SC Austria Lustenau',
#        'SV Ried', 'TSV Hartberg', 'WSG Tirol', 'Rapid Vienna',
#        'Austria Vienna', 'SK Austria Klagenfurt', 'Wolfsberger AC',
#        'Red Bull Salzburg', 'Philadelphia Union', 'FC Cincinnati',
#        'FC Dallas', 'Orlando City SC', 'Los Angeles Galaxy',
#        'New England Revolution', 'D.C. United', 'New York Red Bulls',
#        'Portland Timbers', 'Columbus Crew', 'Charlotte FC',
#        'Sporting Kansas City', 'Colorado Rapids',
#        'Vancouver Whitecaps FC', 'Chicago Fire FC', 'Inter Miami CF',
#        'Minnesota United FC', 'Houston Dynamo FC', 'St. Louis CITY SC',
#        'CF Montréal', 'Real Salt Lake City', 'Nashville SC',
#        'San Jose Earthquakes', 'Seattle Sounders FC', 'Atlanta United FC',
#        'New York City FC', 'Austin FC', 'Los Angeles FC', 'Toronto FC',
#        'CA Vélez Sarsfield', 'CA San Lorenzo de Almagro',
#        'Club Atlético Lanús', 'Defensa y Justicia',
#        'Club Estudiantes de La Plata', "CA Newell's Old Boys", 'CA Colon',
#        'CA Rosario Central', 'CA Banfield',
#        'Club de Gimnasia y Esgrima La Plata', 'Club Atlético Tucumán',
#        'CD Godoy Cruz Antonio Tomba', 'Club Atlético Unión',
#        'Club Atlético Platense', 'Instituto AC Córdoba',
#        'CA Sarmiento (Junin)', 'CA Central Córdoba (SdE)',
#        'CA Barracas Central', 'Arsenal Fútbol Club',
#        'Club Atlético Talleres', 'Club Atlético Belgrano',
#        'AA Argentinos Juniors', 'CA Independiente', 'Club Atlético Tigre',
#        'CA River Plate', 'CA Boca Juniors', 'CA Huracán', 'Racing Club',
#        'Kawasaki Frontale', 'Yokohama F. Marinos', 'Cerezo Osaka',
#        'Kyoto Sanga', 'FC Tokyo', 'Nagoya Grampus', 'Kashiwa Reysol',
#        'Yokohama FC', 'Avispa Fukuoka', 'Sagan Tosu', 'Vissel Kobe',
#        'Hokkaido Consadole Sapporo', 'Shonan Bellmare', 'Albirex Niigata',
#        'Kashima Antlers', 'Sanfrecce Hiroshima', 'Urawa Red Diamonds',
#        'Gamba Osaka', 'Al-Shabab Club (Riyadh)', 'Ettifaq FC',
#        'Al-Taawoun FC', 'Al-Wehda FC', 'Damac FC', 'Al-Tai',
#        'Al-Fayha FC', 'Abha Club', 'Al-Khaleej', 'Al-Raed SFC',
#        'Al-Batin FC', 'Al-Adalah FC', 'Al-Ittihad Club (Jeddah)',
#        'Al-Fateh SC', 'Al-Hilal Saudi FC', 'Al-Nassr FC',
#        'Suwon Samsung Bluewings', 'Jeju United', 'Incheon United',
#        'Gangwon FC', 'Daejeon Hana Citizen', 'Gwangju FC', 'Daegu FC',
#        'Suwon FC', 'Pohang Steelers', 'FC Seoul',
#        'Jeonbuk Hyundai Motors', 'Ulsan Hyundai', 'Sekhukhune United FC',
#        'AmaZulu FC', 'Lamontville Golden Arrows', 'Stellenbosch FC',
#        'Swallows FC', 'Maritzburg United FC', 'Royal AM FC',
#        'TS Galaxy FC', 'Richards Bay FC', 'Marumo Gallants FC',
#        'Cape Town City FC', 'Orlando Pirates', 'SuperSport United',
#        'Chippa United', 'Mamelodi Sundowns FC', 'Kaizer Chiefs',
#        'Melbourne Victory', 'Western United FC', 'Newcastle United Jets',
#        'Perth Glory', 'Macarthur FC', 'Brisbane Roar',
#        'Central Coast Mariners', 'Wellington Phoenix',
#        'Melbourne City FC', 'Sydney FC', 'Adelaide United',
#        'Western Sydney Wanderers'], dtype=object)

# %%
football_df['position'].unique()
# Out:
# array(['Goalkeeper', 'Defender Centre-Back', 'Defender Left-Back',
#        'Defender Right-Back', 'midfield-DefensiveMidfield',
#        'midfield-CentralMidfield', 'midfield-AttackingMidfield',
#        'Attack-LeftWinger', 'Attack-RightWinger', 'Attack Centre-Forward',
#        'midfield-RightMidfield', 'midfield-LeftMidfield',
#        'Attack-SecondStriker', 'midfield', 'Attack', 'Defender'],
#       dtype=object)

# %%
football_df['goals'].unique()
# Out:
# array([0.        , 0.02808989, 0.01788909, ..., 0.22670025, 0.17595308,
#        0.31213873])

# %% [markdown]
# The process of profiling differs slightly for categorical and numerical variables due to their inherent differences.
#
# **The two main types of data are:**
# - Quantitative (numerical) data
# - Qualitative (categorical) data

# %% [markdown]
# ### Data Quality Checks
# Data quality checks involve the process of ensuring that the data is accurate, complete, consistent, relevant, and reliable.
#
#
# **Here are typical steps involved in checking data quality:**

# %% [markdown]
# #### 1. Reliability:
# Evaluate the data's source and collection process to determine its trustworthiness.

# %% [raw]
# The dataset was sourced from Kaggle 'https://www.kaggle.com/datasets/khanghunhnguyntrng/football-players-transfer-fee-prediction-dataset/data'
# But they collected the data from different leagues, which are:
# 11 European leagues, including the Premier League and Championship in England, Bundesliga in Germany, La Liga in Spain, Serie A in Italy, Ligue 1 in France, Eredivisie in the Netherlands, Liga NOS in Portugal, Premier Liga in Russia, Super Lig in Turkey, and Bundesliga in Austria.
#
# 4 American leagues, including Brasileiro in Brazil, Major League Soccer in the United States, Primera División in Argentina, and Liga MX in Mexico.
#
# 1 African league, namely the DStv Premiership in South Africa.
#
# 4 Asian leagues, comprising J-League in Japan, Saudi Pro League in Saudi Arabia, K-League 1 in South Korea, and A-League in Australia.

# %% [markdown]
# #### 2. Timeliness:
# Ensure the data is up-to-date and reflective of the current situation or the period of interest for the analysis.

# %% [raw]
# According to the source "Kaggle" This dataset was generated by scraping data from Transfermarkt using Selenium and BeautifulSoup on June 10, 2023.
# It shows the performance of the players over two seasons
# It meets the time period we supposed work in

# %% [markdown]
# #### 3. Consistency:
#
# Confirm that the data is consistent within the dataset and across multiple data sources. For example, the same data point should not have different values in different places.

# %% [raw]
# Only one dataset so it's consistent

# %% [markdown]
# #### 4. Relevance:

# %% [raw]
# 1. Sample Relevance: The dataset represents players from various top leagues across different continents, capturing diverse market trends and transfer dynamics for better model accuracy.
# 2. Variable Relevance: It covers key factors influencing transfer value, such as age, height, position, goals, assists, injuries, and awards, which directly impact a player's market worth.

# %% [markdown]
# #### 5. Uniqueness:
# Check for and remove duplicate records to prevent skewed analysis results.

# %%
football_df.duplicated().sum()
# Out:
# 0

# %%
# I think all the values may be duplicated unless the whole row is identical it can't be duplicated
football_df.columns
# Out:
# Index(['player', 'team', 'name', 'position', 'height', 'age', 'appearance',
#        'goals', 'assists', 'yellow cards', 'second yellow cards', 'red cards',
#        'goals conceded', 'clean sheets', 'minutes played', 'days_injured',
#        'games_injured', 'award', 'current_value', 'highest_value',
#        'position_encoded', 'winger'],
#       dtype='object')

# %%
# go to delete duplicates columns

# %% [markdown]
# #### 6. Completeness:
# Ensure that no critical data is missing. This might mean checking for null values or required fields that are empty.
#
# We will start by checking the dataset for missing or null values. For this, we can use the isna() method which returns a dataframe of boolean values indicating if a field is null or not. To group all missing values by column, we can include the sum() method.

# %%
football_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10754 entries, 0 to 10753
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   player               10754 non-null  object
#  1   team                 10754 non-null  object
#  2   name                 10754 non-null  object
#  3   position             10754 non-null  object
#  4   height               10754 non-null  float64
#  5   age                  10754 non-null  float64
#  6   appearance           10754 non-null  int64
#  7   goals                10754 non-null  float64
#  8   assists              10754 non-null  float64
#  9   yellow cards         10754 non-null  float64
#  10  second yellow cards  10754 non-null  float64
#  11  red cards            10754 non-null  float64
#  12  goals conceded       10754 non-null  float64
#  13  clean sheets         10754 non-null  float64
#  14  minutes played       10754 non-null  int64
#  15  days_injured         10754 non-null  int64
#  16  games_injured        10754 non-null  int64
#  17  award                10754 non-null  int64
#  18  current_value        10754 non-null  int64
#  19  highest_value        10754 non-null  int64
#  20  position_encoded     10754 non-null  int64
#  21  winger               10754 non-null  int64
# dtypes: float64(9), int64(9), object(4)
# memory usage: 1.8+ MB

# %%
# NO missing values

# %%
# go to clean them

# %% [markdown]
# #### 7. Check Accuracy:
#
# Verify that the data is correct and precise. This could involve comparing data samples with known sources or using validation rules.
#
# **The process includes:**
# 1. Validating the appropriateness of data types for the dataset.
# 2. Identifying outliers  using established validation  rule

# %%
football_df.dtypes
# Out:
# player                  object
# team                    object
# name                    object
# position                object
# height                 float64
# age                    float64
# appearance               int64
# goals                  float64
# assists                float64
# yellow cards           float64
# second yellow cards    float64
# red cards              float64
# goals conceded         float64
# clean sheets           float64
# minutes played           int64
# days_injured             int64
# games_injured            int64
# award                    int64
# current_value            int64
# highest_value            int64
# position_encoded         int64
# winger                   int64
# dtype: object

# %%
# The data type of each column suits their logical meaning

# %% [markdown]
# ## 2. Data Cleaning:
#
# Preliminary findings from data profiling can lead to cleaning the data by:
# - Handling missing values
# - Correcting errors.
# - Dealing with outliers.
#
# -------------------

# %% [markdown]
# ### Correcting errors
#
# -------------------

# %%
# go back to 7th dimension Accuracy

# %% [markdown]
# ##### Dealing with outliers:

# %% [markdown]
# **How to remove Outliers?**
# Most of the ways to deal with outliers are similar to the methods of missing values like deleting rows, transforming them, binning them, treat them as a separate group, imputing values and other statistical methods. Here, we will discuss the common techniques used to deal with outliers:
#
# 1. Deleting rows: We delete outlier values if it is due to data entry error, data processing error or outlier rows are very small in numbers. We can also use trimming at both ends to remove outliers.
#
# 2. Imputing: Like imputation of missing values, we can also impute outliers. We can use mean, median, mode imputation methods. Before imputing values, we should analyse if it is natural outlier or artificial. If it is artificial, we can go with imputing values. We can also use statistical model to predict values of outlier rows and after that we can impute it with predicted values.
#
# 3. Treat separately: If there are significant number of outliers, we should treat them separately in the statistical model. One of the approach is to treat both groups as two different groups and build individual model for both groups and then combine the output.

# %% [markdown]
# ##### football_df - age column's outliers

# %%
filtered_age = football_df[(football_df["age"] >= 16) &(football_df["age"] <= 39)]

plt.figure(figsize=(10, 6))
plt.hist(filtered_age["age"], bins=15, color="navy", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Age", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Players' Age (17 =< Age <= 39)", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
# I tried multiple values and I saw that this gave the most normal distribution

# %%
filtered_age.shape
# Out:
# (10715, 22)

# %%
football_df.shape
# Out:
# (10754, 22)

# %%
# Droping the outliers
football_df=football_df[(football_df["age"] >= 16) &(football_df["age"] <= 39)]

# %%
football_df.shape
# Out:
# (10715, 22)

# %% [markdown]
# ##### football_df - height column's outliers

# %%
zscore(football_df['height'])

football_df['height_z_score'] = zscore(football_df['height'])

football_df[(football_df['height_z_score'] > 2.9) | (football_df['height_z_score']< -2.9)].sort_values(by='height')
# Out:
#                                                   player  \
# 7563               /nahuel-barrios/profil/spieler/503377
# 8288                  /maxi-moralez/profil/spieler/30687
# 6894             /steven-sserwadda/profil/spieler/568840
# 10258             /kajally-drammeh/profil/spieler/863824
# 9341     /al-mutasim-sediq-hassan/profil/spieler/1057847
# 9019            /sumaihan-al-nabit/profil/spieler/478531
# 8647               /taichi-kikuchi/profil/spieler/683325
# 8472            /teruhito-nakagawa/profil/spieler/345326
# 8143              /braian-martinez/profil/spieler/739995
# 8085                 /mariano-mino/profil/spieler/538092
# 6725               /luciano-acosta/profil/spieler/315169
# 10612               /joshua-nisbet/profil/spieler/603863
# 5951                /erhun-oztumer/profil/spieler/326843
# 4625               /edgar-alaffita/profil/spieler/264104
# 4402             /misael-dominguez/profil/spieler/451221
# 3236             /yeferson-soteldo/profil/spieler/312294
# 10285     /ndabayithethwa-ndlondlo/profil/spieler/636981
# 8601            /katsuki-nishimura/profil/spieler/914625
# 8610                 /kazuya-konno/profil/spieler/654348
# 6884               /matthew-nocita/profil/spieler/972457
# 5031                 /stefan-sapic/profil/spieler/429243
# 3039              /andries-noppert/profil/spieler/276853
# 9472                 /fejsal-mulic/profil/spieler/226194
# 6394          /pape-alioune-ndiaye/profil/spieler/433219
# 1656   /vanja-milinkovi%C4%87-savi%C4%87/profil/spiel...
# 3770                /carlos-miguel/profil/spieler/641458
# 2700               /kjell-scherpen/profil/spieler/463527
# 2439                  /isaak-toure/profil/spieler/708678
#
#                                   team                     name  \
# 7563         CA San Lorenzo de Almagro           Nahuel Barrios
# 8288                       Racing Club             Maxi Moralez
# 6894                New York Red Bulls         Steven Sserwadda
# 10258                Cape Town City FC          Kajally Drammeh
# 9341          Al-Ittihad Club (Jeddah)  Al-Mutasim Sediq Hassan
# 9019                     Al-Taawoun FC        Sumaihan Al-Nabit
# 8647                        Sagan Tosu           Taichi Kikuchi
# 8472                          FC Tokyo        Teruhito Nakagawa
# 8143                  CA Independiente          Braian Martínez
# 8085            Club Atlético Belgrano             Mariano Miño
# 6725                     FC Cincinnati           Luciano Acosta
# 10612           Central Coast Mariners            Joshua Nisbet
# 5951                   Adana Demirspor            Erhun Öztümer
# 4625                        UNAM Pumas           Édgar Alaffita
# 4402                      Club Tijuana         Misael Domínguez
# 3236                         Santos FC         Yeferson Soteldo
# 10285                  Orlando Pirates  Ndabayithethwa Ndlondlo
# 8601                    Avispa Fukuoka        Katsuki Nishimura
# 8610                    Avispa Fukuoka             Kazuya Konno
# 6884                New York Red Bulls           Matthew Nocita
# 5031                    Torpedo Moscow             Stefan Sapic
# 3039                     SC Heerenveen          Andries Noppert
# 9472           Suwon Samsung Bluewings             Fejsal Mulic
# 6394                        SCR Altach      Pape-Alioune Ndiaye
# 1656                         Torino FC   Vanja Milinković-Savić
# 3770   Sport Club Corinthians Paulista            Carlos Miguel
# 2700                    Vitesse Arnhem           Kjell Scherpen
# 2439                        AJ Auxerre              Isaak Touré
#
#                          position  height   age  appearance     goals  \
# 7563            Attack-LeftWinger   156.0  25.0           4  0.000000
# 8288   midfield-AttackingMidfield   159.0  36.0          17  0.205950
# 6894     midfield-CentralMidfield   160.0  20.0           0  0.000000
# 10258          Attack-RightWinger   160.0  19.0          19  0.130435
# 9341                       Attack   160.0  21.0           0  0.000000
# 9019            Attack-LeftWinger   160.0  27.0          63  0.231720
# 8647   midfield-AttackingMidfield   160.0  24.0          16  0.000000
# 8472           Attack-RightWinger   160.0  30.0          22  0.256959
# 8143            Attack-LeftWinger   160.0  23.0          10  0.000000
# 8085   midfield-AttackingMidfield   160.0  29.0           3  0.000000
# 6725   midfield-AttackingMidfield   160.0  29.0          16  0.576461
# 10612  midfield-DefensiveMidfield   160.0  23.0          56  0.061728
# 5951   midfield-AttackingMidfield   160.0  32.0          38  0.324519
# 4625     midfield-CentralMidfield   160.0  26.0          61  0.106846
# 4402   midfield-AttackingMidfield   160.0  23.0          29  0.000000
# 3236            Attack-LeftWinger   160.0  25.0          24  0.094937
# 10285  midfield-AttackingMidfield   161.0  28.0          63  0.214844
# 8601                     midfield   161.0  18.0           2  0.000000
# 8610           Attack-RightWinger   161.0  25.0          14  0.078125
# 6884         Defender Centre-Back   202.0  23.0           3  0.000000
# 5031         Defender Centre-Back   202.0  26.0          45  0.049628
# 3039                   Goalkeeper   202.0  29.0          40  0.000000
# 9472        Attack Centre-Forward   202.0  28.0           7  0.300000
# 6394         Defender Centre-Back   202.0  25.0          39  0.000000
# 1656                   Goalkeeper   202.0  26.0          70  0.000000
# 3770                   Goalkeeper   204.0  24.0           0  0.000000
# 2700                   Goalkeeper   206.0  23.0          39  0.000000
# 2439         Defender Centre-Back   206.0  20.0          42  0.032597
#
#         assists  yellow cards  ...  clean sheets  minutes played  \
# 7563   0.283912      0.000000  ...      0.000000             317
# 8288   0.308924      0.308924  ...      0.000000             874
# 6894   0.000000      0.000000  ...      0.000000               0
# 10258  0.000000      0.130435  ...      0.000000             690
# 9341   0.000000      0.000000  ...      0.000000               0
# 9019   0.092688      0.301236  ...      0.000000            3884
# 8647   0.000000      0.000000  ...      0.000000            1166
# 8472   0.192719      0.128480  ...      0.000000            1401
# 8143   0.171103      0.171103  ...      0.000000             526
# 8085   0.000000      0.000000  ...      0.000000              23
# 6725   0.144115      0.288231  ...      0.000000            1249
# 10612  0.041152      0.041152  ...      0.000000            4374
# 5951   0.162260      0.162260  ...      0.000000            1664
# 4625   0.089038      0.089038  ...      0.000000            5054
# 4402   0.096257      0.096257  ...      0.000000             935
# 3236   0.284810      0.094937  ...      0.000000             948
# 10285  0.019531      0.136719  ...      0.000000            4608
# 8601   0.000000      0.000000  ...      0.000000              90
# 8610   0.156250      0.000000  ...      0.000000            1152
# 6884   0.000000      0.407240  ...      0.000000             221
# 5031   0.000000      0.248139  ...      0.000000            3627
# 3039   0.000000      0.025000  ...      0.375000            3600
# 9472   0.000000      0.300000  ...      0.000000             300
# 6394   0.000000      0.206287  ...      0.000000            3054
# 1656   0.000000      0.113208  ...      0.268868            6360
# 3770   0.000000      0.000000  ...      0.000000               0
# 2700   0.000000      0.000000  ...      0.283424            3493
# 2439   0.000000      0.260775  ...      0.000000            2761
#
#        days_injured  games_injured  award  current_value  highest_value  \
# 7563             13              2      0        3500000        3500000
# 8288            137             25      3         400000        6000000
# 6894              0              0      0         200000         200000
# 10258             0              0      0         250000         250000
# 9341              0              0      1          25000          25000
# 9019              0              0      0        1200000        1200000
# 8647              0              0      0         400000         400000
# 8472            176             25      6        1400000        2800000
# 8143              0              0      0         400000         425000
# 8085            225             20      1         350000         425000
# 6725             42              5      0        4500000        6000000
# 10612             0              0      1         400000         400000
# 5951              0              0      0         150000         750000
# 4625              0              0      0         600000         600000
# 4402             22              2      5         300000         600000
# 3236            157             21      0        6000000       10000000
# 10285             0              0      1         750000         750000
# 8601              0              0      0              0              0
# 8610            218             43      1         400000         400000
# 6884              0              0      0         100000         100000
# 5031              0              0      0         500000        1600000
# 3039            507             27      0        5000000        5000000
# 9472            205             24      0         700000         750000
# 6394             20              2      0         250000         900000
# 1656             63             15      2        3500000        4500000
# 3770              0              0      0        1000000        1000000
# 2700             78              9      2        2000000        2800000
# 2439            129              1      0        5000000        5000000
#
#        position_encoded  winger  height_z_score
# 7563                  4       1       -3.620520
# 8288                  3       0       -3.190029
# 6894                  3       0       -3.046532
# 10258                 4       1       -3.046532
# 9341                  4       0       -3.046532
# 9019                  4       1       -3.046532
# 8647                  3       0       -3.046532
# 8472                  4       1       -3.046532
# 8143                  4       1       -3.046532
# 8085                  3       0       -3.046532
# 6725                  3       0       -3.046532
# 10612                 3       0       -3.046532
# 5951                  3       0       -3.046532
# 4625                  3       0       -3.046532
# 4402                  3       0       -3.046532
# 3236                  4       1       -3.046532
# 10285                 3       0       -2.903035
# 8601                  3       0       -2.903035
# 8610                  4       1       -2.903035
# 6884                  2       0        2.980341
# 5031                  2       0        2.980341
# 3039                  1       0        2.980341
# 9472                  4       0        2.980341
# 6394                  2       0        2.980341
# 1656                  1       0        2.980341
# 3770                  1       0        3.267335
# 2700                  1       0        3.554329
# 2439                  2       0        3.554329
#
# [28 rows x 23 columns]

# %%
# Filter data
filtered_height = football_df[(football_df["height"] > 161) & (football_df["height"] < 202)]

# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(filtered_height["height"], bins=15, color="navy", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Height (cm)", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Players' Height (160 cm < Height < 204 cm)", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
# The chart looks pretty normally distributed after excluding these values so I will drop them
football_df=football_df[(football_df["height"] > 161) & (football_df["height"] < 202)]

# %%
football_df.shape
# Out:
# (10687, 23)

# %% [markdown]
# ##### football_df - days_injuref column's outliers

# %%
zscore(football_df['days_injured'])

football_df['days_injured_z_score'] = zscore(football_df['days_injured'])
# The column didnt show up so I wanted to know where did it start
football_df[(football_df['days_injured_z_score'] > 3.5) | (football_df['days_injured_z_score']< -3)].sort_values(by='days_injured')['days_injured'].min()
# Out:
# 732

# %%
indexs=football_df[(football_df['days_injured_z_score'] > 3.5) | (football_df['days_injured_z_score']< -3)].sort_values(by='days_injured').index
football_df.drop(indexs,inplace=True)

# %%
football_df.shape
# Out:
# (10565, 24)

# %% [markdown]
# ##### football_df - games_injured columns outliers

# %%
# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(football_df["games_injured"], bins=15, color="red", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Games Injured", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Games Injured", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
filtered_games=football_df[football_df["games_injured"]<90]
# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(filtered_games["games_injured"], bins=15, color="red", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Games Injured", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Games Injured", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
# Well obviously the chart won't help so I'll try zscore

# %%
zscore(football_df['games_injured'])

football_df['games_injured_z_score'] = zscore(football_df['games_injured'])

football_df[(football_df['games_injured_z_score'] > 3.5) | (football_df['games_injured_z_score']< -3.5)].sort_values(by='games_injured')
# Out:
#                                           player                 team  \
# 3115        /justin-bijlow/profil/spieler/315121  Feyenoord Rotterdam
# 37          /angelo-ogbonna/profil/spieler/48002      West Ham United
# 10563       /daniel-arzani/profil/spieler/399997         Macarthur FC
# 1619   /giacomo-bonaventura/profil/spieler/57280       ACF Fiorentina
# 1317       /clement-grenier/profil/spieler/72479         RCD Mallorca
# ...                                          ...                  ...
# 355            /rico-henry/profil/spieler/339556         Brentford FC
# 8291   /maximiliano-romero/profil/spieler/365758          Racing Club
# 440        /benjamin-mendy/profil/spieler/157495      Manchester City
# 783          /tolga-cigerci/profil/spieler/94199           Hertha BSC
# 5745        /jack-robinson/profil/spieler/128909     Sheffield United
#
#                       name                    position  height   age  \
# 3115         Justin Bijlow                  Goalkeeper   188.0  25.0
# 37          Angelo Ogbonna        Defender Centre-Back   191.0  35.0
# 10563        Daniel Arzani           Attack-LeftWinger   175.0  24.0
# 1619   Giacomo Bonaventura    midfield-CentralMidfield   180.0  33.0
# 1317       Clément Grenier    midfield-CentralMidfield   186.0  32.0
# ...                    ...                         ...     ...   ...
# 355             Rico Henry          Defender Left-Back   170.0  25.0
# 8291    Maximiliano Romero       Attack Centre-Forward   180.0  24.0
# 440         Benjamin Mendy          Defender Left-Back   185.0  28.0
# 783          Tolga Cigerci  midfield-DefensiveMidfield   185.0  31.0
# 5745         Jack Robinson          Defender Left-Back   180.0  29.0
#
#        appearance     goals   assists  yellow cards  ...  days_injured  \
# 3115           69  0.000000  0.000000      0.014375  ...           560
# 37             42  0.027060  0.000000      0.108238  ...           664
# 10563          39  0.201162  0.321860      0.362092  ...           524
# 1619           84  0.171221  0.233483      0.202352  ...           535
# 1317           29  0.185950  0.000000      0.743802  ...           587
# ...           ...       ...       ...           ...  ...           ...
# 355            76  0.043028  0.028685      0.086056  ...           608
# 8291           37  0.336000  0.240000      0.000000  ...           726
# 440             2  0.000000  0.000000      0.000000  ...           696
# 783            60  0.057545  0.095908      0.268542  ...           591
# 5745           64  0.100784  0.033595      0.218365  ...           687
#
#        games_injured  award  current_value  highest_value  position_encoded  \
# 3115              87      5       13000000       13000000                 1
# 37                87      5        1000000       13000000                 2
# 10563             87      3         450000        1500000                 4
# 1619              87      2        2500000       24000000                 3
# 1317              87      4         800000       12000000                 3
# ...              ...    ...            ...            ...               ...
# 355              117      0       22000000       22000000                 2
# 8291             120      3        2800000        7500000                 4
# 440              121     13              0       45000000                 2
# 783              139      3        1500000        4500000                 3
# 5745             140      1         700000        2500000                 2
#
#        winger  height_z_score  days_injured_z_score  games_injured_z_score
# 3115        0        0.971383              2.526314               3.512632
# 37          0        1.401874              3.120418               3.512632
# 10563       1       -0.894078              2.320663               3.512632
# 1619        0       -0.176593              2.383501               3.512632
# 1317        0        0.684389              2.680553               3.512632
# ...       ...             ...                   ...                    ...
# 355         1       -1.611562              2.800516               4.969552
# 8291        0       -0.176593              3.474595               5.115244
# 440         1        0.540892              3.303219               5.163808
# 783         0        0.540892              2.703403               6.037960
# 5745        1       -0.176593              3.251806               6.086524
#
# [92 rows x 25 columns]

# %%
# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(football_df["games_injured_z_score"], bins=15, color="purple", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Z-score of Games Injured", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Games Injured (Z-score)", fontsize=14)
plt.axvline(0, color='red', linestyle='dashed', linewidth=2, label="Mean (0)")
plt.axvline(3.5, color='green', linestyle='dashed', linewidth=2, label="Upper Outlier Threshold (+3.5)")
plt.axvline(-3.5, color='orange', linestyle='dashed', linewidth=2, label="Lower Outlier Threshold (-3.5)")
plt.legend()
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
indexs=football_df[(football_df['games_injured_z_score'] > 3.5) | (football_df['games_injured_z_score']< -3.5)].sort_values(by='days_injured').index
football_df.drop(indexs,inplace=True)

# %%
football_df.shape
# Out:
# (10473, 25)

# %% [markdown]
# ##### football_df - award column's outliers

# %%
plt.figure(figsize=(12, 6))
plt.hist(football_df["award"], bins=10, color="gold", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Number of Awards", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Awards Won by Players", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
filter_award=football_df[football_df["award"]<20]
# Plot histogram
plt.figure(figsize=(12, 6))
plt.hist(filter_award["award"], bins=10, color="gold", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Number of Awards", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Awards Won by Players", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
filter_award.shape
# Out:
# (10414, 25)

# %%
football_df.shape
# Out:
# (10473, 25)

# %%
# Feels like the tail is never ending I'll try zscore

# %%
zscore(football_df['award'])

football_df['award_z_score'] = zscore(football_df['award'])

football_df[(football_df['award_z_score'] > 3.5) | (football_df['award_z_score']< -3.5)].sort_values(by='award')
# Out:
#                                         player  \
# 4080         /nico-gaitan/profil/spieler/75442
# 1022         /leroy-sane/profil/spieler/192565
# 3296         /felipe-melo/profil/spieler/35537
# 945         /niklas-sule/profil/spieler/166601
# 3786            /paulinho/profil/spieler/57229
# ...                                        ...
# 1507         /david-alaba/profil/spieler/59016
# 1525       /karim-benzema/profil/spieler/18922
# 1549  /robert-lewandowski/profil/spieler/38253
# 9433    /cristiano-ronaldo/profil/spieler/8198
# 2643        /lionel-messi/profil/spieler/28003
#
#                                  team                name  \
# 4080             FC Paços de Ferreira         Nico Gaitán
# 1022                    Bayern Munich          Leroy Sané
# 3296         Fluminense Football Club         Felipe Melo
# 945                 Borussia Dortmund         Niklas Süle
# 3786  Sport Club Corinthians Paulista            Paulinho
# ...                               ...                 ...
# 1507                      Real Madrid         David Alaba
# 1525                      Real Madrid       Karim Benzema
# 1549                     FC Barcelona  Robert Lewandowski
# 9433                      Al-Nassr FC   Cristiano Ronaldo
# 2643              Paris Saint-Germain        Lionel Messi
#
#                         position  height   age  appearance     goals  \
# 4080  midfield-AttackingMidfield   174.0  35.0          35  0.198151
# 1022          Attack-RightWinger   183.0  27.0          89  0.438871
# 3296  midfield-DefensiveMidfield   183.0  39.0           4  0.000000
# 945         Defender Centre-Back   195.0  27.0          79  0.048043
# 3786    midfield-CentralMidfield   183.0  34.0           8  0.450000
# ...                          ...     ...   ...         ...       ...
# 1507        Defender Centre-Back   180.0  30.0          85  0.063649
# 1525       Attack Centre-Forward   185.0  35.0          89  0.894040
# 1549       Attack Centre-Forward   185.0  34.0          92  0.938442
# 9433       Attack Centre-Forward   187.0  38.0          74  0.617780
# 2643          Attack-RightWinger   170.0  35.0          75  0.442464
#
#        assists  yellow cards  ...  games_injured  award  current_value  \
# 4080  0.158520      0.118890  ...             54     15         300000
# 1022  0.391850      0.141066  ...             75     15       70000000
# 3296  0.000000      0.649819  ...             40     15         150000
# 945   0.096085      0.112100  ...             53     15       35000000
# 3786  0.000000      0.225000  ...             57     15        1200000
# ...        ...           ...  ...            ...    ...            ...
# 1507  0.089109      0.101839  ...             26     43       40000000
# 1525  0.250331      0.023841  ...             26     53       25000000
# 1549  0.169598      0.067839  ...             22     65       30000000
# 9433  0.105475      0.256153  ...             27     90       15000000
# 2643  0.483945      0.013827  ...             30     92       45000000
#
#       highest_value  position_encoded  winger  height_z_score  \
# 4080       30000000                 3       0       -1.037575
# 1022      100000000                 4       1        0.253898
# 3296       19000000                 3       0        0.253898
# 945        60000000                 2       0        1.975862
# 3786       40000000                 3       0        0.253898
# ...             ...               ...     ...             ...
# 1507       65000000                 2       0       -0.176593
# 1525       60000000                 4       0        0.540892
# 1549       90000000                 4       0        0.540892
# 9433      120000000                 4       0        0.827886
# 2643      180000000                 4       1       -1.611562
#
#       days_injured_z_score  games_injured_z_score  award_z_score
# 4080              1.081044               1.910020       3.587764
# 1022              1.880798               2.929864       3.587764
# 3296              0.406966               1.230124       3.587764
# 945               1.383808               1.861456       3.587764
# 3786              0.903956               2.055712       3.587764
# ...                    ...                    ...            ...
# 1507              0.029939               0.550228      11.257960
# 1525              0.218452               0.550228      13.997316
# 1549              0.121339               0.355972      17.284544
# 9433              0.287002               0.598792      24.132934
# 2643              0.281290               0.744484      24.680805
#
# [131 rows x 26 columns]

# %%
# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(football_df["award_z_score"], bins=15, color="gold", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Z-score of Awards", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Awards (Z-score)", fontsize=14)
plt.axvline(0, color='red', linestyle='dashed', linewidth=2, label="Mean (0)")
plt.axvline(3.5, color='green', linestyle='dashed', linewidth=2, label="Upper Outlier Threshold (+3.5)")
plt.axvline(-3.5, color='orange', linestyle='dashed', linewidth=2, label="Lower Outlier Threshold (-3.5)")
plt.legend()
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
# I think the best decision is to drop values above 20 because excluding more values will affect the results causing misleading

# %%
football_df.drop(columns=["award_z_score"],inplace=True)

# %% [markdown]
# ##### football_df - current_value column's outliers

# %%
# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(football_df["current_value"], bins=15, color="blue", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Current Value", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Players' Current Value", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
# The chart doesn't give a detailed information

# %%
zscore(football_df['current_value'])

football_df['current_value_z_score'] = zscore(football_df['current_value'])

football_df[(football_df['current_value_z_score'] > 3) | (football_df['current_value_z_score']< -3)].sort_values(by='current_value')
# Out:
#                                        player                        team  \
# 5731        /joao-pedro/profil/spieler/626724                  Watford FC
# 275   /joachim-andersen/profil/spieler/260827              Crystal Palace
# 162     /robert-sanchez/profil/spieler/403151  Brighton &amp; Hove Albion
# 124         /pedro-neto/profil/spieler/487465     Wolverhampton Wanderers
# 1508    /antonio-rudiger/profil/spieler/86202                 Real Madrid
# ...                                       ...                         ...
# 1017     /jamal-musiala/profil/spieler/580195               Bayern Munich
# 960    /jude-bellingham/profil/spieler/581678           Borussia Dortmund
# 1521   /vinicius-junior/profil/spieler/371998                 Real Madrid
# 453     /erling-haaland/profil/spieler/418560             Manchester City
# 2644     /kylian-mbappe/profil/spieler/342229         Paris Saint-Germain
#
#                   name                    position  height   age  appearance  \
# 5731        João Pedro       Attack Centre-Forward   182.0  21.0          64
# 275   Joachim Andersen        Defender Centre-Back   192.0  26.0          72
# 162     Robert Sánchez                  Goalkeeper   197.0  25.0          63
# 124         Pedro Neto          Attack-RightWinger   172.0  23.0          34
# 1508   Antonio Rüdiger        Defender Centre-Back   190.0  30.0         107
# ...                ...                         ...     ...   ...         ...
# 1017     Jamal Musiala  midfield-AttackingMidfield   184.0  20.0          87
# 960    Jude Bellingham    midfield-CentralMidfield   186.0  19.0          86
# 1521   Vinicius Junior           Attack-LeftWinger   176.0  22.0         107
# 453     Erling Haaland       Attack Centre-Forward   195.0  22.0          83
# 2644     Kylian Mbappé       Attack Centre-Forward   178.0  24.0          89
#
#          goals   assists  yellow cards  ...  games_injured  award  \
# 5731  0.300000  0.100000      0.160000  ...             15      0
# 275   0.014428  0.043283      0.158705  ...             12      0
# 162   0.000000  0.000000      0.078947  ...              0      0
# 124   0.116129  0.058065      0.232258  ...             68      2
# 1508  0.071106  0.040632      0.142212  ...             66      9
# ...        ...       ...           ...  ...            ...    ...
# 1017  0.431655  0.395683      0.071942  ...              6     11
# 960   0.244798  0.257038      0.269278  ...              4      2
# 1521  0.448356  0.408502      0.229160  ...             12     12
# 453   1.118270  0.234699      0.124252  ...             36     17
# 2644  0.963082  0.433387      0.204655  ...             23     37
#
#       current_value  highest_value  position_encoded  winger  height_z_score  \
# 5731       32000000       32000000                 4       0        0.110401
# 275        32000000       32000000                 2       0        1.545371
# 162        32000000       32000000                 1       0        2.262856
# 124        32000000       38000000                 4       1       -1.324568
# 1508       32000000       50000000                 2       0        1.258377
# ...             ...            ...               ...     ...             ...
# 1017      110000000      110000000                 3       0        0.397395
# 960       120000000      120000000                 3       0        0.684389
# 1521      150000000      150000000                 4       1       -0.750581
# 453       170000000      170000000                 4       0        1.975862
# 2644      180000000      200000000                 4       0       -0.463587
#
#       days_injured_z_score  games_injured_z_score  current_value_z_score
# 5731             -0.249975               0.016024               3.097237
# 275              -0.198563              -0.129668               3.097237
# 162              -0.672703              -0.712436               3.097237
# 124               2.172138               2.589916               3.097237
# 1508              1.989337               2.492788               3.097237
# ...                    ...                    ...                    ...
# 1017             -0.295676              -0.421052              11.615150
# 960              -0.564165              -0.518180              12.707190
# 1521             -0.272826              -0.129668              15.983310
# 453               0.492654               1.035868              18.167391
# 2644              0.121339               0.404536              19.259431
#
# [201 rows x 26 columns]

# %%
# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(football_df["current_value_z_score"], bins=15, color="blue", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Z-score of Current Value", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Players' Current Value (Z-score)", fontsize=14)
plt.axvline(0, color='red', linestyle='dashed', linewidth=2, label="Mean (0)")
plt.axvline(3, color='green', linestyle='dashed', linewidth=2, label="Upper Outlier Threshold (+3)")
plt.axvline(-3, color='orange', linestyle='dashed', linewidth=2, label="Lower Outlier Threshold (-3)")
plt.legend()
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
indexs=football_df[(football_df['current_value_z_score'] > 3) | (football_df['current_value_z_score']< -3)].index
football_df.drop(indexs,inplace=True)

# %%
football_df.shape
# Out:
# (10272, 26)

# %% [markdown]
# ##### football_df - current_value column's outliers

# %%
# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(football_df["highest_value"], bins=15, color="green", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Highest Value", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Players' Highest Value", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
zscore(football_df['highest_value'])

football_df['highest_value_z_score'] = zscore(football_df['highest_value'])

football_df[(football_df['highest_value_z_score'] > 4) | (football_df['highest_value_z_score']< -4)].sort_values(by='highest_value')
# Out:
#                                         player                team  \
# 1052        /andre-silva/profil/spieler/198008          RB Leipzig
# 4298        /david-neres/profil/spieler/469822          SL Benfica
# 3756        /arturo-vidal/profil/spieler/37666         CR Flamengo
# 519       /denis-zakaria/profil/spieler/334526          Chelsea FC
# 970    /sebastien-haller/profil/spieler/181375   Borussia Dortmund
# ...                                        ...                 ...
# 518         /ngolo-kante/profil/spieler/225083          Chelsea FC
# 1575       /paulo-dybala/profil/spieler/206050             AS Roma
# 9433    /cristiano-ronaldo/profil/spieler/8198         Al-Nassr FC
# 1501  /antoine-griezmann/profil/spieler/125781  Atlético de Madrid
# 1522         /eden-hazard/profil/spieler/50202         Real Madrid
#
#                    name                    position  height   age  appearance  \
# 1052        André Silva       Attack Centre-Forward   185.0  27.0          95
# 4298        David Neres          Attack-RightWinger   176.0  26.0          70
# 3756       Arturo Vidal    midfield-CentralMidfield   180.0  36.0          49
# 519       Denis Zakaria  midfield-DefensiveMidfield   190.0  26.0          44
# 970    Sébastien Haller       Attack Centre-Forward   191.0  28.0          65
# ...                 ...                         ...     ...   ...         ...
# 518        N'Golo Kanté  midfield-DefensiveMidfield   171.0  32.0          51
# 1575       Paulo Dybala        Attack-SecondStriker   177.0  29.0          77
# 9433  Cristiano Ronaldo       Attack Centre-Forward   187.0  38.0          74
# 1501  Antoine Griezmann        Attack-SecondStriker   176.0  32.0          87
# 1522        Eden Hazard           Attack-LeftWinger   175.0  32.0          33
#
#          goals   assists  yellow cards  ...  award  current_value  \
# 1052  0.403379  0.263748      0.077573  ...      4       20000000
# 4298  0.381659  0.405513      0.143122  ...      7       22000000
# 3756  0.104227  0.208454      0.416908  ...     27        1200000
# 519   0.117188  0.058594      0.175781  ...      0       20000000
# 970   0.784036  0.255267      0.127634  ...      6       30000000
# ...        ...       ...           ...  ...    ...            ...
# 518   0.052972  0.158917      0.105945  ...     13       20000000
# 1575  0.580418  0.246238      0.175884  ...     17       30000000
# 9433  0.617780  0.105475      0.256153  ...     90       15000000
# 1501  0.351391  0.380673      0.087848  ...     11       25000000
# 1522  0.138996  0.277992      0.138996  ...     19        5000000
#
#       highest_value  position_encoded  winger  height_z_score  \
# 1052       45000000                 4       0        0.540892
# 4298       45000000                 4       1       -0.750581
# 3756       45000000                 3       0       -0.176593
# 519        45000000                 3       0        1.258377
# 970        45000000                 4       0        1.401874
# ...             ...               ...     ...             ...
# 518       100000000                 3       0       -1.468065
# 1575      110000000                 4       0       -0.607084
# 9433      120000000                 4       0        0.827886
# 1501      150000000                 4       0       -0.750581
# 1522      150000000                 4       1       -0.894078
#
#       days_injured_z_score  games_injured_z_score  current_value_z_score  \
# 1052              0.589767               0.016024               1.786789
# 4298              1.697997               1.667200               2.005197
# 3756              0.755430               1.278688              -0.266246
# 519               2.109300               2.152840               1.786789
# 970               0.966794               1.230124               2.878829
# ...                    ...                    ...                    ...
# 518               2.240688               2.978428               1.786789
# 1575              1.086757               2.055712               2.878829
# 9433              0.287002               0.598792               1.240769
# 1501             -0.055749               0.161716               2.332809
# 1522              1.612310               2.152840               0.148729
#
#       highest_value_z_score
# 1052               4.253117
# 4298               4.253117
# 3756               4.253117
# 519                4.253117
# 970                4.253117
# ...                     ...
# 518               10.081170
# 1575              11.140816
# 9433              12.200462
# 1501              15.379401
# 1522              15.379401
#
# [123 rows x 27 columns]

# %%
# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(football_df["highest_value_z_score"], bins=15, color="green", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Z-score of Highest Value", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Players' Highest Value (Z-score)", fontsize=14)
plt.axvline(0, color='red', linestyle='dashed', linewidth=2, label="Mean (0)")
plt.axvline(4, color='green', linestyle='dashed', linewidth=2, label="Upper Outlier Threshold (+4)")
plt.axvline(-4, color='orange', linestyle='dashed', linewidth=2, label="Lower Outlier Threshold (-4)")
plt.legend()
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
indexs=football_df[(football_df['highest_value_z_score'] > 4) | (football_df['highest_value_z_score']< -4)].index
football_df.drop(indexs,inplace=True)

# %%
football_df.shape
# Out:
# (10149, 27)

# %% [markdown]
# ## 3. Univariate Analysis:

# %% [markdown]
# ### 1. Univariate Graphical Analysis:
# Method to perform uni-variate analysis will depend on whether the variable type is categorical or numerical.

# %% [markdown]
# #### I. Categorical Variables:
#
# we’ll use frequency table to understand distribution of each category
# - Bar Chart (Ordinal) - Orderd
# - Pie Chart (Nominal) - non Orderd

# %%
team_counts = football_df["team"].value_counts().head(10)  # استخراج أعلى 10 فرق

# رسم المخطط الشريطي
plt.figure(figsize=(10, 6))
team_counts.plot(kind="bar", color="#52796F")

# تخصيص المخطط
plt.xlabel("Team", fontsize=12)
plt.ylabel("How frequent it showed up", fontsize=12)
plt.title("Top 10 Teams ", fontsize=14)
plt.xticks(rotation=45)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# عرض المخطط
plt.show()

# %%
# I thought that maybe the top-showing teams would affect the player's value but none of these teams are well-known ones 
# So I thought the exact opposite thing is that maybe the players with high values don't change their teams frequently(?) *Neymar is a special case

# %%
position_counts = football_df["position"].value_counts()  # حساب تكرار كل مركز

# رسم المخطط الشريطي
plt.figure(figsize=(12, 6))
position_counts.plot(kind="bar", color="darkgreen")

# تخصيص المخطط
plt.xlabel("Position", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Player Distribution by Position", fontsize=14)
plt.xticks(rotation=45)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# عرض المخطط
plt.show()

# %%
# Defender Center-Back is the most showing position it's more by almost 500 than the nearest position in the list

# %% [markdown]
# #### II. Numerical Variables:
#
# we need to understand the central tendency and spread of the variable (Descriptive Analysis) using:
#    - Box plot
#    - Histogram

# %%
football_df.dtypes
# Out:
# player                    object
# team                      object
# name                      object
# position                  object
# height                   float64
# age                      float64
# appearance                 int64
# goals                    float64
# assists                  float64
# yellow cards             float64
# second yellow cards      float64
# red cards                float64
# goals conceded           float64
# clean sheets             float64
# minutes played             int64
# days_injured               int64
# games_injured              int64
# award                      int64
# current_value              int64
# highest_value              int64
# position_encoded           int64
# winger                     int64
# height_z_score           float64
# days_injured_z_score     float64
# games_injured_z_score    float64
# current_value_z_score    float64
# highest_value_z_score    float64
# dtype: object

# %%
# رسم الهيستوغرام لعمر اللاعبين
plt.figure(figsize=(10, 6))
plt.hist(football_df["age"], bins=15, color="navy", edgecolor="black", alpha=0.7)

# تخصيص المخطط
plt.xlabel("Age", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Players' Age", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# عرض المخطط
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(football_df["goals"], fill=True, color="royalblue", alpha=0.6)

plt.xlabel("Goals Scored", fontsize=12)
plt.ylabel("Density", fontsize=12)
plt.title("KDE Plot for Goals Scored", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

plt.show()

# %%
# Since  the values are super close to each other, it didn't  make any sense seeing this in an univariate chart

# %%
plt.figure(figsize=(10, 6))
plt.hist(football_df["appearance"], bins=15, color="navy", edgecolor="black", alpha=0.7)

# تخصيص المخطط
plt.xlabel("Appearance", fontsize=12)
plt.ylabel("Number of Appearances", fontsize=12)
plt.title("Distribution of Players' Appearance", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# عرض المخطط
plt.show()

# %%
plt.figure(figsize=(10, 6))
filtered_appearance=football_df[(football_df["appearance"]<=100)]
plt.hist(filtered_appearance["appearance"], bins=15, color="navy", edgecolor="black", alpha=0.7)

# تخصيص المخطط
plt.xlabel("Appearance", fontsize=12)
plt.ylabel("Number of Appearances", fontsize=12)
plt.title("Distribution of Players' Appearance", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# عرض المخطط
plt.show()

# %%
filtered_appearance.shape
# Out:
# (10142, 27)

# %%
# Droping outliers
football_df=football_df[(football_df["appearance"]<=100)]

# %%
# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(football_df["height"], bins=15, color="navy", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Height (cm)", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Players' Height", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %% [markdown]
# ### 2. Univariate Non-Graphical analysis:
#
# - Where is the center of the data? (location) --> **Measures of central tendency**
# - How much does the data vary? (scale) --> **Measure of variability**
# - What is the shape of the data? (shape) --> **Measures of variation combined with an average (measure of center) gives a good picture of the distribution of the data.**

# %%
football_df.describe().T
# Out:
#                          count          mean           std         min  \
# height                 10142.0  1.811946e+02  6.897916e+00  162.000000
# age                    10142.0  2.589190e+01  4.714432e+00   16.000000
# appearance             10142.0  3.520331e+01  2.580724e+01    0.000000
# goals                  10142.0  1.214765e-01  2.327186e-01    0.000000
# assists                10142.0  8.478983e-02  1.429608e-01    0.000000
# yellow cards           10142.0  1.912952e-01  4.440116e-01    0.000000
# second yellow cards    10142.0  4.696911e-03  2.541109e-02    0.000000
# red cards              10142.0  6.888534e-03  8.316415e-02    0.000000
# goals conceded         10142.0  1.334008e-01  4.471045e-01    0.000000
# clean sheets           10142.0  4.555922e-02  9.509049e-01    0.000000
# minutes played         10142.0  2.378587e+03  1.954585e+03    0.000000
# days_injured           10142.0  1.006381e+02  1.421382e+02    0.000000
# games_injured          10142.0  1.337596e+01  1.875072e+01    0.000000
# award                  10142.0  1.647505e+00  2.739897e+00    0.000000
# current_value          10142.0  2.477473e+06  4.501240e+06    0.000000
# highest_value          10142.0  4.169222e+06  6.812978e+06    0.000000
# position_encoded       10142.0  2.704792e+00  9.858553e-01    1.000000
# winger                 10142.0  3.097022e-01  4.623936e-01    0.000000
# height_z_score         10142.0 -5.176263e-03  9.898300e-01   -2.759538
# days_injured_z_score   10142.0 -9.780428e-02  8.119687e-01   -0.672703
# games_injured_z_score  10142.0 -6.284576e-02  9.106100e-01   -0.712436
# current_value_z_score  10142.0 -1.267411e-01  4.915535e-01   -0.397291
# highest_value_z_score  10142.0 -7.350058e-02  7.219345e-01   -0.515291
#
#                                  25%           50%           75%           max
# height                    176.000000  1.812404e+02  1.860000e+02  2.000000e+02
# age                        22.000000  2.500000e+01  2.900000e+01  3.900000e+01
# appearance                 11.000000  3.300000e+01  5.700000e+01  1.000000e+02
# goals                       0.000000  4.256829e-02  1.654260e-01  1.125000e+01
# assists                     0.000000  3.786286e-02  1.291526e-01  4.000000e+00
# yellow cards                0.050876  1.508359e-01  2.492104e-01  3.000000e+01
# second yellow cards         0.000000  0.000000e+00  0.000000e+00  1.000000e+00
# red cards                   0.000000  0.000000e+00  0.000000e+00  6.923077e+00
# goals conceded              0.000000  0.000000e+00  0.000000e+00  9.000000e+00
# clean sheets                0.000000  0.000000e+00  0.000000e+00  9.000000e+01
# minutes played            630.000000  1.982000e+03  3.822750e+03  8.970000e+03
# days_injured                0.000000  3.000000e+01  1.590000e+02  7.300000e+02
# games_injured               0.000000  4.000000e+00  2.100000e+01  8.600000e+01
# award                       0.000000  1.000000e+00  2.000000e+00  3.700000e+01
# current_value          300000.000000  7.500000e+05  2.500000e+06  3.000000e+07
# highest_value          400000.000000  1.250000e+06  4.500000e+06  4.200000e+07
# position_encoded            2.000000  3.000000e+00  4.000000e+00  4.000000e+00
# winger                      0.000000  0.000000e+00  1.000000e+00  1.000000e+00
# height_z_score             -0.750581  1.394214e-03  6.843892e-01  2.693347e+00
# days_injured_z_score       -0.672703 -5.013268e-01  2.355896e-01  3.497445e+00
# games_injured_z_score      -0.712436 -5.181800e-01  3.074081e-01  3.464068e+00
# current_value_z_score      -0.364530 -3.153880e-01 -1.242810e-01  2.878829e+00
# highest_value_z_score      -0.472905 -3.828348e-01 -3.844982e-02  3.935223e+00

# %% [markdown]
# ## 4. Bivariate/Multivariate Analysis:
#
# Here, you look at the relationships between two or more variables. This can involve looking for correlations, patterns, and trends that suggest a relationship or an association.
#
# We can perform bi-variate analysis for any combination of categorical and numerical variables. The combination can be:
# | bi-variate variables   | Plot type |
# | ------------- | ------------- |
# | Categorical & Categorical| Stacked Bar Chart |
# | Categorical & numerical  | scatter plot, histogram, box plot|
# | numerical  & numerical  | Scatter plot, line chart|
#
#
# Multivariate Analysis:
# - Heat map
# - Bar Chart
# - Scatter Chart
# - Line Chart

# %%
# تحديد الأعمدة العددية فقط
numeric_df = football_df.select_dtypes(include=["number"])

# حساب مصفوفة الارتباط
correlation_matrix = numeric_df.corr()
# رسم الخريطة الحرارية
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)

# تخصيص المخطط
plt.title("Correlation Heatmap of Football Data", fontsize=14)
plt.show()

# %%
correlation = football_df[["age", "current_value"]].corr().iloc[0, 1]
print(f"Correlation between Age and Current Value: {correlation:.2f}")

# Plot scatter plot with regression line
plt.figure(figsize=(8, 6))
sns.regplot(x=football_df["age"], y=football_df["current_value"], scatter_kws={"alpha": 0.6}, line_kws={"color": "red"})

# Customize plot
plt.xlabel("Age", fontsize=12)
plt.ylabel("Current Value", fontsize=12)
plt.title(f"Age vs. Current Value (Correlation: {correlation:.2f})", fontsize=14)
plt.grid(True)

# Show plot
plt.show()
# Out:
# Correlation between Age and Current Value: -0.07

# %%
# Seems like the age and current value relationship is weak but its still when the age is larger the less the value

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=football_df["award"], y=football_df["current_value"], alpha=0.6)

plt.xlabel("Number of Awards", fontsize=12)
plt.ylabel("Current Market Value", fontsize=12)
plt.title("Relationship Between Awards and Current Value", fontsize=14)
plt.grid(True)

# Show the plot
plt.show()

# %%
# I see players with higher market values spread across different award counts.
# This means that having a high current value doesn't necessarily mean having a lot of awards.

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=football_df["appearance"], y=football_df["current_value"], alpha=0.6, label="Players")
sns.regplot(x=football_df["appearance"], y=football_df["current_value"], scatter=False, color="red", line_kws={"linewidth":2}, label="Trend Line")

# تخصيص المخطط
plt.xlabel("Number of Appearances", fontsize=12)
plt.ylabel("Current Market Value", fontsize=12)
plt.title("Relationship Between Appearances and Current Value", fontsize=14)
plt.legend()
plt.grid(True)

# عرض المخطط
plt.show()

# %%
# Players with many appearances may have high current value but not necessarily

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Feature Selection

# %%
football_df.dtypes
# Out:
# player                    object
# team                      object
# name                      object
# position                  object
# height                   float64
# age                      float64
# appearance                 int64
# goals                    float64
# assists                  float64
# yellow cards             float64
# second yellow cards      float64
# red cards                float64
# goals conceded           float64
# clean sheets             float64
# minutes played             int64
# days_injured               int64
# games_injured              int64
# award                      int64
# current_value              int64
# highest_value              int64
# position_encoded           int64
# winger                     int64
# height_z_score           float64
# days_injured_z_score     float64
# games_injured_z_score    float64
# current_value_z_score    float64
# highest_value_z_score    float64
# dtype: object

# %%
categorical_features = ['team', 'name', 'position']

# %%
# Need to drop these columns cuz feature engineering didn't work so I want to make the load less
football_df = football_df.drop(columns=[
    "height_z_score",
    "days_injured_z_score",
    "games_injured_z_score",
    "current_value_z_score",
    "highest_value_z_score",
    "player"
])

# %%
football_df = pd.get_dummies(football_df, columns=categorical_features)

# %%
football_df.shape
# Out:
# (10142, 10400)

# %%
correlation = football_df.corr()
print(correlation['current_value'].sort_values(ascending=False))
# Out:
# current_value          1.000000
# highest_value          0.798225
# appearance             0.450694
# minutes played         0.435342
# award                  0.173692
#                          ...
# position_Attack       -0.038840
# position_midfield     -0.046327
# age                   -0.065281
# goals conceded        -0.075350
# position_Goalkeeper   -0.098512
# Name: current_value, Length: 10400, dtype: float64

# %%
# Set the correlation threshold
threshold = 0.16

# Filter the correlations
# We use `abs()` for absolute value to consider both strong positive and negative correlations
selected_features = correlation[abs(correlation['current_value']) > threshold]['current_value'].index
selected_features
# Out:
# Index(['appearance', 'minutes played', 'games_injured', 'award',
#        'current_value', 'highest_value'],
#       dtype='object')

# %%
selected_features = ['appearance', 'minutes played', 'games_injured', 'award',
       'current_value', 'highest_value']

# %%
football_df = football_df[selected_features]
football_df.head()
# Out:
#     appearance  minutes played  games_injured  award  current_value  \
# 1           15            1304             58      1        1500000
# 2            4             292             84      4         600000
# 6           70            5471             19     10       15000000
# 8           34            2758             13      0        2000000
# 10          89            7132             15      3       22000000
#
#     highest_value
# 1        22000000
# 2         6000000
# 6        35000000
# 8         2000000
# 10       22000000

# %%
football_df.shape
# Out:
# (10142, 6)

# %% [markdown]
# ## Prepare Train and Test Data

# %%
# Prepare data
X = football_df.drop(['current_value'], axis=1)
y = football_df['current_value']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.2,
                                                    shuffle=True,
                                                    random_state=42)

# scale the data
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X.shape
# Out:
# (10142, 5)

# %% [markdown]
# # Building The Model

# %%
model = LinearRegression()

# %% [markdown]
# # Train The Model

# %%
# Fit the model on the training data
model.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Test The Model

# %%
# Predict and evaluate the model
y_pred = model.predict(X_test_scaled)      # Linear regression model

# %% [markdown]
# # Interpretation of the Model

# %%
coeff_df = pd.DataFrame(model.coef_,X.columns,columns=['Coefficient'])   # Linear model cofficients

# %%
coeff_df
# Out:
#                  Coefficient
# appearance     -1.242257e+05
# minutes played  7.234879e+05
# games_injured  -4.764537e+05
# award          -6.468828e+05
# highest_value   3.822006e+06

# %%
print(f" Linear regression intercept: {model.intercept_}")
# Out:
#  Linear regression intercept: 2479058.917786269

# %% [markdown]
# # Evaluating The Model

# %% [markdown]
# ### Mean Square Error

# %%
y_base = [y_train.mean()] * len(y_test)

# %%
y_base
# Out:
# [2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  ...]

# %%
# our benchmark model
mse_base = mean_squared_error(y_test, y_base )
print(f'Mean Squared Error of base model: {mse_base:2e}')
# Out:
# Mean Squared Error of base model: 1.885992e+13

# %% [markdown]
# ### Mean Square Error

# %%
# MSE for Linear model
mse_train = mean_squared_error(y_train, model.predict(X_train_scaled))
mse_test = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error for training: {mse_train:2e}')
print(f'Mean Squared Error for testing: {mse_test:2e}')
# Out:
# Mean Squared Error for training: 6.408768e+12
# Mean Squared Error for testing: 6.273010e+12

# %% [markdown]
# ### Mean Absolute Error

# %%
# our benchmark model
mae_base = mean_absolute_error(y_test, y_base )
print(f'Mean Absolute  Error of base model: {mae_base:2e}')
# Out:
# Mean Absolute  Error of base model: 2.645631e+06

# %%
# Linear model
mae_train = mean_absolute_error(y_train, model.predict(X_train_scaled))
mae_test = mean_absolute_error(y_test, y_pred)
print(f'Mean Absolute Error for training: {mae_train:2e}')
print(f'Mean Absolute Error for testing: {mae_test:2e}')
# Out:
# Mean Absolute Error for training: 1.376426e+06
# Mean Absolute Error for testing: 1.387276e+06

# %% [markdown]
# ### Root Mean Squared Error

# %%
# our benchmark model
print(f'Root Mean Squared  Error of base model: {np.sqrt(mse_base):2e}')
# Out:
# Root Mean Squared  Error of base model: 4.342801e+06

# %%
# RMSE for Linear model

print(f'Root Mean Squared Error for training: {np.sqrt(mse_train):2e}')
print(f'Root Mean Squared Error for testing: {np.sqrt(mse_test):2e}')
# Out:
# Root Mean Squared Error for training: 2.531555e+06
# Root Mean Squared Error for testing: 2.504598e+06

# %% [markdown]
# ### Predictions vs. Real Values

# %%
predictions = model.predict(X_test_scaled)
#predictions

# %%
predictions
# Out:
# array([3393480.80327581,  671834.49036245, -741282.49567546, ...,
#        1741975.41510535, -212143.11584316, -249311.52672854])

# %%
Real_Values = np.array(y_test)
# Real_Values

# %%
plt.scatter(Real_Values, predictions)
plt.plot([Real_Values.min(), Real_Values.max()], [Real_Values.min(), Real_Values.max()], color='red', lw=1)
plt.xlabel('Real Values')
plt.ylabel('Predictions')
plt.title('Real Values vs Predictions')
plt.show()

# %%
sns.histplot((y_test - predictions), bins=50, kde=True)
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Distribution of Residuals")
plt.show()

# %% [markdown]
# # R-Square

# %%
r2_score_train = r2_score(y_train, model.predict(X_train_scaled))
r2_score_test = r2_score(y_test, y_pred)
print(f'R Square for training: {r2_score_train}')
print(f'R Square for testing: {r2_score_test}')
# Out:
# R Square for training: 0.6890322703354719
# R Square for testing: 0.6673882835628302

# %% [markdown]
# # Other Models

# %% [markdown]
# ## Building The Model

# %%
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)

# %% [markdown]
# ## Train The Model

# %%
# It was working till I did the rerun :)
rf_model.fit(X_test_scaled, y_train)

# %% [markdown]
# ## Test The Model

# %%
predictions = rf_model.predict(X_test_scaled)

# %% [markdown]
# ## Evaluating The Model

# %% [markdown]
# ### Mean Square Error

# %%
y_base = [y_train.mean()] * len(y_test)

# %%
y_base

# %%
# our benchmark model
mse_base = mean_squared_error(y_test, y_base)
print(f'Mean Squared Error of base model: {mse_base:2e}')
# Out:
# Mean Squared Error of base model: 1.885992e+13

# %% [markdown]
# ### Mean Square Error

# %%
mse_train = mean_squared_error(y_train, rf_model.predict(X_train_scaled))
mse_test = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error for training: {mse_train:2e}')
print(f'Mean Squared Error for testing: {mse_test:2e}')

# %% [markdown]
# ### Mean Absolute Error

# %%
# our benchmark model
mae_base = mean_absolute_error(y_test, y_base )
print(f'Mean Absolute  Error of base model: {mae_base:2e}')

# %%
mae_train = mean_absolute_error(y_train, rf_model.predict(X_train_scaled))
mae_test = mean_absolute_error(y_test, y_pred)
print(f'Mean Absolute Error for training: {mae_train:2e}')
print(f'Mean Absolute Error for testing: {mae_test:2e}')

# %% [markdown]
# ### Root Mean Squared Error

# %%
# our benchmark model
print(f'Root Mean Squared  Error of base model: {np.sqrt(mse_base):2e}')

# %%
print(f'Root Mean Squared Error for training: {np.sqrt(mse_train):2e}')
print(f'Root Mean Squared Error for testing: {np.sqrt(mse_test):2e}')

# %% [markdown]
# ### Predictions vs. Real Values

# %%
predictions = rf_model.predict(X_test_scaled)
#predictions

# %%
predictions

# %%
Real_Values = np.array(y_test)
# Real_Values

# %%
importances = rf_model.feature_importances_
feature_importance_df = pd.DataFrame({'Feature': X_train.columns, 'Importance': importances})
print(feature_importance_df.sort_values(by='Importance', ascending=False))

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_test, predictions, alpha=0.6)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linestyle='--')
plt.xlabel('Actual Values')
plt.ylabel('Predictions')
plt.title('Predictions vs Actual Values')
plt.grid()
plt.show()

# %%
# Plotting Distribution of Residuals
plt.figure(figsize=(10, 6))
sns.histplot((y_test - predictions), bins=50, kde=True)
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.title('Distribution of Residuals')
plt.grid()
plt.show()

# %% [markdown]
# ### R- Square

# %%
r2_score_train = r2_score(y_train, rf_model.predict(X_train_scaled))
r2_score_test = r2_score(y_test, y_pred)
print(f'R Square for training: {r2_score_train}')
print(f'R Square for testing: {r2_score_test}')

# %% [markdown]
# ## Building The Model

# %%
# Initialize the XGBoost model
xg_model = XGBRegressor(n_estimators=100, random_state=42)

# %% [markdown]
# ## Train Model

# %%
# Fit the model using the scaled training data
xg_model.fit(X_train_scaled, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %% [markdown]
# ## Test The Model

# %%
# Make predictions on the scaled test data
predictions_xg = xg_model.predict(X_test_scaled)

# %% [markdown]
# ## Evaluating The Model

# %% [markdown]
# ### Mean Square Error

# %%
y_base = [y_train.mean()] * len(y_test)

# %%
y_base
# Out:
# [2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  ...]

# %%
# our benchmark model
mse_base = mean_squared_error(y_test, y_base)
print(f'Mean Squared Error of base model: {mse_base:2e}')
# Out:
# Mean Squared Error of base model: 1.885992e+13

# %% [markdown]
# ### Mean Square Error

# %%
# MSE 
mse_train = mean_squared_error(y_train, xg_model.predict(X_train_scaled))
mse_test = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error for training: {mse_train:2e}')
print(f'Mean Squared Error for testing: {mse_test:2e}')
# Out:
# Mean Squared Error for training: 5.086670e+11
# Mean Squared Error for testing: 6.273010e+12

# %% [markdown]
# ### Mean Absolute Error

# %%
# our benchmark model
mae_base = mean_absolute_error(y_test, y_base )
print(f'Mean Absolute  Error of base model: {mae_base:2e}')
# Out:
# Mean Absolute  Error of base model: 2.645631e+06

# %%
mae_train = mean_absolute_error(y_train, xg_model.predict(X_train_scaled))
mae_test = mean_absolute_error(y_test, y_pred)
print(f'Mean Absolute Error for training: {mae_train:2e}')
print(f'Mean Absolute Error for testing: {mae_test:2e}')
# Out:
# Mean Absolute Error for training: 4.133219e+05
# Mean Absolute Error for testing: 1.387276e+06

# %% [markdown]
# ### Root Mean Squared Error

# %%
# our benchmark model
print(f'Root Mean Squared  Error of base model: {np.sqrt(mse_base):2e}')
# Out:
# Root Mean Squared  Error of base model: 4.342801e+06

# %%
# RMSE 

print(f'Root Mean Squared Error for training: {np.sqrt(mse_train):2e}')
print(f'Root Mean Squared Error for testing: {np.sqrt(mse_test):2e}')
# Out:
# Root Mean Squared Error for training: 7.132089e+05
# Root Mean Squared Error for testing: 2.504598e+06

# %% [markdown]
# ### Predictions vs. Real Values

# %%
predictions = xg_model.predict(X_test_scaled)
#predictions

# %%
predictions
# Out:
# array([2618934.5  ,  120362.266,  604862.56 , ..., 1080096.9  ,
#         528805.56 ,  553520.4  ], dtype=float32)

# %%
Real_Values = np.array(y_test)
# Real_Values

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_test, predictions, alpha=0.6)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linestyle='--')
plt.xlabel('Actual Values')
plt.ylabel('Predictions')
plt.title('Predictions vs Actual Values')
plt.grid()
plt.show()

# %%
# Plotting Distribution of Residuals
plt.figure(figsize=(10, 6))
sns.histplot((y_test - predictions), bins=50, kde=True)
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.title('Distribution of Residuals')
plt.grid()
plt.show()

# %% [markdown]
# ## R- Square

# %%
r2_score_train = r2_score(y_train, xg_model.predict(X_train_scaled))
r2_score_test = r2_score(y_test, y_pred)
print(f'R Square for training: {r2_score_train}')
print(f'R Square for testing: {r2_score_test}')
# Out:
# R Square for training: 0.9753183126449585
# R Square for testing: 0.6673882835628302

# %% [markdown]
# ##### What I Understood

# %% [raw]
# -
