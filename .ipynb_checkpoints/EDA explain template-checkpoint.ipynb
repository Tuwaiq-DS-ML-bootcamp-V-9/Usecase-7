# %%
# To ignore warnings
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

from scipy.stats import zscore
import dtale




## This statement allows the visuals to render within your Jupyter Notebook.
# %matplotlib inline

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-2.1.4-py3-none-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in c:\users\rahaf\anaconda3\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\rahaf\anaconda3\lib\site-packages (from xgboost) (1.13.1)
# Downloading xgboost-2.1.4-py3-none-win_amd64.whl (124.9 MB)
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 1.3/124.9 MB 6.7 MB/s eta 0:00:19
#    - -------------------------------------- 4.5/124.9 MB 10.3 MB/s eta 0:00:12
#    -- ------------------------------------- 7.1/124.9 MB 10.9 MB/s eta 0:00:11
#    --- ------------------------------------ 10.5/124.9 MB 12.1 MB/s eta 0:00:10
#    ---- ----------------------------------- 13.9/124.9 MB 12.8 MB/s eta 0:00:09
#    ----- ---------------------------------- 16.3/124.9 MB 12.5 MB/s eta 0:00:09
#    ------ --------------------------------- 18.9/124.9 MB 12.4 MB/s eta 0:00:09
#    ------ --------------------------------- 21.5/124.9 MB 12.6 MB/s eta 0:00:09
#    ------- -------------------------------- 24.6/124.9 MB 12.7 MB/s eta 0:00:08
#    -------- ------------------------------- 27.3/124.9 MB 12.6 MB/s eta 0:00:08
#    --------- ------------------------------ 29.4/124.9 MB 12.4 MB/s eta 0:00:08
#    ---------- ----------------------------- 31.5/124.9 MB 12.2 MB/s eta 0:00:08
#    ----------- ---------------------------- 36.2/124.9 MB 12.8 MB/s eta 0:00:07
#    ------------ --------------------------- 39.3/124.9 MB 13.0 MB/s eta 0:00:07
#    ------------- -------------------------- 43.3/124.9 MB 13.4 MB/s eta 0:00:07
#    --------------- ------------------------ 47.2/124.9 MB 13.6 MB/s eta 0:00:06
#    ---------------- ----------------------- 51.6/124.9 MB 14.1 MB/s eta 0:00:06
#    ------------------ --------------------- 56.6/124.9 MB 14.5 MB/s eta 0:00:05
#    ------------------- -------------------- 61.6/124.9 MB 15.0 MB/s eta 0:00:05
#    -------------------- ------------------- 64.7/124.9 MB 15.3 MB/s eta 0:00:04
#    -------------------- ------------------- 65.0/124.9 MB 14.6 MB/s eta 0:00:05
#    --------------------- ------------------ 67.9/124.9 MB 14.3 MB/s eta 0:00:04
#    ---------------------- ----------------- 70.5/124.9 MB 14.2 MB/s eta 0:00:04
#    ----------------------- ---------------- 72.4/124.9 MB 13.9 MB/s eta 0:00:04
#    ------------------------ --------------- 75.5/124.9 MB 14.0 MB/s eta 0:00:04
#    ------------------------ --------------- 77.3/124.9 MB 13.7 MB/s eta 0:00:04
#    ------------------------- -------------- 80.0/124.9 MB 13.7 MB/s eta 0:00:04
#    -------------------------- ------------- 82.8/124.9 MB 13.7 MB/s eta 0:00:04
#    --------------------------- ------------ 85.7/124.9 MB 13.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 89.4/124.9 MB 13.8 MB/s eta 0:00:03
#    ----------------------------- ---------- 92.0/124.9 MB 13.7 MB/s eta 0:00:03
#    ------------------------------ --------- 94.4/124.9 MB 13.6 MB/s eta 0:00:03
#    ------------------------------- -------- 97.5/124.9 MB 13.6 MB/s eta 0:00:03
#    ------------------------------- ------- 100.4/124.9 MB 13.7 MB/s eta 0:00:02
#    -------------------------------- ------ 103.0/124.9 MB 13.6 MB/s eta 0:00:02
#    --------------------------------- ----- 106.2/124.9 MB 13.6 MB/s eta 0:00:02
#    ---------------------------------- ---- 110.4/124.9 MB 13.8 MB/s eta 0:00:02
#    ---------------------------------- ---- 110.9/124.9 MB 13.5 MB/s eta 0:00:02
#    ----------------------------------- --- 112.7/124.9 MB 13.3 MB/s eta 0:00:01
#    ----------------------------------- --- 114.0/124.9 MB 13.1 MB/s eta 0:00:01
#    ------------------------------------ -- 116.4/124.9 MB 13.1 MB/s eta 0:00:01
#    ------------------------------------- - 119.5/124.9 MB 13.1 MB/s eta 0:00:01
#    ------------------------------------- - 121.1/124.9 MB 13.0 MB/s eta 0:00:01
#    --------------------------------------  124.0/124.9 MB 13.0 MB/s eta 0:00:01
#    --------------------------------------  124.8/124.9 MB 12.9 MB/s eta 0:00:01
#    --------------------------------------  124.8/124.9 MB 12.9 MB/s eta 0:00:01
#    --------------------------------------- 124.9/124.9 MB 12.5 MB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-2.1.4

# %% [markdown]
# ## Loading the data
# We can now load the dataset into pandas using the read_csv() function. This converts the CSV file into a Pandas dataframe.

# %%
football_df = pd.read_csv('Data/final_data.csv')

# %% [markdown]
# # Preprocess the Data

# %% [markdown]
# ### Viewing the dataframe
# We can get a quick sense of the size of our dataset by using the shape method. This returns a tuple with the number of rows and columns in the dataset.

# %%
football_df_report=dtale.show(football_df)
football_df_report
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://LAPTOP-8L6R58JJ:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # EDA

# %% [markdown]
# ## 1. Data Profiling:
# Data profiling is a comprehensive process of examining the data available in an existing dataset and collecting statistics and information about that data.

# %%
football_df.head()
# Out:
#                                      player               team  \
# 0        /david-de-gea/profil/spieler/59377  Manchester United
# 1       /jack-butland/profil/spieler/128899  Manchester United
# 2          /tom-heaton/profil/spieler/34130  Manchester United
# 3  /lisandro-martinez/profil/spieler/480762  Manchester United
# 4     /raphael-varane/profil/spieler/164770  Manchester United
#
#                 name              position  height   age  appearance  \
# 0       David de Gea            Goalkeeper   189.0  32.0         104
# 1       Jack Butland            Goalkeeper   196.0  30.0          15
# 2         Tom Heaton            Goalkeeper   188.0  37.0           4
# 3  Lisandro Martínez  Defender Centre-Back   175.0  25.0          82
# 4     Raphaël Varane  Defender Centre-Back   191.0  30.0          63
#
#       goals   assists  yellow cards  ...  goals conceded  clean sheets  \
# 0  0.000000  0.000000      0.009585  ...        1.217252      0.335463
# 1  0.000000  0.000000      0.069018  ...        1.242331      0.207055
# 2  0.000000  0.000000      0.000000  ...        0.616438      0.924658
# 3  0.028090  0.056180      0.224719  ...        0.000000      0.000000
# 4  0.017889  0.017889      0.053667  ...        0.000000      0.000000
#
#    minutes played  days_injured  games_injured  award  current_value  \
# 0            9390            42              5     13       15000000
# 1            1304           510             58      1        1500000
# 2             292           697             84      4         600000
# 3            6408           175             22      9       50000000
# 4            5031           238             51     21       40000000
#
#    highest_value  position_encoded  winger
# 0       70000000                 1       0
# 1       22000000                 1       0
# 2        6000000                 1       0
# 3       50000000                 2       0
# 4       80000000                 2       0
#
# [5 rows x 22 columns]

# %%
# NO NULL VALUES
football_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10754 entries, 0 to 10753
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   player               10754 non-null  object
#  1   team                 10754 non-null  object
#  2   name                 10754 non-null  object
#  3   position             10754 non-null  object
#  4   height               10754 non-null  float64
#  5   age                  10754 non-null  float64
#  6   appearance           10754 non-null  int64
#  7   goals                10754 non-null  float64
#  8   assists              10754 non-null  float64
#  9   yellow cards         10754 non-null  float64
#  10  second yellow cards  10754 non-null  float64
#  11  red cards            10754 non-null  float64
#  12  goals conceded       10754 non-null  float64
#  13  clean sheets         10754 non-null  float64
#  14  minutes played       10754 non-null  int64
#  15  days_injured         10754 non-null  int64
#  16  games_injured        10754 non-null  int64
#  17  award                10754 non-null  int64
#  18  current_value        10754 non-null  int64
#  19  highest_value        10754 non-null  int64
#  20  position_encoded     10754 non-null  int64
#  21  winger               10754 non-null  int64
# dtypes: float64(9), int64(9), object(4)
# memory usage: 1.8+ MB

# %%
football_df.duplicated().sum()
# Out:
# 0

# %%
football_df
# Out:
#                                           player                      team  \
# 0             /david-de-gea/profil/spieler/59377         Manchester United
# 1            /jack-butland/profil/spieler/128899         Manchester United
# 2               /tom-heaton/profil/spieler/34130         Manchester United
# 3       /lisandro-martinez/profil/spieler/480762         Manchester United
# 4          /raphael-varane/profil/spieler/164770         Manchester United
# ...                                          ...                       ...
# 10749       /aidan-simmons/profil/spieler/867763  Western Sydney Wanderers
# 10750        /kusini-yengi/profil/spieler/708099  Western Sydney Wanderers
# 10751    /nathanael-blair/profil/spieler/1023268  Western Sydney Wanderers
# 10752    /zachary-sapsford/profil/spieler/703657  Western Sydney Wanderers
# 10753  /alexander-badolato/profil/spieler/957230  Western Sydney Wanderers
#
#                      name               position      height   age  \
# 0            David de Gea             Goalkeeper  189.000000  32.0
# 1            Jack Butland             Goalkeeper  196.000000  30.0
# 2              Tom Heaton             Goalkeeper  188.000000  37.0
# 3       Lisandro Martínez   Defender Centre-Back  175.000000  25.0
# 4          Raphaël Varane   Defender Centre-Back  191.000000  30.0
# ...                   ...                    ...         ...   ...
# 10749       Aidan Simmons     Attack-RightWinger  181.240353  20.0
# 10750        Kusini Yengi  Attack Centre-Forward  190.000000  24.0
# 10751     Nathanael Blair  Attack Centre-Forward  181.240353  19.0
# 10752    Zachary Sapsford  Attack Centre-Forward  181.240353  20.0
# 10753  Alexander Badolato  Attack Centre-Forward  170.000000  18.0
#
#        appearance     goals   assists  yellow cards  ...  goals conceded  \
# 0             104  0.000000  0.000000      0.009585  ...        1.217252
# 1              15  0.000000  0.000000      0.069018  ...        1.242331
# 2               4  0.000000  0.000000      0.000000  ...        0.616438
# 3              82  0.028090  0.056180      0.224719  ...        0.000000
# 4              63  0.017889  0.017889      0.053667  ...        0.000000
# ...           ...       ...       ...           ...  ...             ...
# 10749          16  0.175953  0.087977      0.263930  ...        0.000000
# 10750          26  0.372671  0.186335      0.186335  ...        0.000000
# 10751          20  0.375000  0.000000      0.187500  ...        0.000000
# 10752          17  0.312139  0.104046      0.000000  ...        0.000000
# 10753          21  0.000000  0.000000      0.086042  ...        0.000000
#
#        clean sheets  minutes played  days_injured  games_injured  award  \
# 0          0.335463            9390            42              5     13
# 1          0.207055            1304           510             58      1
# 2          0.924658             292           697             84      4
# 3          0.000000            6408           175             22      9
# 4          0.000000            5031           238             51     21
# ...             ...             ...           ...            ...    ...
# 10749      0.000000            1023             0              0      0
# 10750      0.000000            1449           102             18      0
# 10751      0.000000             960             0              0      0
# 10752      0.000000             865             0              0      0
# 10753      0.000000            1046             0              0      0
#
#        current_value  highest_value  position_encoded  winger
# 0           15000000       70000000                 1       0
# 1            1500000       22000000                 1       0
# 2             600000        6000000                 1       0
# 3           50000000       50000000                 2       0
# 4           40000000       80000000                 2       0
# ...              ...            ...               ...     ...
# 10749          75000          75000                 4       1
# 10750         300000         300000                 4       0
# 10751          50000          50000                 4       0
# 10752          50000          50000                 4       0
# 10753          25000          25000                 4       0
#
# [10754 rows x 22 columns]

# %%
# position_encoded --> 1- Goalkeeper, 2- Defender, 3- midfield, 4- Attack
# winger --> 1: winger, 0: not a winger

# %%
# Apperentlly "goals," "assists," "yellow cards," "second yellow cards," 
# "red cards," "goals conceded," and "clean sheets" were transformed to a per 90-minute basis.

# %%
football_df.dtypes
# Out:
# player                  object
# team                    object
# name                    object
# position                object
# height                 float64
# age                    float64
# appearance               int64
# goals                  float64
# assists                float64
# yellow cards           float64
# second yellow cards    float64
# red cards              float64
# goals conceded         float64
# clean sheets           float64
# minutes played           int64
# days_injured             int64
# games_injured            int64
# award                    int64
# current_value            int64
# highest_value            int64
# position_encoded         int64
# winger                   int64
# dtype: object

# %%
football_df['team'].unique()
# Out:
# array(['Manchester United', 'West Ham United', 'Leicester City',
#        'Aston Villa', 'Wolverhampton Wanderers', 'Southampton FC',
#        'Brighton &amp; Hove Albion', 'Everton FC', 'Nottingham Forest',
#        'Leeds United', 'Crystal Palace', 'Fulham FC', 'AFC Bournemouth',
#        'Brentford FC', 'Liverpool FC', 'Newcastle United',
#        'Manchester City', 'Arsenal FC', 'Tottenham Hotspur', 'Chelsea FC',
#        'Borussia Mönchengladbach', 'VfL Wolfsburg', 'TSG 1899 Hoffenheim',
#        '1.FC Union Berlin', 'FC Augsburg', 'VfB Stuttgart',
#        '1.FSV Mainz 05', '1.FC Köln', 'Hertha BSC', 'FC Schalke 04',
#        'VfL Bochum', 'SV Werder Bremen', 'Eintracht Frankfurt',
#        'SC Freiburg', 'Borussia Dortmund', 'Bayer 04 Leverkusen',
#        'Bayern Munich', 'RB Leipzig', 'Real Sociedad', 'Villarreal CF',
#        'Real Betis Balompié', 'Athletic Bilbao', 'Valencia CF',
#        'Sevilla FC', 'Celta de Vigo', 'CA Osasuna', 'Girona FC',
#        'Rayo Vallecano', 'RCD Mallorca', 'UD Almería',
#        'Real Valladolid CF', 'Cádiz CF', 'Elche CF',
#        'RCD Espanyol Barcelona', 'Getafe CF', 'Atlético de Madrid',
#        'Real Madrid', 'FC Barcelona', 'AS Roma', 'SS Lazio',
#        'ACF Fiorentina', 'US Sassuolo', 'Torino FC', 'Udinese Calcio',
#        'Bologna FC 1909', 'AC Monza', 'FC Empoli', 'US Lecce',
#        'Spezia Calcio', 'Hellas Verona', 'UC Sampdoria', 'US Cremonese',
#        'US Salernitana 1919', 'Atalanta BC', 'SSC Napoli', 'Inter Milan',
#        'AC Milan', 'Juventus FC', 'AS Monaco', 'Stade Rennais FC',
#        'Olympique Marseille', 'OGC Nice', 'RC Lens', 'FC Nantes',
#        'Montpellier HSC', 'FC Lorient', 'FC Toulouse', 'ESTAC Troyes',
#        'Stade Brestois 29', 'Angers SCO', 'AJ Auxerre',
#        'Clermont Foot 63', 'AC Ajaccio', 'Olympique Lyon', 'LOSC Lille',
#        'Stade Reims', 'RC Strasbourg Alsace', 'Paris Saint-Germain',
#        'AZ Alkmaar', 'Twente Enschede FC', 'Vitesse Arnhem',
#        'FC Groningen', 'Fortuna Sittard', 'NEC Nijmegen',
#        'Sparta Rotterdam', 'SC Cambuur Leeuwarden', 'Excelsior Rotterdam',
#        'FC Volendam', 'RKC Waalwijk', 'FC Emmen', 'Go Ahead Eagles',
#        'FC Utrecht', 'SC Heerenveen', 'Ajax Amsterdam', 'PSV Eindhoven',
#        'Feyenoord Rotterdam', 'Club Athletico Paranaense',
#        'Red Bull Bragantino', 'Santos FC',
#        'Clube de Regatas Vasco da Gama', 'Fluminense Football Club',
#        'Sport Club Internacional', 'Esporte Clube Bahia',
#        'Grêmio Foot-Ball Porto Alegrense', 'Coritiba Foot Ball Club',
#        'Fortaleza Esporte Clube', 'Cruzeiro Esporte Clube',
#        'Goiás Esporte Clube', 'Cuiabá Esporte Clube (MT)',
#        'Botafogo de Futebol e Regatas', 'Clube Atlético Mineiro',
#        'São Paulo Futebol Clube', 'América Futebol Clube (MG)',
#        'Sociedade Esportiva Palmeiras', 'CR Flamengo',
#        'Sport Club Corinthians Paulista', 'SC Braga', 'FC Famalicão',
#        'Vitória Guimarães SC', 'CD Santa Clara', 'GD Estoril Praia',
#        'Boavista FC', 'Portimonense SC', 'CS Marítimo', 'Casa Pia AC',
#        'FC Paços de Ferreira', 'FC Arouca', 'FC Vizela', 'Rio Ave FC',
#        'GD Chaves', 'Gil Vicente FC', 'FC Porto', 'Sporting CP',
#        'SL Benfica', 'Santos Laguna', 'Club León FC', 'FC Juárez',
#        'Club Tijuana', 'Atlético de San Luis', 'Club Necaxa', 'Puebla FC',
#        'Mazatlán FC', 'Querétaro FC', 'CF América', 'CF Monterrey',
#        'Atlas Guadalajara', 'UNAM Pumas', 'Deportivo Toluca',
#        'Tigres UANL', 'Deportivo Guadalajara', 'CD Cruz Azul',
#        'CF Pachuca', 'Dynamo Moscow', 'Lokomotiv Moscow', 'FK Rostov',
#        'Krylya Sovetov Samara', 'FC Sochi', 'Akhmat Grozny',
#        'Ural Yekaterinburg', 'FK Orenburg', 'FC Pari Nizhniy Novgorod',
#        'FK Khimki', 'Torpedo Moscow', 'Fakel Voronezh', 'Spartak Moscow',
#        'CSKA Moscow', 'FK Krasnodar', 'Zenit St. Petersburg',
#        'West Bromwich Albion', 'Sunderland AFC', 'Hull City',
#        'Preston North End', 'Stoke City', 'Queens Park Rangers',
#        'Birmingham City', 'Cardiff City', 'Millwall FC', 'Reading FC',
#        'Blackpool FC', 'Bristol City', 'Huddersfield Town',
#        'Rotherham United', 'Wigan Athletic', 'Middlesbrough FC',
#        'Coventry City', 'Luton Town', 'Swansea City', 'Burnley FC',
#        'Watford FC', 'Sheffield United', 'Blackburn Rovers',
#        'Norwich City', 'Trabzonspor', 'Besiktas JK', 'Basaksehir FK',
#        'Antalyaspor', 'Adana Demirspor', 'Alanyaspor', 'Kasimpasa',
#        'Konyaspor', 'MKE Ankaragücü', 'Sivasspor', 'Kayserispor',
#        'Giresunspor', 'Istanbulspor', 'Hatayspor', 'Gaziantep FK',
#        'Fatih Karagümrük', 'Ümraniyespor', 'Fenerbahce', 'Galatasaray',
#        'SK Sturm Graz', 'LASK', 'SCR Altach', 'SC Austria Lustenau',
#        'SV Ried', 'TSV Hartberg', 'WSG Tirol', 'Rapid Vienna',
#        'Austria Vienna', 'SK Austria Klagenfurt', 'Wolfsberger AC',
#        'Red Bull Salzburg', 'Philadelphia Union', 'FC Cincinnati',
#        'FC Dallas', 'Orlando City SC', 'Los Angeles Galaxy',
#        'New England Revolution', 'D.C. United', 'New York Red Bulls',
#        'Portland Timbers', 'Columbus Crew', 'Charlotte FC',
#        'Sporting Kansas City', 'Colorado Rapids',
#        'Vancouver Whitecaps FC', 'Chicago Fire FC', 'Inter Miami CF',
#        'Minnesota United FC', 'Houston Dynamo FC', 'St. Louis CITY SC',
#        'CF Montréal', 'Real Salt Lake City', 'Nashville SC',
#        'San Jose Earthquakes', 'Seattle Sounders FC', 'Atlanta United FC',
#        'New York City FC', 'Austin FC', 'Los Angeles FC', 'Toronto FC',
#        'CA Vélez Sarsfield', 'CA San Lorenzo de Almagro',
#        'Club Atlético Lanús', 'Defensa y Justicia',
#        'Club Estudiantes de La Plata', "CA Newell's Old Boys", 'CA Colon',
#        'CA Rosario Central', 'CA Banfield',
#        'Club de Gimnasia y Esgrima La Plata', 'Club Atlético Tucumán',
#        'CD Godoy Cruz Antonio Tomba', 'Club Atlético Unión',
#        'Club Atlético Platense', 'Instituto AC Córdoba',
#        'CA Sarmiento (Junin)', 'CA Central Córdoba (SdE)',
#        'CA Barracas Central', 'Arsenal Fútbol Club',
#        'Club Atlético Talleres', 'Club Atlético Belgrano',
#        'AA Argentinos Juniors', 'CA Independiente', 'Club Atlético Tigre',
#        'CA River Plate', 'CA Boca Juniors', 'CA Huracán', 'Racing Club',
#        'Kawasaki Frontale', 'Yokohama F. Marinos', 'Cerezo Osaka',
#        'Kyoto Sanga', 'FC Tokyo', 'Nagoya Grampus', 'Kashiwa Reysol',
#        'Yokohama FC', 'Avispa Fukuoka', 'Sagan Tosu', 'Vissel Kobe',
#        'Hokkaido Consadole Sapporo', 'Shonan Bellmare', 'Albirex Niigata',
#        'Kashima Antlers', 'Sanfrecce Hiroshima', 'Urawa Red Diamonds',
#        'Gamba Osaka', 'Al-Shabab Club (Riyadh)', 'Ettifaq FC',
#        'Al-Taawoun FC', 'Al-Wehda FC', 'Damac FC', 'Al-Tai',
#        'Al-Fayha FC', 'Abha Club', 'Al-Khaleej', 'Al-Raed SFC',
#        'Al-Batin FC', 'Al-Adalah FC', 'Al-Ittihad Club (Jeddah)',
#        'Al-Fateh SC', 'Al-Hilal Saudi FC', 'Al-Nassr FC',
#        'Suwon Samsung Bluewings', 'Jeju United', 'Incheon United',
#        'Gangwon FC', 'Daejeon Hana Citizen', 'Gwangju FC', 'Daegu FC',
#        'Suwon FC', 'Pohang Steelers', 'FC Seoul',
#        'Jeonbuk Hyundai Motors', 'Ulsan Hyundai', 'Sekhukhune United FC',
#        'AmaZulu FC', 'Lamontville Golden Arrows', 'Stellenbosch FC',
#        'Swallows FC', 'Maritzburg United FC', 'Royal AM FC',
#        'TS Galaxy FC', 'Richards Bay FC', 'Marumo Gallants FC',
#        'Cape Town City FC', 'Orlando Pirates', 'SuperSport United',
#        'Chippa United', 'Mamelodi Sundowns FC', 'Kaizer Chiefs',
#        'Melbourne Victory', 'Western United FC', 'Newcastle United Jets',
#        'Perth Glory', 'Macarthur FC', 'Brisbane Roar',
#        'Central Coast Mariners', 'Wellington Phoenix',
#        'Melbourne City FC', 'Sydney FC', 'Adelaide United',
#        'Western Sydney Wanderers'], dtype=object)

# %%
football_df['position'].unique()
# Out:
# array(['Goalkeeper', 'Defender Centre-Back', 'Defender Left-Back',
#        'Defender Right-Back', 'midfield-DefensiveMidfield',
#        'midfield-CentralMidfield', 'midfield-AttackingMidfield',
#        'Attack-LeftWinger', 'Attack-RightWinger', 'Attack Centre-Forward',
#        'midfield-RightMidfield', 'midfield-LeftMidfield',
#        'Attack-SecondStriker', 'midfield', 'Attack', 'Defender'],
#       dtype=object)

# %%
football_df['goals'].unique()
# Out:
# array([0.        , 0.02808989, 0.01788909, ..., 0.22670025, 0.17595308,
#        0.31213873])

# %% [markdown]
# The process of profiling differs slightly for categorical and numerical variables due to their inherent differences.
#
# **The two main types of data are:**
# - Quantitative (numerical) data
# - Qualitative (categorical) data

# %% [markdown]
# ### Data Quality Checks
# Data quality checks involve the process of ensuring that the data is accurate, complete, consistent, relevant, and reliable.
#
#
# **Here are typical steps involved in checking data quality:**

# %% [markdown]
# #### 1. Reliability:
# Evaluate the data's source and collection process to determine its trustworthiness.

# %% [raw]
# The dataset was sourced from Kaggle 'https://www.kaggle.com/datasets/khanghunhnguyntrng/football-players-transfer-fee-prediction-dataset/data'
# But they collected the data from different leagues, which are:
# 11 European leagues, including the Premier League and Championship in England, Bundesliga in Germany, La Liga in Spain, Serie A in Italy, Ligue 1 in France, Eredivisie in the Netherlands, Liga NOS in Portugal, Premier Liga in Russia, Super Lig in Turkey, and Bundesliga in Austria.
#
# 4 American leagues, including Brasileiro in Brazil, Major League Soccer in the United States, Primera División in Argentina, and Liga MX in Mexico.
#
# 1 African league, namely the DStv Premiership in South Africa.
#
# 4 Asian leagues, comprising J-League in Japan, Saudi Pro League in Saudi Arabia, K-League 1 in South Korea, and A-League in Australia.

# %% [markdown]
# #### 2. Timeliness:
# Ensure the data is up-to-date and reflective of the current situation or the period of interest for the analysis.

# %% [raw]
# According to the source "Kaggle" This dataset was generated by scraping data from Transfermarkt using Selenium and BeautifulSoup on June 10, 2023.
# It shows the performance of the players over two seasons
# It meets the time period we supposed work in

# %% [markdown]
# #### 3. Consistency:
#
# Confirm that the data is consistent within the dataset and across multiple data sources. For example, the same data point should not have different values in different places.

# %% [raw]
# Only one dataset so it's consistent

# %% [markdown]
# #### 4. Relevance:

# %% [raw]
# 1. Sample Relevance: The dataset represents players from various top leagues across different continents, capturing diverse market trends and transfer dynamics for better model accuracy.
# 2. Variable Relevance: It covers key factors influencing transfer value, such as age, height, position, goals, assists, injuries, and awards, which directly impact a player's market worth.

# %% [markdown]
# #### 5. Uniqueness:
# Check for and remove duplicate records to prevent skewed analysis results.

# %%
football_df.duplicated().sum()
# Out:
# 0

# %%
# I think all the values may be duplicated unless the whole row is identical it can't be duplicated
football_df.columns
# Out:
# Index(['player', 'team', 'name', 'position', 'height', 'age', 'appearance',
#        'goals', 'assists', 'yellow cards', 'second yellow cards', 'red cards',
#        'goals conceded', 'clean sheets', 'minutes played', 'days_injured',
#        'games_injured', 'award', 'current_value', 'highest_value',
#        'position_encoded', 'winger'],
#       dtype='object')

# %%
# go to delete duplicates columns

# %% [markdown]
# #### 6. Completeness:
# Ensure that no critical data is missing. This might mean checking for null values or required fields that are empty.
#
# We will start by checking the dataset for missing or null values. For this, we can use the isna() method which returns a dataframe of boolean values indicating if a field is null or not. To group all missing values by column, we can include the sum() method.

# %%
football_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10754 entries, 0 to 10753
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   player               10754 non-null  object
#  1   team                 10754 non-null  object
#  2   name                 10754 non-null  object
#  3   position             10754 non-null  object
#  4   height               10754 non-null  float64
#  5   age                  10754 non-null  float64
#  6   appearance           10754 non-null  int64
#  7   goals                10754 non-null  float64
#  8   assists              10754 non-null  float64
#  9   yellow cards         10754 non-null  float64
#  10  second yellow cards  10754 non-null  float64
#  11  red cards            10754 non-null  float64
#  12  goals conceded       10754 non-null  float64
#  13  clean sheets         10754 non-null  float64
#  14  minutes played       10754 non-null  int64
#  15  days_injured         10754 non-null  int64
#  16  games_injured        10754 non-null  int64
#  17  award                10754 non-null  int64
#  18  current_value        10754 non-null  int64
#  19  highest_value        10754 non-null  int64
#  20  position_encoded     10754 non-null  int64
#  21  winger               10754 non-null  int64
# dtypes: float64(9), int64(9), object(4)
# memory usage: 1.8+ MB

# %%
# NO missing values

# %%
# go to clean them

# %% [markdown]
# #### 7. Check Accuracy:
#
# Verify that the data is correct and precise. This could involve comparing data samples with known sources or using validation rules.
#
# **The process includes:**
# 1. Validating the appropriateness of data types for the dataset.
# 2. Identifying outliers  using established validation  rule

# %%
football_df.dtypes
# Out:
# player                  object
# team                    object
# name                    object
# position                object
# height                 float64
# age                    float64
# appearance               int64
# goals                  float64
# assists                float64
# yellow cards           float64
# second yellow cards    float64
# red cards              float64
# goals conceded         float64
# clean sheets           float64
# minutes played           int64
# days_injured             int64
# games_injured            int64
# award                    int64
# current_value            int64
# highest_value            int64
# position_encoded         int64
# winger                   int64
# dtype: object

# %%
# The data type of each column suits their logical meaning

# %% [markdown]
# ## 2. Data Cleaning:
#
# Preliminary findings from data profiling can lead to cleaning the data by:
# - Handling missing values
# - Correcting errors.
# - Dealing with outliers.
#
# -------------------

# %% [markdown]
# ### Correcting errors
#
# -------------------

# %%
# go back to 7th dimension Accuracy

# %% [markdown]
# ##### Dealing with outliers:

# %% [markdown]
# **How to remove Outliers?**
# Most of the ways to deal with outliers are similar to the methods of missing values like deleting rows, transforming them, binning them, treat them as a separate group, imputing values and other statistical methods. Here, we will discuss the common techniques used to deal with outliers:
#
# 1. Deleting rows: We delete outlier values if it is due to data entry error, data processing error or outlier rows are very small in numbers. We can also use trimming at both ends to remove outliers.
#
# 2. Imputing: Like imputation of missing values, we can also impute outliers. We can use mean, median, mode imputation methods. Before imputing values, we should analyse if it is natural outlier or artificial. If it is artificial, we can go with imputing values. We can also use statistical model to predict values of outlier rows and after that we can impute it with predicted values.
#
# 3. Treat separately: If there are significant number of outliers, we should treat them separately in the statistical model. One of the approach is to treat both groups as two different groups and build individual model for both groups and then combine the output.

# %% [markdown]
# ##### football_df - age column's outliers

# %%
filtered_age = football_df[(football_df["age"] >= 16) &(football_df["age"] <= 39)]

plt.figure(figsize=(10, 6))
plt.hist(filtered_age["age"], bins=15, color="navy", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Age", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Players' Age (17 =< Age <= 39)", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
# I tried multiple values and I saw that this gave the most normal distribution

# %%
filtered_age.shape
# Out:
# (10689, 22)

# %%
football_df.shape
# Out:
# (10728, 22)

# %%
# Droping the outliers
football_df=football_df[(football_df["age"] >= 16) &(football_df["age"] <= 39)]

# %%
football_df.shape
# Out:
# (10689, 22)

# %% [markdown]
# ##### football_df - height column's outliers

# %%
zscore(football_df['height'])

football_df['height_z_score'] = zscore(football_df['height'])

football_df[(football_df['height_z_score'] > 2.9) | (football_df['height_z_score']< -2.9)].sort_values(by='height')
# Out:
#                                                   player  \
# 7563               /nahuel-barrios/profil/spieler/503377
# 8288                  /maxi-moralez/profil/spieler/30687
# 6894             /steven-sserwadda/profil/spieler/568840
# 10258             /kajally-drammeh/profil/spieler/863824
# 9341     /al-mutasim-sediq-hassan/profil/spieler/1057847
# 9019            /sumaihan-al-nabit/profil/spieler/478531
# 8647               /taichi-kikuchi/profil/spieler/683325
# 8472            /teruhito-nakagawa/profil/spieler/345326
# 8143              /braian-martinez/profil/spieler/739995
# 8085                 /mariano-mino/profil/spieler/538092
# 6725               /luciano-acosta/profil/spieler/315169
# 10612               /joshua-nisbet/profil/spieler/603863
# 5951                /erhun-oztumer/profil/spieler/326843
# 4625               /edgar-alaffita/profil/spieler/264104
# 4402             /misael-dominguez/profil/spieler/451221
# 3236             /yeferson-soteldo/profil/spieler/312294
# 10285     /ndabayithethwa-ndlondlo/profil/spieler/636981
# 8601            /katsuki-nishimura/profil/spieler/914625
# 8610                 /kazuya-konno/profil/spieler/654348
# 6884               /matthew-nocita/profil/spieler/972457
# 5031                 /stefan-sapic/profil/spieler/429243
# 3039              /andries-noppert/profil/spieler/276853
# 9472                 /fejsal-mulic/profil/spieler/226194
# 6394          /pape-alioune-ndiaye/profil/spieler/433219
# 1656   /vanja-milinkovi%C4%87-savi%C4%87/profil/spiel...
# 3770                /carlos-miguel/profil/spieler/641458
# 2700               /kjell-scherpen/profil/spieler/463527
# 2439                  /isaak-toure/profil/spieler/708678
#
#                                   team                     name  \
# 7563         CA San Lorenzo de Almagro           Nahuel Barrios
# 8288                       Racing Club             Maxi Moralez
# 6894                New York Red Bulls         Steven Sserwadda
# 10258                Cape Town City FC          Kajally Drammeh
# 9341          Al-Ittihad Club (Jeddah)  Al-Mutasim Sediq Hassan
# 9019                     Al-Taawoun FC        Sumaihan Al-Nabit
# 8647                        Sagan Tosu           Taichi Kikuchi
# 8472                          FC Tokyo        Teruhito Nakagawa
# 8143                  CA Independiente          Braian Martínez
# 8085            Club Atlético Belgrano             Mariano Miño
# 6725                     FC Cincinnati           Luciano Acosta
# 10612           Central Coast Mariners            Joshua Nisbet
# 5951                   Adana Demirspor            Erhun Öztümer
# 4625                        UNAM Pumas           Édgar Alaffita
# 4402                      Club Tijuana         Misael Domínguez
# 3236                         Santos FC         Yeferson Soteldo
# 10285                  Orlando Pirates  Ndabayithethwa Ndlondlo
# 8601                    Avispa Fukuoka        Katsuki Nishimura
# 8610                    Avispa Fukuoka             Kazuya Konno
# 6884                New York Red Bulls           Matthew Nocita
# 5031                    Torpedo Moscow             Stefan Sapic
# 3039                     SC Heerenveen          Andries Noppert
# 9472           Suwon Samsung Bluewings             Fejsal Mulic
# 6394                        SCR Altach      Pape-Alioune Ndiaye
# 1656                         Torino FC   Vanja Milinković-Savić
# 3770   Sport Club Corinthians Paulista            Carlos Miguel
# 2700                    Vitesse Arnhem           Kjell Scherpen
# 2439                        AJ Auxerre              Isaak Touré
#
#                          position  height   age  appearance     goals  \
# 7563            Attack-LeftWinger   156.0  25.0           4  0.000000
# 8288   midfield-AttackingMidfield   159.0  36.0          17  0.205950
# 6894     midfield-CentralMidfield   160.0  20.0           0  0.000000
# 10258          Attack-RightWinger   160.0  19.0          19  0.130435
# 9341                       Attack   160.0  21.0           0  0.000000
# 9019            Attack-LeftWinger   160.0  27.0          63  0.231720
# 8647   midfield-AttackingMidfield   160.0  24.0          16  0.000000
# 8472           Attack-RightWinger   160.0  30.0          22  0.256959
# 8143            Attack-LeftWinger   160.0  23.0          10  0.000000
# 8085   midfield-AttackingMidfield   160.0  29.0           3  0.000000
# 6725   midfield-AttackingMidfield   160.0  29.0          16  0.576461
# 10612  midfield-DefensiveMidfield   160.0  23.0          56  0.061728
# 5951   midfield-AttackingMidfield   160.0  32.0          38  0.324519
# 4625     midfield-CentralMidfield   160.0  26.0          61  0.106846
# 4402   midfield-AttackingMidfield   160.0  23.0          29  0.000000
# 3236            Attack-LeftWinger   160.0  25.0          24  0.094937
# 10285  midfield-AttackingMidfield   161.0  28.0          63  0.214844
# 8601                     midfield   161.0  18.0           2  0.000000
# 8610           Attack-RightWinger   161.0  25.0          14  0.078125
# 6884         Defender Centre-Back   202.0  23.0           3  0.000000
# 5031         Defender Centre-Back   202.0  26.0          45  0.049628
# 3039                   Goalkeeper   202.0  29.0          40  0.000000
# 9472        Attack Centre-Forward   202.0  28.0           7  0.300000
# 6394         Defender Centre-Back   202.0  25.0          39  0.000000
# 1656                   Goalkeeper   202.0  26.0          70  0.000000
# 3770                   Goalkeeper   204.0  24.0           0  0.000000
# 2700                   Goalkeeper   206.0  23.0          39  0.000000
# 2439         Defender Centre-Back   206.0  20.0          42  0.032597
#
#         assists  yellow cards  ...  clean sheets  minutes played  \
# 7563   0.283912      0.000000  ...      0.000000             317
# 8288   0.308924      0.308924  ...      0.000000             874
# 6894   0.000000      0.000000  ...      0.000000               0
# 10258  0.000000      0.130435  ...      0.000000             690
# 9341   0.000000      0.000000  ...      0.000000               0
# 9019   0.092688      0.301236  ...      0.000000            3884
# 8647   0.000000      0.000000  ...      0.000000            1166
# 8472   0.192719      0.128480  ...      0.000000            1401
# 8143   0.171103      0.171103  ...      0.000000             526
# 8085   0.000000      0.000000  ...      0.000000              23
# 6725   0.144115      0.288231  ...      0.000000            1249
# 10612  0.041152      0.041152  ...      0.000000            4374
# 5951   0.162260      0.162260  ...      0.000000            1664
# 4625   0.089038      0.089038  ...      0.000000            5054
# 4402   0.096257      0.096257  ...      0.000000             935
# 3236   0.284810      0.094937  ...      0.000000             948
# 10285  0.019531      0.136719  ...      0.000000            4608
# 8601   0.000000      0.000000  ...      0.000000              90
# 8610   0.156250      0.000000  ...      0.000000            1152
# 6884   0.000000      0.407240  ...      0.000000             221
# 5031   0.000000      0.248139  ...      0.000000            3627
# 3039   0.000000      0.025000  ...      0.375000            3600
# 9472   0.000000      0.300000  ...      0.000000             300
# 6394   0.000000      0.206287  ...      0.000000            3054
# 1656   0.000000      0.113208  ...      0.268868            6360
# 3770   0.000000      0.000000  ...      0.000000               0
# 2700   0.000000      0.000000  ...      0.283424            3493
# 2439   0.000000      0.260775  ...      0.000000            2761
#
#        days_injured  games_injured  award  current_value  highest_value  \
# 7563             13              2      0        3500000        3500000
# 8288            137             25      3         400000        6000000
# 6894              0              0      0         200000         200000
# 10258             0              0      0         250000         250000
# 9341              0              0      1          25000          25000
# 9019              0              0      0        1200000        1200000
# 8647              0              0      0         400000         400000
# 8472            176             25      6        1400000        2800000
# 8143              0              0      0         400000         425000
# 8085            225             20      1         350000         425000
# 6725             42              5      0        4500000        6000000
# 10612             0              0      1         400000         400000
# 5951              0              0      0         150000         750000
# 4625              0              0      0         600000         600000
# 4402             22              2      5         300000         600000
# 3236            157             21      0        6000000       10000000
# 10285             0              0      1         750000         750000
# 8601              0              0      0              0              0
# 8610            218             43      1         400000         400000
# 6884              0              0      0         100000         100000
# 5031              0              0      0         500000        1600000
# 3039            507             27      0        5000000        5000000
# 9472            205             24      0         700000         750000
# 6394             20              2      0         250000         900000
# 1656             63             15      2        3500000        4500000
# 3770              0              0      0        1000000        1000000
# 2700             78              9      2        2000000        2800000
# 2439            129              1      0        5000000        5000000
#
#        position_encoded  winger  height_z_score
# 7563                  4       1       -3.621619
# 8288                  3       0       -3.190831
# 6894                  3       0       -3.047235
# 10258                 4       1       -3.047235
# 9341                  4       0       -3.047235
# 9019                  4       1       -3.047235
# 8647                  3       0       -3.047235
# 8472                  4       1       -3.047235
# 8143                  4       1       -3.047235
# 8085                  3       0       -3.047235
# 6725                  3       0       -3.047235
# 10612                 3       0       -3.047235
# 5951                  3       0       -3.047235
# 4625                  3       0       -3.047235
# 4402                  3       0       -3.047235
# 3236                  4       1       -3.047235
# 10285                 3       0       -2.903639
# 8601                  3       0       -2.903639
# 8610                  4       1       -2.903639
# 6884                  2       0        2.983793
# 5031                  2       0        2.983793
# 3039                  1       0        2.983793
# 9472                  4       0        2.983793
# 6394                  2       0        2.983793
# 1656                  1       0        2.983793
# 3770                  1       0        3.270984
# 2700                  1       0        3.558176
# 2439                  2       0        3.558176
#
# [28 rows x 23 columns]

# %%
# Filter data
filtered_height = football_df[(football_df["height"] > 161) & (football_df["height"] < 202)]

# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(filtered_height["height"], bins=15, color="navy", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Height (cm)", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Players' Height (160 cm < Height < 204 cm)", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
# The chart looks pretty normally distributed after excluding these values so I will drop them
football_df=football_df[(football_df["height"] > 161) & (football_df["height"] < 202)]

# %%
football_df.shape
# Out:
# (10661, 23)

# %% [markdown]
# ##### football_df - days_injuref column's outliers

# %%
zscore(football_df['days_injured'])

football_df['days_injured_z_score'] = zscore(football_df['days_injured'])
# The column didnt show up so I wanted to know where did it start
football_df[(football_df['days_injured_z_score'] > 3.5) | (football_df['days_injured_z_score']< -3)].sort_values(by='days_injured')['days_injured'].min()
# Out:
# 732

# %%
indexs=football_df[(football_df['days_injured_z_score'] > 3.5) | (football_df['days_injured_z_score']< -3)].sort_values(by='days_injured').index
football_df.drop(indexs,inplace=True)

# %%
football_df.shape
# Out:
# (10539, 24)

# %% [markdown]
# ##### football_df - games_injured columns outliers

# %%
# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(football_df["games_injured"], bins=15, color="red", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Games Injured", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Games Injured", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
filtered_games=football_df[football_df["games_injured"]<90]
# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(filtered_games["games_injured"], bins=15, color="red", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Games Injured", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Games Injured", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
# Well obviously the chart won't help so I'll try zscore

# %%
zscore(football_df['games_injured'])

football_df['games_injured_z_score'] = zscore(football_df['games_injured'])

football_df[(football_df['games_injured_z_score'] > 3.5) | (football_df['games_injured_z_score']< -3.5)].sort_values(by='games_injured')
# Out:
#                                           player                 team  \
# 3115        /justin-bijlow/profil/spieler/315121  Feyenoord Rotterdam
# 37          /angelo-ogbonna/profil/spieler/48002      West Ham United
# 10563       /daniel-arzani/profil/spieler/399997         Macarthur FC
# 1619   /giacomo-bonaventura/profil/spieler/57280       ACF Fiorentina
# 1317       /clement-grenier/profil/spieler/72479         RCD Mallorca
# ...                                          ...                  ...
# 355            /rico-henry/profil/spieler/339556         Brentford FC
# 8291   /maximiliano-romero/profil/spieler/365758          Racing Club
# 440        /benjamin-mendy/profil/spieler/157495      Manchester City
# 783          /tolga-cigerci/profil/spieler/94199           Hertha BSC
# 5745        /jack-robinson/profil/spieler/128909     Sheffield United
#
#                       name                    position  height   age  \
# 3115         Justin Bijlow                  Goalkeeper   188.0  25.0
# 37          Angelo Ogbonna        Defender Centre-Back   191.0  35.0
# 10563        Daniel Arzani           Attack-LeftWinger   175.0  24.0
# 1619   Giacomo Bonaventura    midfield-CentralMidfield   180.0  33.0
# 1317       Clément Grenier    midfield-CentralMidfield   186.0  32.0
# ...                    ...                         ...     ...   ...
# 355             Rico Henry          Defender Left-Back   170.0  25.0
# 8291    Maximiliano Romero       Attack Centre-Forward   180.0  24.0
# 440         Benjamin Mendy          Defender Left-Back   185.0  28.0
# 783          Tolga Cigerci  midfield-DefensiveMidfield   185.0  31.0
# 5745         Jack Robinson          Defender Left-Back   180.0  29.0
#
#        appearance     goals   assists  yellow cards  ...  days_injured  \
# 3115           69  0.000000  0.000000      0.014375  ...           560
# 37             42  0.027060  0.000000      0.108238  ...           664
# 10563          39  0.201162  0.321860      0.362092  ...           524
# 1619           84  0.171221  0.233483      0.202352  ...           535
# 1317           29  0.185950  0.000000      0.743802  ...           587
# ...           ...       ...       ...           ...  ...           ...
# 355            76  0.043028  0.028685      0.086056  ...           608
# 8291           37  0.336000  0.240000      0.000000  ...           726
# 440             2  0.000000  0.000000      0.000000  ...           696
# 783            60  0.057545  0.095908      0.268542  ...           591
# 5745           64  0.100784  0.033595      0.218365  ...           687
#
#        games_injured  award  current_value  highest_value  position_encoded  \
# 3115              87      5       13000000       13000000                 1
# 37                87      5        1000000       13000000                 2
# 10563             87      3         450000        1500000                 4
# 1619              87      2        2500000       24000000                 3
# 1317              87      4         800000       12000000                 3
# ...              ...    ...            ...            ...               ...
# 355              117      0       22000000       22000000                 2
# 8291             120      3        2800000        7500000                 4
# 440              121     13              0       45000000                 2
# 783              139      3        1500000        4500000                 3
# 5745             140      1         700000        2500000                 2
#
#        winger  height_z_score  days_injured_z_score  games_injured_z_score
# 3115        0        0.973450              2.526006               3.514056
# 37          0        1.404238              3.119964               3.514056
# 10563       1       -0.893297              2.320405               3.514056
# 1619        0       -0.175317              2.383227               3.514056
# 1317        0        0.686258              2.680207               3.514056
# ...       ...             ...                   ...                    ...
# 355         1       -1.611276              2.800141               4.971301
# 8291        0       -0.175317              3.474055               5.117026
# 440         1        0.542662              3.302721               5.165601
# 783         0        0.542662              2.703051               6.039948
# 5745        1       -0.175317              3.251320               6.088523
#
# [91 rows x 25 columns]

# %%
# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(football_df["games_injured_z_score"], bins=15, color="purple", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Z-score of Games Injured", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Games Injured (Z-score)", fontsize=14)
plt.axvline(0, color='red', linestyle='dashed', linewidth=2, label="Mean (0)")
plt.axvline(3.5, color='green', linestyle='dashed', linewidth=2, label="Upper Outlier Threshold (+3.5)")
plt.axvline(-3.5, color='orange', linestyle='dashed', linewidth=2, label="Lower Outlier Threshold (-3.5)")
plt.legend()
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
indexs=football_df[(football_df['games_injured_z_score'] > 3.5) | (football_df['games_injured_z_score']< -3.5)].sort_values(by='days_injured').index
football_df.drop(indexs,inplace=True)

# %%
football_df.shape
# Out:
# (10448, 25)

# %% [markdown]
# ##### football_df - award column's outliers

# %%
plt.figure(figsize=(12, 6))
plt.hist(football_df["award"], bins=10, color="gold", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Number of Awards", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Awards Won by Players", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
filter_award=football_df[football_df["award"]<20]
# Plot histogram
plt.figure(figsize=(12, 6))
plt.hist(filter_award["award"], bins=10, color="gold", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Number of Awards", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Awards Won by Players", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
filter_award.shape
# Out:
# (10392, 25)

# %%
football_df.shape
# Out:
# (10448, 25)

# %%
# Feels like the tail is never ending I'll try zscore

# %%
zscore(football_df['award'])

football_df['award_z_score'] = zscore(football_df['award'])

football_df[(football_df['award_z_score'] > 3.5) | (football_df['award_z_score']< -3.5)].sort_values(by='award')
# Out:
#                                         player  \
# 4080         /nico-gaitan/profil/spieler/75442
# 3296         /felipe-melo/profil/spieler/35537
# 3786            /paulinho/profil/spieler/57229
# 945         /niklas-sule/profil/spieler/166601
# 3817               /pizzi/profil/spieler/64339
# ...                                        ...
# 1507         /david-alaba/profil/spieler/59016
# 1525       /karim-benzema/profil/spieler/18922
# 1549  /robert-lewandowski/profil/spieler/38253
# 9433    /cristiano-ronaldo/profil/spieler/8198
# 2643        /lionel-messi/profil/spieler/28003
#
#                                  team                name  \
# 4080             FC Paços de Ferreira         Nico Gaitán
# 3296         Fluminense Football Club         Felipe Melo
# 3786  Sport Club Corinthians Paulista            Paulinho
# 945                 Borussia Dortmund         Niklas Süle
# 3817                         SC Braga               Pizzi
# ...                               ...                 ...
# 1507                      Real Madrid         David Alaba
# 1525                      Real Madrid       Karim Benzema
# 1549                     FC Barcelona  Robert Lewandowski
# 9433                      Al-Nassr FC   Cristiano Ronaldo
# 2643              Paris Saint-Germain        Lionel Messi
#
#                         position  height   age  appearance     goals  \
# 4080  midfield-AttackingMidfield   174.0  35.0          35  0.198151
# 3296  midfield-DefensiveMidfield   183.0  39.0           4  0.000000
# 3786    midfield-CentralMidfield   183.0  34.0           8  0.450000
# 945         Defender Centre-Back   195.0  27.0          79  0.048043
# 3817  midfield-AttackingMidfield   177.0  33.0          77  0.252809
# ...                          ...     ...   ...         ...       ...
# 1507        Defender Centre-Back   180.0  30.0          85  0.063649
# 1525       Attack Centre-Forward   185.0  35.0          89  0.894040
# 1549       Attack Centre-Forward   185.0  34.0          92  0.938442
# 9433       Attack Centre-Forward   187.0  38.0          74  0.617780
# 2643          Attack-RightWinger   170.0  35.0          75  0.442464
#
#        assists  yellow cards  ...  games_injured  award  current_value  \
# 4080  0.158520      0.118890  ...             54     15         300000
# 3296  0.000000      0.649819  ...             40     15         150000
# 3786  0.000000      0.225000  ...             57     15        1200000
# 945   0.096085      0.112100  ...             53     15       35000000
# 3817  0.347612      0.158006  ...              4     15        3000000
# ...        ...           ...  ...            ...    ...            ...
# 1507  0.089109      0.101839  ...             26     43       40000000
# 1525  0.250331      0.023841  ...             26     53       25000000
# 1549  0.169598      0.067839  ...             22     65       30000000
# 9433  0.105475      0.256153  ...             27     90       15000000
# 2643  0.483945      0.013827  ...             30     92       45000000
#
#       highest_value  position_encoded  winger  height_z_score  \
# 4080       30000000                 3       0       -1.036893
# 3296       19000000                 3       0        0.255470
# 3786       40000000                 3       0        0.255470
# 945        60000000                 2       0        1.978621
# 3817       27000000                 3       0       -0.606105
# ...             ...               ...     ...             ...
# 1507       65000000                 2       0       -0.175317
# 1525       60000000                 4       0        0.542662
# 1549       90000000                 4       0        0.542662
# 9433      120000000                 4       0        0.829854
# 2643      180000000                 4       1       -1.611276
#
#       days_injured_z_score  games_injured_z_score  award_z_score
# 4080              1.081088               1.911086       3.621177
# 3296              0.407174               1.231038       3.621177
# 3786              0.904043               2.056810       3.621177
# 945               1.383778               1.862511       3.621177
# 3817             -0.495186              -0.517657       3.621177
# ...                    ...                    ...            ...
# 1507              0.030239               0.550990      11.351598
# 1525              0.218706               0.550990      14.112463
# 1549              0.121617               0.356690      17.425500
# 9433              0.287240               0.599565      24.327661
# 2643              0.281529               0.745289      24.879834
#
# [126 rows x 26 columns]

# %%
# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(football_df["award_z_score"], bins=15, color="gold", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Z-score of Awards", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Awards (Z-score)", fontsize=14)
plt.axvline(0, color='red', linestyle='dashed', linewidth=2, label="Mean (0)")
plt.axvline(3.5, color='green', linestyle='dashed', linewidth=2, label="Upper Outlier Threshold (+3.5)")
plt.axvline(-3.5, color='orange', linestyle='dashed', linewidth=2, label="Lower Outlier Threshold (-3.5)")
plt.legend()
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
# I think the best decision is to drop values above 20 because excluding more values will affect the results causing misleading

# %%
football_df.drop(columns=["award_z_score"],inplace=True)

# %% [markdown]
# ##### football_df - current_value column's outliers

# %%
# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(football_df["current_value"], bins=15, color="blue", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Current Value", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Players' Current Value", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
# The chart doesn't give a detailed information

# %%
zscore(football_df['current_value'])

football_df['current_value_z_score'] = zscore(football_df['current_value'])

football_df[(football_df['current_value_z_score'] > 3) | (football_df['current_value_z_score']< -3)].sort_values(by='current_value')
# Out:
#                                          player                 team  \
# 977       /edmond-tapsoba/profil/spieler/564545  Bayer 04 Leverkusen
# 437      /aymeric-laporte/profil/spieler/176553      Manchester City
# 1147        /oihan-sancet/profil/spieler/571020      Athletic Bilbao
# 236   /morgan-gibbs-white/profil/spieler/429014    Nottingham Forest
# 237      /brennan-johnson/profil/spieler/470607    Nottingham Forest
# ...                                         ...                  ...
# 474          /bukayo-saka/profil/spieler/433177           Arsenal FC
# 1017       /jamal-musiala/profil/spieler/580195        Bayern Munich
# 960      /jude-bellingham/profil/spieler/581678    Borussia Dortmund
# 453       /erling-haaland/profil/spieler/418560      Manchester City
# 2644       /kylian-mbappe/profil/spieler/342229  Paris Saint-Germain
#
#                     name                    position  height   age  \
# 977       Edmond Tapsoba        Defender Centre-Back   194.0  24.0
# 437      Aymeric Laporte        Defender Centre-Back   189.0  29.0
# 1147        Oihan Sancet  midfield-AttackingMidfield   188.0  23.0
# 236   Morgan Gibbs-White  midfield-AttackingMidfield   178.0  23.0
# 237      Brennan Johnson  midfield-AttackingMidfield   179.0  22.0
# ...                  ...                         ...     ...   ...
# 474          Bukayo Saka          Attack-RightWinger   178.0  21.0
# 1017       Jamal Musiala  midfield-AttackingMidfield   184.0  20.0
# 960      Jude Bellingham    midfield-CentralMidfield   186.0  19.0
# 453       Erling Haaland       Attack Centre-Forward   195.0  22.0
# 2644       Kylian Mbappé       Attack Centre-Forward   178.0  24.0
#
#       appearance     goals   assists  yellow cards  ...  games_injured  award  \
# 977           76  0.042587  0.028391      0.127760  ...             14      0
# 437           68  0.064080  0.016020      0.128159  ...             83     15
# 1147          74  0.312839  0.117315      0.195525  ...             37      1
# 236           80  0.248695  0.248695      0.179613  ...             35      2
# 237           97  0.331766  0.137282      0.114402  ...              0      0
# ...          ...       ...       ...           ...  ...            ...    ...
# 474           91  0.342109  0.228073      0.164719  ...              2      2
# 1017          87  0.431655  0.395683      0.071942  ...              6     11
# 960           86  0.244798  0.257038      0.269278  ...              4      2
# 453           83  1.118270  0.234699      0.124252  ...             36     17
# 2644          89  0.963082  0.433387      0.204655  ...             23     37
#
#       current_value  highest_value  position_encoded  winger  height_z_score  \
# 977        30000000       40000000                 2       0        1.835025
# 437        30000000       75000000                 2       0        1.117046
# 1147       30000000       30000000                 3       0        0.973450
# 236        30000000       30000000                 3       0       -0.462509
# 237        30000000       30000000                 3       0       -0.318913
# ...             ...            ...               ...     ...             ...
# 474       110000000      110000000                 4       1       -0.462509
# 1017      110000000      110000000                 3       0        0.399066
# 960       120000000      120000000                 3       0        0.686258
# 453       170000000      170000000                 4       0        1.978621
# 2644      180000000      200000000                 4       0       -0.462509
#
#       days_injured_z_score  games_injured_z_score  current_value_z_score
# 977              -0.061139              -0.031909               3.047042
# 437               2.714473               3.319756               3.047042
# 1147              0.824087               1.085313               3.047042
# 236               0.772687               0.988163               3.047042
# 237              -0.672231              -0.711956               3.047042
# ...                    ...                    ...                    ...
# 474              -0.518030              -0.614807              12.254288
# 1017             -0.295296              -0.420507              12.254288
# 960              -0.563719              -0.517657              13.405194
# 453               0.492841               1.036738              19.159723
# 2644              0.121617               0.405265              20.310628
#
# [230 rows x 26 columns]

# %%
# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(football_df["current_value_z_score"], bins=15, color="blue", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Z-score of Current Value", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Players' Current Value (Z-score)", fontsize=14)
plt.axvline(0, color='red', linestyle='dashed', linewidth=2, label="Mean (0)")
plt.axvline(3, color='green', linestyle='dashed', linewidth=2, label="Upper Outlier Threshold (+3)")
plt.axvline(-3, color='orange', linestyle='dashed', linewidth=2, label="Lower Outlier Threshold (-3)")
plt.legend()
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
indexs=football_df[(football_df['current_value_z_score'] > 3) | (football_df['current_value_z_score']< -3)].index
football_df.drop(indexs,inplace=True)

# %%
football_df.shape
# Out:
# (10218, 26)

# %% [markdown]
# ##### football_df - current_value column's outliers

# %%
# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(football_df["highest_value"], bins=15, color="green", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Highest Value", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Players' Highest Value", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
zscore(football_df['highest_value'])

football_df['highest_value_z_score'] = zscore(football_df['highest_value'])

football_df[(football_df['highest_value_z_score'] > 4) | (football_df['highest_value_z_score']< -4)].sort_values(by='highest_value')
# Out:
#                                         player                team  \
# 17      /marcel-sabitzer/profil/spieler/106987   Manchester United
# 963      /giovanni-reyna/profil/spieler/504215   Borussia Dortmund
# 6321           /juan-mata/profil/spieler/44068         Galatasaray
# 2529      /jerome-boateng/profil/spieler/26485      Olympique Lyon
# 3109     /thorgan-hazard/profil/spieler/102226       PSV Eindhoven
# ...                                        ...                 ...
# 16     /christian-eriksen/profil/spieler/69633   Manchester United
# 5864          /dele-alli/profil/spieler/207929         Besiktas JK
# 9433    /cristiano-ronaldo/profil/spieler/8198         Al-Nassr FC
# 1501  /antoine-griezmann/profil/spieler/125781  Atlético de Madrid
# 1522         /eden-hazard/profil/spieler/50202         Real Madrid
#
#                    name                    position  height   age  appearance  \
# 17      Marcel Sabitzer    midfield-CentralMidfield   177.0  29.0          74
# 963      Giovanni Reyna  midfield-AttackingMidfield   185.0  20.0          43
# 6321          Juan Mata  midfield-AttackingMidfield   170.0  35.0          30
# 2529     Jérôme Boateng        Defender Centre-Back   192.0  34.0          35
# 3109     Thorgan Hazard           Attack-LeftWinger   175.0  30.0          64
# ...                 ...                         ...     ...   ...         ...
# 16    Christian Eriksen    midfield-CentralMidfield   182.0  31.0          55
# 5864          Dele Alli  midfield-AttackingMidfield   188.0  27.0          46
# 9433  Cristiano Ronaldo       Attack Centre-Forward   187.0  38.0          74
# 1501  Antoine Griezmann        Attack-SecondStriker   176.0  32.0          87
# 1522        Eden Hazard           Attack-LeftWinger   175.0  32.0          33
#
#          goals   assists  yellow cards  ...  award  current_value  \
# 17    0.144046  0.086428      0.230474  ...      8       20000000
# 963   0.487658  0.325105      0.108368  ...      2       28000000
# 6321  0.299667  0.199778      0.099889  ...     14        1000000
# 2529  0.000000  0.079858      0.319432  ...     30        1000000
# 3109  0.293585  0.065241      0.163103  ...      4        9000000
# ...        ...       ...           ...  ...    ...            ...
# 16    0.067214  0.313667      0.089619  ...     10       25000000
# 5864  0.200983  0.040197      0.200983  ...      0        8000000
# 9433  0.617780  0.105475      0.256153  ...     90       15000000
# 1501  0.351391  0.380673      0.087848  ...     11       25000000
# 1522  0.138996  0.277992      0.138996  ...     19        5000000
#
#       highest_value  position_encoded  winger  height_z_score  \
# 17         42000000                 3       0       -0.606105
# 963        42000000                 3       0        0.542662
# 6321       45000000                 3       0       -1.611276
# 2529       45000000                 2       0        1.547834
# 3109       45000000                 4       1       -0.893297
# ...             ...               ...     ...             ...
# 16        100000000                 3       0        0.111875
# 5864      100000000                 3       0        0.973450
# 9433      120000000                 4       0        0.829854
# 1501      150000000                 4       0       -0.749701
# 1522      150000000                 4       1       -0.893297
#
#       days_injured_z_score  games_injured_z_score  current_value_z_score  \
# 17                0.926887               0.988163               1.896137
# 963               1.121066               1.473912               2.816861
# 6321             -0.129673               0.453840              -0.290584
# 2529              0.475708               0.356690              -0.290584
# 3109              1.252422               2.202535               0.630140
# ...                    ...                    ...                    ...
# 16               -0.672231              -0.711956               2.471590
# 5864              1.406623               2.493984               0.515050
# 9433              0.287240               0.599565               1.320684
# 1501             -0.055428               0.162391               2.471590
# 1522              1.612224               2.153960               0.169778
#
#       highest_value_z_score
# 17                 4.122026
# 963                4.122026
# 6321               4.453441
# 2529               4.453441
# 3109               4.453441
# ...                     ...
# 16                10.529385
# 5864              10.529385
# 9433              12.738819
# 1501              16.052970
# 1522              16.052970
#
# [109 rows x 27 columns]

# %%
# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(football_df["highest_value_z_score"], bins=15, color="green", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Z-score of Highest Value", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Players' Highest Value (Z-score)", fontsize=14)
plt.axvline(0, color='red', linestyle='dashed', linewidth=2, label="Mean (0)")
plt.axvline(4, color='green', linestyle='dashed', linewidth=2, label="Upper Outlier Threshold (+4)")
plt.axvline(-4, color='orange', linestyle='dashed', linewidth=2, label="Lower Outlier Threshold (-4)")
plt.legend()
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
indexs=football_df[(football_df['highest_value_z_score'] > 4) | (football_df['highest_value_z_score']< -4)].index
football_df.drop(indexs,inplace=True)

# %%
football_df.shape
# Out:
# (10109, 27)

# %% [markdown]
# ## 3. Univariate Analysis:

# %% [markdown]
# ### 1. Univariate Graphical Analysis:
# Method to perform uni-variate analysis will depend on whether the variable type is categorical or numerical.

# %% [markdown]
# #### I. Categorical Variables:
#
# we’ll use frequency table to understand distribution of each category
# - Bar Chart (Ordinal) - Orderd
# - Pie Chart (Nominal) - non Orderd

# %%
team_counts = football_df["team"].value_counts().head(10)  # استخراج أعلى 10 فرق

# رسم المخطط الشريطي
plt.figure(figsize=(10, 6))
team_counts.plot(kind="bar", color="#52796F")

# تخصيص المخطط
plt.xlabel("Team", fontsize=12)
plt.ylabel("How frequent it showed up", fontsize=12)
plt.title("Top 10 Teams ", fontsize=14)
plt.xticks(rotation=45)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# عرض المخطط
plt.show()

# %%
# I thought that maybe the top-showing teams would affect the player's value but none of these teams are well-known ones 
# So I thought the exact opposite thing is that maybe the players with high values don't change their teams frequently(?) *Neymar is a special case

# %%
position_counts = football_df["position"].value_counts()  # حساب تكرار كل مركز

# رسم المخطط الشريطي
plt.figure(figsize=(12, 6))
position_counts.plot(kind="bar", color="darkgreen")

# تخصيص المخطط
plt.xlabel("Position", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Player Distribution by Position", fontsize=14)
plt.xticks(rotation=45)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# عرض المخطط
plt.show()

# %%
# Defender Center-Back is the most showing position it's more by almost 500 than the nearest position in the list

# %% [markdown]
# #### II. Numerical Variables:
#
# we need to understand the central tendency and spread of the variable (Descriptive Analysis) using:
#    - Box plot
#    - Histogram

# %%
football_df.dtypes
# Out:
# player                  object
# team                    object
# name                    object
# position                object
# height                 float64
# age                    float64
# appearance               int64
# goals                  float64
# assists                float64
# yellow cards           float64
# second yellow cards    float64
# red cards              float64
# goals conceded         float64
# clean sheets           float64
# minutes played           int64
# days_injured             int64
# games_injured            int64
# award                    int64
# current_value            int64
# highest_value            int64
# position_encoded         int64
# winger                   int64
# dtype: object

# %%
# رسم الهيستوغرام لعمر اللاعبين
plt.figure(figsize=(10, 6))
plt.hist(football_df["age"], bins=15, color="navy", edgecolor="black", alpha=0.7)

# تخصيص المخطط
plt.xlabel("Age", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Players' Age", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# عرض المخطط
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(football_df["goals"], fill=True, color="royalblue", alpha=0.6)

plt.xlabel("Goals Scored", fontsize=12)
plt.ylabel("Density", fontsize=12)
plt.title("KDE Plot for Goals Scored", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

plt.show()

# %%
# Since  the values are super close to each other, it didn't  make any sense seeing this in an univariate chart

# %%
plt.figure(figsize=(10, 6))
plt.hist(football_df["appearance"], bins=15, color="navy", edgecolor="black", alpha=0.7)

# تخصيص المخطط
plt.xlabel("Appearance", fontsize=12)
plt.ylabel("Number of Appearances", fontsize=12)
plt.title("Distribution of Players' Appearance", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# عرض المخطط
plt.show()

# %%
plt.figure(figsize=(10, 6))
filtered_appearance=football_df[(football_df["appearance"]<=100)]
plt.hist(filtered_appearance["appearance"], bins=15, color="navy", edgecolor="black", alpha=0.7)

# تخصيص المخطط
plt.xlabel("Appearance", fontsize=12)
plt.ylabel("Number of Appearances", fontsize=12)
plt.title("Distribution of Players' Appearance", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# عرض المخطط
plt.show()

# %%
filtered_appearance.shape
# Out:
# (10728, 22)

# %%
# Droping outliers
football_df=football_df[(football_df["appearance"]<=100)]

# %%
# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(football_df["height"], bins=15, color="navy", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Height (cm)", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Players' Height", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %% [markdown]
# ### 2. Univariate Non-Graphical analysis:
#
# - Where is the center of the data? (location) --> **Measures of central tendency**
# - How much does the data vary? (scale) --> **Measure of variability**
# - What is the shape of the data? (shape) --> **Measures of variation combined with an average (measure of center) gives a good picture of the distribution of the data.**

# %%
football_df.describe().T
# Out:
#                        count          mean           std    min  \
# height               10728.0  1.812307e+02  6.965051e+00  156.0
# age                  10728.0  2.603800e+01  4.779052e+00   15.0
# appearance           10728.0  3.624478e+01  2.635270e+01    0.0
# goals                10728.0  1.253797e-01  2.356498e-01    0.0
# assists              10728.0  8.684641e-02  1.433912e-01    0.0
# yellow cards         10728.0  1.898608e-01  4.328825e-01    0.0
# second yellow cards  10728.0  4.676974e-03  2.526152e-02    0.0
# red cards            10728.0  6.837577e-03  8.124018e-02    0.0
# goals conceded       10728.0  1.315073e-01  4.424265e-01    0.0
# clean sheets         10728.0  4.480356e-02  9.255228e-01    0.0
# minutes played       10728.0  2.457240e+03  2.004548e+03    0.0
# days_injured         10728.0  1.179087e+02  1.752497e+02    0.0
# games_injured        10728.0  1.581618e+01  2.338656e+01    0.0
# award                10728.0  1.941648e+00  3.716803e+00    0.0
# current_value        10728.0  3.510666e+06  8.633915e+06    0.0
# highest_value        10728.0  6.011291e+06  1.295709e+07    0.0
# position_encoded     10728.0  2.713087e+00  9.861955e-01    1.0
# winger               10728.0  3.077927e-01  4.616018e-01    0.0
#
#                                25%           50%           75%           max
# height                  176.000000  1.812404e+02  1.860000e+02  2.060000e+02
# age                      22.000000  2.600000e+01  2.900000e+01  4.300000e+01
# appearance               12.000000  3.500000e+01  5.800000e+01  1.000000e+02
# goals                     0.000000  4.587156e-02  1.718237e-01  1.125000e+01
# assists                   0.000000  4.052229e-02  1.329394e-01  4.000000e+00
# yellow cards              0.053009  1.503251e-01  2.486188e-01  3.000000e+01
# second yellow cards       0.000000  0.000000e+00  0.000000e+00  1.000000e+00
# red cards                 0.000000  0.000000e+00  0.000000e+00  6.923077e+00
# goals conceded            0.000000  0.000000e+00  0.000000e+00  9.000000e+00
# clean sheets              0.000000  0.000000e+00  0.000000e+00  9.000000e+01
# minutes played          658.750000  2.084000e+03  3.953000e+03  8.970000e+03
# days_injured              0.000000  3.700000e+01  1.810000e+02  2.349000e+03
# games_injured             0.000000  5.000000e+00  2.400000e+01  3.390000e+02
# award                     0.000000  1.000000e+00  2.000000e+00  9.200000e+01
# current_value        300000.000000  8.000000e+05  2.800000e+06  1.800000e+08
# highest_value        450000.000000  1.500000e+06  5.000000e+06  2.000000e+08
# position_encoded          2.000000  3.000000e+00  4.000000e+00  4.000000e+00
# winger                    0.000000  0.000000e+00  1.000000e+00  1.000000e+00

# %% [markdown]
# ## 4. Bivariate/Multivariate Analysis:
#
# Here, you look at the relationships between two or more variables. This can involve looking for correlations, patterns, and trends that suggest a relationship or an association.
#
# We can perform bi-variate analysis for any combination of categorical and numerical variables. The combination can be:
# | bi-variate variables   | Plot type |
# | ------------- | ------------- |
# | Categorical & Categorical| Stacked Bar Chart |
# | Categorical & numerical  | scatter plot, histogram, box plot|
# | numerical  & numerical  | Scatter plot, line chart|
#
#
# Multivariate Analysis:
# - Heat map
# - Bar Chart
# - Scatter Chart
# - Line Chart

# %%
# تحديد الأعمدة العددية فقط
numeric_df = football_df.select_dtypes(include=["number"])

# حساب مصفوفة الارتباط
correlation_matrix = numeric_df.corr()
# رسم الخريطة الحرارية
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)

# تخصيص المخطط
plt.title("Correlation Heatmap of Football Data", fontsize=14)
plt.show()

# %%
correlation = football_df[["age", "current_value"]].corr().iloc[0, 1]
print(f"Correlation between Age and Current Value: {correlation:.2f}")

# Plot scatter plot with regression line
plt.figure(figsize=(8, 6))
sns.regplot(x=football_df["age"], y=football_df["current_value"], scatter_kws={"alpha": 0.6}, line_kws={"color": "red"})

# Customize plot
plt.xlabel("Age", fontsize=12)
plt.ylabel("Current Value", fontsize=12)
plt.title(f"Age vs. Current Value (Correlation: {correlation:.2f})", fontsize=14)
plt.grid(True)

# Show plot
plt.show()
# Out:
# Correlation between Age and Current Value: -0.05

# %%
# Seems like the age and current value relationship is weak but its still when the age is larger the less the value

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=football_df["award"], y=football_df["current_value"], alpha=0.6)

plt.xlabel("Number of Awards", fontsize=12)
plt.ylabel("Current Market Value", fontsize=12)
plt.title("Relationship Between Awards and Current Value", fontsize=14)
plt.grid(True)

# Show the plot
plt.show()

# %%
# I see players with higher market values spread across different award counts.
# This means that having a high current value doesn't necessarily mean having a lot of awards.

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=football_df["appearance"], y=football_df["current_value"], alpha=0.6, label="Players")
sns.regplot(x=football_df["appearance"], y=football_df["current_value"], scatter=False, color="red", line_kws={"linewidth":2}, label="Trend Line")

# تخصيص المخطط
plt.xlabel("Number of Appearances", fontsize=12)
plt.ylabel("Current Market Value", fontsize=12)
plt.title("Relationship Between Appearances and Current Value", fontsize=14)
plt.legend()
plt.grid(True)

# عرض المخطط
plt.show()

# %%
# Players with many appearances may have high current value but not necessarily

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Feature Selection

# %%
football_df.dtypes
# Out:
# player                    object
# team                      object
# name                      object
# position                  object
# height                   float64
# age                      float64
# appearance                 int64
# goals                    float64
# assists                  float64
# yellow cards             float64
# second yellow cards      float64
# red cards                float64
# goals conceded           float64
# clean sheets             float64
# minutes played             int64
# days_injured               int64
# games_injured              int64
# award                      int64
# current_value              int64
# highest_value              int64
# position_encoded           int64
# winger                     int64
# height_z_score           float64
# days_injured_z_score     float64
# games_injured_z_score    float64
# current_value_z_score    float64
# highest_value_z_score    float64
# dtype: object

# %%
categorical_features = ['team', 'name', 'position']

# %%
# Need to drop these columns cuz feature engineering didn't work so I want to make the load less
football_df = football_df.drop(columns=[
    "height_z_score",
    "days_injured_z_score",
    "games_injured_z_score",
    "current_value_z_score",
    "highest_value_z_score",
    "player"
])

# %%
football_df = pd.get_dummies(football_df, columns=categorical_features)

# %%
football_df.shape
# Out:
# (10109, 10369)

# %%
correlation = football_df.corr()
print(correlation['current_value'].sort_values(ascending=False))
# Out:
# 2025-02-23 14:36:00,300 - INFO     - Executing shutdown due to inactivity...
# 2025-02-23 14:36:04,466 - INFO     - Executing shutdown...
# 2025-02-23 14:36:04,471 - INFO     - Not running with the Werkzeug Server, exiting by searching gc for BaseWSGIServer
# current_value          1.000000
# highest_value          0.787515
# appearance             0.448397
# minutes played         0.434030
# award                  0.178781
#                          ...
# position_Attack       -0.039881
# position_midfield     -0.047567
# age                   -0.057575
# goals conceded        -0.074041
# position_Goalkeeper   -0.097412
# Name: current_value, Length: 10369, dtype: float64

# %%
# Set the correlation threshold
threshold = 0.16

# Filter the correlations
# We use `abs()` for absolute value to consider both strong positive and negative correlations
selected_features = correlation[abs(correlation['current_value']) > threshold]['current_value'].index
selected_features
# Out:
# Index(['appearance', 'minutes played', 'current_value', 'highest_value'], dtype='object')

# %%
selected_features = ['appearance', 'minutes played', 'games_injured', 'award',
       'current_value', 'highest_value']

# %%
football_df = football_df[selected_features]
football_df.head()
# Out:
#     appearance  minutes played  games_injured  award  current_value  \
# 1           15            1304             58      1        1500000
# 2            4             292             84      4         600000
# 6           70            5471             19     10       15000000
# 8           34            2758             13      0        2000000
# 10          89            7132             15      3       22000000
#
#     highest_value
# 1        22000000
# 2         6000000
# 6        35000000
# 8         2000000
# 10       22000000

# %%
football_df.shape
# Out:
# (10109, 6)

# %% [markdown]
# ## Prepare Train and Test Data

# %%
# Prepare data
X = football_df.drop(['current_value'], axis=1)
y = football_df['current_value']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.2,
                                                    shuffle=True,
                                                    random_state=42)

# scale the data
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X.shape
# Out:
# (10109, 5)

# %% [markdown]
# # Building The Model

# %%
model = LinearRegression()

# %% [markdown]
# # Train The Model

# %%
# Fit the model on the training data
model.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Test The Model

# %%
# Predict and evaluate the model
y_pred = model.predict(X_test_scaled)      # Linear regression model

# %% [markdown]
# # Interpretation of the Model

# %%
coeff_df = pd.DataFrame(model.coef_,X.columns,columns=['Coefficient'])   # Linear model cofficients

# %%
coeff_df
# Out:
#                  Coefficient
# appearance     -1.698836e+05
# minutes played  7.709485e+05
# games_injured  -4.197683e+05
# award          -5.548376e+05
# highest_value   3.391253e+06

# %%
print(f" Linear regression intercept: {model.intercept_}")
# Out:
#  Linear regression intercept: 2357682.7006306415

# %% [markdown]
# # Evaluating The Model

# %% [markdown]
# ### Mean Square Error

# %%
y_base = [y_train.mean()] * len(y_test)

# %%
y_base
# Out:
# [2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  ...]

# %%
# our benchmark model
mse_base = mean_squared_error(y_test, y_base )
print(f'Mean Squared Error of base model: {mse_base:2e}')
# Out:
# Mean Squared Error of base model: 2.064785e+13

# %% [markdown]
# ### Mean Square Error

# %%
# MSE for Linear model
mse_train = mean_squared_error(y_train, model.predict(X_train_scaled))
mse_test = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error for training: {mse_train:2e}')
print(f'Mean Squared Error for testing: {mse_test:2e}')
# Out:
# Mean Squared Error for training: 5.863767e+12
# Mean Squared Error for testing: 6.210861e+12

# %% [markdown]
# ### Mean Absolute Error

# %%
# our benchmark model
mae_base = mean_absolute_error(y_test, y_base )
print(f'Mean Absolute  Error of base model: {mae_base:2e}')
# Out:
# Mean Absolute  Error of base model: 2.730649e+06

# %%
# Linear model
mae_train = mean_absolute_error(y_train, model.predict(X_train_scaled))
mae_test = mean_absolute_error(y_test, y_pred)
print(f'Mean Absolute Error for training: {mae_train:2e}')
print(f'Mean Absolute Error for testing: {mae_test:2e}')
# Out:
# Mean Absolute Error for training: 1.333732e+06
# Mean Absolute Error for testing: 1.367016e+06

# %% [markdown]
# ### Root Mean Squared Error

# %%
# our benchmark model
print(f'Root Mean Squared  Error of base model: {np.sqrt(mse_base):2e}')
# Out:
# Root Mean Squared  Error of base model: 4.543990e+06

# %%
# RMSE for Linear model

print(f'Root Mean Squared Error for training: {np.sqrt(mse_train):2e}')
print(f'Root Mean Squared Error for testing: {np.sqrt(mse_test):2e}')
# Out:
# Root Mean Squared Error for training: 2.421522e+06
# Root Mean Squared Error for testing: 2.492160e+06

# %% [markdown]
# ### Predictions vs. Real Values

# %%
predictions = model.predict(X_test_scaled)
#predictions

# %%
predictions
# Out:
# array([1242157.28930655, 2283489.73138598,  889708.37386271, ...,
#         604151.35567054, 3316998.57181308, 3178779.91029465])

# %%
Real_Values = np.array(y_test)
# Real_Values

# %%
plt.scatter(Real_Values, predictions)
plt.plot([Real_Values.min(), Real_Values.max()], [Real_Values.min(), Real_Values.max()], color='red', lw=1)
plt.xlabel('Real Values')
plt.ylabel('Predictions')
plt.title('Real Values vs Predictions')
plt.show()

# %%
sns.histplot((y_test - predictions), bins=50, kde=True)
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Distribution of Residuals")
plt.show()

# %% [markdown]
# # Building The Model

# %%
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)

# %% [markdown]
# # Train The Model

# %%
rf_model.fit(X_test_scaled, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[408], line 1
# ----> 1 rf_model.fit(X_test_scaled, y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:363, in BaseForest.fit(self, X, y, sample_weight)
#     360 if issparse(y):
#     361     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 363 X, y = self._validate_data(
#     364     X,
#     365     y,
#     366     multi_output=True,
#     367     accept_sparse="csc",
#     368     dtype=DTYPE,
#     369     force_all_finite=False,
#     370 )
#     371 # _compute_missing_values_in_feature_mask checks if X has missing values and
#     372 # will raise an error if the underlying tree base estimator can't handle missing
#     373 # values. Only the criterion is required to determine if the tree supports
#     374 # missing values.
#     375 estimator = type(self.estimator)(criterion=self.criterion)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:650, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     648         y = check_array(y, input_name="y", **check_y_params)
#     649     else:
# --> 650         X, y = check_X_y(X, y, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1320, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1301 X = check_array(
#    1302     X,
#    1303     accept_sparse=accept_sparse,
#    (...)
#    1315     input_name="X",
#    1316 )
#    1318 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
# -> 1320 check_consistent_length(X, y)
#    1322 return X, y
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:457, in check_consistent_length(*arrays)
#     455 uniques = np.unique(lengths)
#     456 if len(uniques) > 1:
# --> 457     raise ValueError(
#     458         "Found input variables with inconsistent numbers of samples: %r"
#     459         % [int(l) for l in lengths]
#     460     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [2022, 8087]

# %% [markdown]
# # Test The Model

# %%
predictions = rf_model.predict(X_test_scaled)

# %% [markdown]
# # Evaluating The Model

# %% [markdown]
# ### Mean Square Error

# %%
y_base = [y_train.mean()] * len(y_test)

# %%
y_base
# Out:
# [2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  ...]

# %%
# our benchmark model
mse_base = mean_squared_error(y_test, y_base)
print(f'Mean Squared Error of base model: {mse_base:2e}')
# Out:
# Mean Squared Error of base model: 2.064785e+13

# %% [markdown]
# ### Mean Square Error

# %%
mse_train = mean_squared_error(y_train, rf_model.predict(X_train_scaled))
mse_test = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error for training: {mse_train:2e}')
print(f'Mean Squared Error for testing: {mse_test:2e}')
# Out:
# Mean Squared Error for training: 2.277250e+13
# Mean Squared Error for testing: 6.972548e+12

# %% [markdown]
# ### Mean Absolute Error

# %%
# our benchmark model
mae_base = mean_absolute_error(y_test, y_base )
print(f'Mean Absolute  Error of base model: {mae_base:2e}')
# Out:
# Mean Absolute  Error of base model: 2.730649e+06

# %%
mae_train = mean_absolute_error(y_train, rf_model.predict(X_train_scaled))
mae_test = mean_absolute_error(y_test, y_pred)
print(f'Mean Absolute Error for training: {mae_train:2e}')
print(f'Mean Absolute Error for testing: {mae_test:2e}')
# Out:
# Mean Absolute Error for training: 2.357683e+06
# Mean Absolute Error for testing: 1.372384e+06

# %% [markdown]
# ### Root Mean Squared Error

# %%
# our benchmark model
print(f'Root Mean Squared  Error of base model: {np.sqrt(mse_base):2e}')
# Out:
# Root Mean Squared  Error of base model: 4.543990e+06

# %%
print(f'Root Mean Squared Error for training: {np.sqrt(mse_train):2e}')
print(f'Root Mean Squared Error for testing: {np.sqrt(mse_test):2e}')
# Out:
# Root Mean Squared Error for training: 4.772054e+06
# Root Mean Squared Error for testing: 2.640558e+06

# %% [markdown]
# ### Predictions vs. Real Values

# %%
predictions = rf_model.predict(X_test_scaled)
#predictions

# %%
predictions
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
Real_Values = np.array(y_test)
# Real_Values

# %%
importances = rf_model.feature_importances_
feature_importance_df = pd.DataFrame({'Feature': X_train.columns, 'Importance': importances})
print(feature_importance_df.sort_values(by='Importance', ascending=False))
# Out:
#           Feature  Importance
# 2   highest_value    0.694574
# 1  minutes played    0.188502
# 0      appearance    0.116924

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_test, predictions, alpha=0.6)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linestyle='--')
plt.xlabel('Actual Values')
plt.ylabel('Predictions')
plt.title('Predictions vs Actual Values')
plt.grid()
plt.show()

# %%
# Plotting Distribution of Residuals
plt.figure(figsize=(10, 6))
sns.histplot((y_test - predictions), bins=50, kde=True)
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.title('Distribution of Residuals')
plt.grid()
plt.show()

# %% [markdown]
# # Building The Model

# %%
# Initialize the XGBoost model
xg_model = XGBRegressor(n_estimators=100, random_state=42)

# %% [markdown]
# # Train Model

# %%
# Fit the model using the scaled training data
xg_model.fit(X_train_scaled, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %% [markdown]
# # Test The Model

# %%
# Make predictions on the scaled test data
predictions_xg = xg_model.predict(X_test_scaled)

# %% [markdown]
# # Evaluating The Model

# %% [markdown]
# ### Mean Square Error

# %%
y_base = [y_train.mean()] * len(y_test)

# %%
y_base
# Out:
# [2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  2357682.7006306415,
#  ...]

# %%
# our benchmark model
mse_base = mean_squared_error(y_test, y_base)
print(f'Mean Squared Error of base model: {mse_base:2e}')
# Out:
# Mean Squared Error of base model: 2.064785e+13

# %% [markdown]
# ### Mean Square Error

# %%
# MSE 
mse_train = mean_squared_error(y_train, xg_model.predict(X_train_scaled))
mse_test = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error for training: {mse_train:2e}')
print(f'Mean Squared Error for testing: {mse_test:2e}')
# Out:
# Mean Squared Error for training: 1.119462e+12
# Mean Squared Error for testing: 6.972548e+12

# %% [markdown]
# ### Mean Absolute Error

# %%
# our benchmark model
mae_base = mean_absolute_error(y_test, y_base )
print(f'Mean Absolute  Error of base model: {mae_base:2e}')
# Out:
# Mean Absolute  Error of base model: 2.730649e+06

# %%
mae_train = mean_absolute_error(y_train, xg_model.predict(X_train_scaled))
mae_test = mean_absolute_error(y_test, y_pred)
print(f'Mean Absolute Error for training: {mae_train:2e}')
print(f'Mean Absolute Error for testing: {mae_test:2e}')
# Out:
# Mean Absolute Error for training: 5.845325e+05
# Mean Absolute Error for testing: 1.372384e+06

# %% [markdown]
# ### Root Mean Squared Error

# %%
# our benchmark model
print(f'Root Mean Squared  Error of base model: {np.sqrt(mse_base):2e}')
# Out:
# Root Mean Squared  Error of base model: 4.543990e+06

# %%
# RMSE 

print(f'Root Mean Squared Error for training: {np.sqrt(mse_train):2e}')
print(f'Root Mean Squared Error for testing: {np.sqrt(mse_test):2e}')
# Out:
# Root Mean Squared Error for training: 1.058046e+06
# Root Mean Squared Error for testing: 2.640558e+06

# %% [markdown]
# ### Predictions vs. Real Values

# %%
predictions = xg_model.predict(X_test_scaled)
#predictions

# %%
predictions
# Out:
# array([2049503.4 , 2761672.  , 1362630.1 , ...,  109093.28, 1970236.5 ,
#        5250939.5 ], dtype=float32)

# %%
Real_Values = np.array(y_test)
# Real_Values

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_test, predictions, alpha=0.6)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linestyle='--')
plt.xlabel('Actual Values')
plt.ylabel('Predictions')
plt.title('Predictions vs Actual Values')
plt.grid()
plt.show()

# %%
# Plotting Distribution of Residuals
plt.figure(figsize=(10, 6))
sns.histplot((y_test - predictions), bins=50, kde=True)
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.title('Distribution of Residuals')
plt.grid()
plt.show()

# %% [markdown]
# ##### What I Understood

# %% [raw]
# Linear Regression performs the best on the test set, with the lowest MSE and RMSE, and comparable MAE to the other models.
#
# Despite being a simpler model, it generalizes better to unseen data compared to the more complex Random Forest and XGBoost models.

# %% [raw]
# -
