# %%
# To ignore warnings
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.linear_model import Ridge, Lasso
from sklearn.model_selection import GridSearchCV
from scipy.stats import zscore
import dtale
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score




## This statement allows the visuals to render within your Jupyter Notebook.
# %matplotlib inline

# %%
# !pip install xgboost

# %% [markdown]
# ## Loading the data
# We can now load the dataset into pandas using the read_csv() function. This converts the CSV file into a Pandas dataframe.

# %%
football_df = pd.read_csv('Data/final_data.csv')

# %% [markdown]
# # Preprocess the Data

# %% [markdown]
# ### Viewing the dataframe
# We can get a quick sense of the size of our dataset by using the shape method. This returns a tuple with the number of rows and columns in the dataset.

# %%
football_df_report=dtale.show(football_df)
football_df_report
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://LAPTOP-8L6R58JJ:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # EDA

# %% [markdown]
# ## 1. Data Profiling:
# Data profiling is a comprehensive process of examining the data available in an existing dataset and collecting statistics and information about that data.

# %%
football_df.head()
# Out:
#                                      player               team  \
# 0        /david-de-gea/profil/spieler/59377  Manchester United
# 1       /jack-butland/profil/spieler/128899  Manchester United
# 2          /tom-heaton/profil/spieler/34130  Manchester United
# 3  /lisandro-martinez/profil/spieler/480762  Manchester United
# 4     /raphael-varane/profil/spieler/164770  Manchester United
#
#                 name              position  height   age  appearance  \
# 0       David de Gea            Goalkeeper   189.0  32.0         104
# 1       Jack Butland            Goalkeeper   196.0  30.0          15
# 2         Tom Heaton            Goalkeeper   188.0  37.0           4
# 3  Lisandro Martínez  Defender Centre-Back   175.0  25.0          82
# 4     Raphaël Varane  Defender Centre-Back   191.0  30.0          63
#
#       goals   assists  yellow cards  second yellow cards  red cards  \
# 0  0.000000  0.000000      0.009585                  0.0        0.0
# 1  0.000000  0.000000      0.069018                  0.0        0.0
# 2  0.000000  0.000000      0.000000                  0.0        0.0
# 3  0.028090  0.056180      0.224719                  0.0        0.0
# 4  0.017889  0.017889      0.053667                  0.0        0.0
#
#    goals conceded  clean sheets  minutes played  days_injured  games_injured  \
# 0        1.217252      0.335463            9390            42              5
# 1        1.242331      0.207055            1304           510             58
# 2        0.616438      0.924658             292           697             84
# 3        0.000000      0.000000            6408           175             22
# 4        0.000000      0.000000            5031           238             51
#
#    award  current_value  highest_value  position_encoded  winger
# 0     13       15000000       70000000                 1       0
# 1      1        1500000       22000000                 1       0
# 2      4         600000        6000000                 1       0
# 3      9       50000000       50000000                 2       0
# 4     21       40000000       80000000                 2       0

# %%
# NO NULL VALUES
football_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10754 entries, 0 to 10753
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   player               10754 non-null  object
#  1   team                 10754 non-null  object
#  2   name                 10754 non-null  object
#  3   position             10754 non-null  object
#  4   height               10754 non-null  float64
#  5   age                  10754 non-null  float64
#  6   appearance           10754 non-null  int64
#  7   goals                10754 non-null  float64
#  8   assists              10754 non-null  float64
#  9   yellow cards         10754 non-null  float64
#  10  second yellow cards  10754 non-null  float64
#  11  red cards            10754 non-null  float64
#  12  goals conceded       10754 non-null  float64
#  13  clean sheets         10754 non-null  float64
#  14  minutes played       10754 non-null  int64
#  15  days_injured         10754 non-null  int64
#  16  games_injured        10754 non-null  int64
#  17  award                10754 non-null  int64
#  18  current_value        10754 non-null  int64
#  19  highest_value        10754 non-null  int64
#  20  position_encoded     10754 non-null  int64
#  21  winger               10754 non-null  int64
# dtypes: float64(9), int64(9), object(4)
# memory usage: 1.8+ MB

# %%
football_df.duplicated().sum()
# Out:
# 0

# %%
football_df
# Out:
#                                           player                      team  \
# 0             /david-de-gea/profil/spieler/59377         Manchester United
# 1            /jack-butland/profil/spieler/128899         Manchester United
# 2               /tom-heaton/profil/spieler/34130         Manchester United
# 3       /lisandro-martinez/profil/spieler/480762         Manchester United
# 4          /raphael-varane/profil/spieler/164770         Manchester United
# ...                                          ...                       ...
# 10749       /aidan-simmons/profil/spieler/867763  Western Sydney Wanderers
# 10750        /kusini-yengi/profil/spieler/708099  Western Sydney Wanderers
# 10751    /nathanael-blair/profil/spieler/1023268  Western Sydney Wanderers
# 10752    /zachary-sapsford/profil/spieler/703657  Western Sydney Wanderers
# 10753  /alexander-badolato/profil/spieler/957230  Western Sydney Wanderers
#
#                      name               position      height   age  \
# 0            David de Gea             Goalkeeper  189.000000  32.0
# 1            Jack Butland             Goalkeeper  196.000000  30.0
# 2              Tom Heaton             Goalkeeper  188.000000  37.0
# 3       Lisandro Martínez   Defender Centre-Back  175.000000  25.0
# 4          Raphaël Varane   Defender Centre-Back  191.000000  30.0
# ...                   ...                    ...         ...   ...
# 10749       Aidan Simmons     Attack-RightWinger  181.240353  20.0
# 10750        Kusini Yengi  Attack Centre-Forward  190.000000  24.0
# 10751     Nathanael Blair  Attack Centre-Forward  181.240353  19.0
# 10752    Zachary Sapsford  Attack Centre-Forward  181.240353  20.0
# 10753  Alexander Badolato  Attack Centre-Forward  170.000000  18.0
#
#        appearance     goals   assists  yellow cards  second yellow cards  \
# 0             104  0.000000  0.000000      0.009585                  0.0
# 1              15  0.000000  0.000000      0.069018                  0.0
# 2               4  0.000000  0.000000      0.000000                  0.0
# 3              82  0.028090  0.056180      0.224719                  0.0
# 4              63  0.017889  0.017889      0.053667                  0.0
# ...           ...       ...       ...           ...                  ...
# 10749          16  0.175953  0.087977      0.263930                  0.0
# 10750          26  0.372671  0.186335      0.186335                  0.0
# 10751          20  0.375000  0.000000      0.187500                  0.0
# 10752          17  0.312139  0.104046      0.000000                  0.0
# 10753          21  0.000000  0.000000      0.086042                  0.0
#
#        red cards  goals conceded  clean sheets  minutes played  days_injured  \
# 0       0.000000        1.217252      0.335463            9390            42
# 1       0.000000        1.242331      0.207055            1304           510
# 2       0.000000        0.616438      0.924658             292           697
# 3       0.000000        0.000000      0.000000            6408           175
# 4       0.000000        0.000000      0.000000            5031           238
# ...          ...             ...           ...             ...           ...
# 10749   0.000000        0.000000      0.000000            1023             0
# 10750   0.000000        0.000000      0.000000            1449           102
# 10751   0.000000        0.000000      0.000000             960             0
# 10752   0.104046        0.000000      0.000000             865             0
# 10753   0.000000        0.000000      0.000000            1046             0
#
#        games_injured  award  current_value  highest_value  position_encoded  \
# 0                  5     13       15000000       70000000                 1
# 1                 58      1        1500000       22000000                 1
# 2                 84      4         600000        6000000                 1
# 3                 22      9       50000000       50000000                 2
# 4                 51     21       40000000       80000000                 2
# ...              ...    ...            ...            ...               ...
# 10749              0      0          75000          75000                 4
# 10750             18      0         300000         300000                 4
# 10751              0      0          50000          50000                 4
# 10752              0      0          50000          50000                 4
# 10753              0      0          25000          25000                 4
#
#        winger
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 10749       1
# 10750       0
# 10751       0
# 10752       0
# 10753       0
#
# [10754 rows x 22 columns]

# %%
# position_encoded --> 1- Goalkeeper, 2- Defender, 3- midfield, 4- Attack
# winger --> 1: winger, 0: not a winger

# %%
# Apperentlly "goals," "assists," "yellow cards," "second yellow cards," 
# "red cards," "goals conceded," and "clean sheets" were transformed to a per 90-minute basis.

# %%
football_df.dtypes
# Out:
# player                  object
# team                    object
# name                    object
# position                object
# height                 float64
# age                    float64
# appearance               int64
# goals                  float64
# assists                float64
# yellow cards           float64
# second yellow cards    float64
# red cards              float64
# goals conceded         float64
# clean sheets           float64
# minutes played           int64
# days_injured             int64
# games_injured            int64
# award                    int64
# current_value            int64
# highest_value            int64
# position_encoded         int64
# winger                   int64
# dtype: object

# %%
football_df['team'].unique()
# Out:
# array(['Manchester United', 'West Ham United', 'Leicester City',
#        'Aston Villa', 'Wolverhampton Wanderers', 'Southampton FC',
#        'Brighton &amp; Hove Albion', 'Everton FC', 'Nottingham Forest',
#        'Leeds United', 'Crystal Palace', 'Fulham FC', 'AFC Bournemouth',
#        'Brentford FC', 'Liverpool FC', 'Newcastle United',
#        'Manchester City', 'Arsenal FC', 'Tottenham Hotspur', 'Chelsea FC',
#        'Borussia Mönchengladbach', 'VfL Wolfsburg', 'TSG 1899 Hoffenheim',
#        '1.FC Union Berlin', 'FC Augsburg', 'VfB Stuttgart',
#        '1.FSV Mainz 05', '1.FC Köln', 'Hertha BSC', 'FC Schalke 04',
#        'VfL Bochum', 'SV Werder Bremen', 'Eintracht Frankfurt',
#        'SC Freiburg', 'Borussia Dortmund', 'Bayer 04 Leverkusen',
#        'Bayern Munich', 'RB Leipzig', 'Real Sociedad', 'Villarreal CF',
#        'Real Betis Balompié', 'Athletic Bilbao', 'Valencia CF',
#        'Sevilla FC', 'Celta de Vigo', 'CA Osasuna', 'Girona FC',
#        'Rayo Vallecano', 'RCD Mallorca', 'UD Almería',
#        'Real Valladolid CF', 'Cádiz CF', 'Elche CF',
#        'RCD Espanyol Barcelona', 'Getafe CF', 'Atlético de Madrid',
#        'Real Madrid', 'FC Barcelona', 'AS Roma', 'SS Lazio',
#        'ACF Fiorentina', 'US Sassuolo', 'Torino FC', 'Udinese Calcio',
#        'Bologna FC 1909', 'AC Monza', 'FC Empoli', 'US Lecce',
#        'Spezia Calcio', 'Hellas Verona', 'UC Sampdoria', 'US Cremonese',
#        'US Salernitana 1919', 'Atalanta BC', 'SSC Napoli', 'Inter Milan',
#        'AC Milan', 'Juventus FC', 'AS Monaco', 'Stade Rennais FC',
#        'Olympique Marseille', 'OGC Nice', 'RC Lens', 'FC Nantes',
#        'Montpellier HSC', 'FC Lorient', 'FC Toulouse', 'ESTAC Troyes',
#        'Stade Brestois 29', 'Angers SCO', 'AJ Auxerre',
#        'Clermont Foot 63', 'AC Ajaccio', 'Olympique Lyon', 'LOSC Lille',
#        'Stade Reims', 'RC Strasbourg Alsace', 'Paris Saint-Germain',
#        'AZ Alkmaar', 'Twente Enschede FC', 'Vitesse Arnhem',
#        'FC Groningen', 'Fortuna Sittard', 'NEC Nijmegen',
#        'Sparta Rotterdam', 'SC Cambuur Leeuwarden', 'Excelsior Rotterdam',
#        'FC Volendam', 'RKC Waalwijk', 'FC Emmen', 'Go Ahead Eagles',
#        'FC Utrecht', 'SC Heerenveen', 'Ajax Amsterdam', 'PSV Eindhoven',
#        'Feyenoord Rotterdam', 'Club Athletico Paranaense',
#        'Red Bull Bragantino', 'Santos FC',
#        'Clube de Regatas Vasco da Gama', 'Fluminense Football Club',
#        'Sport Club Internacional', 'Esporte Clube Bahia',
#        'Grêmio Foot-Ball Porto Alegrense', 'Coritiba Foot Ball Club',
#        'Fortaleza Esporte Clube', 'Cruzeiro Esporte Clube',
#        'Goiás Esporte Clube', 'Cuiabá Esporte Clube (MT)',
#        'Botafogo de Futebol e Regatas', 'Clube Atlético Mineiro',
#        'São Paulo Futebol Clube', 'América Futebol Clube (MG)',
#        'Sociedade Esportiva Palmeiras', 'CR Flamengo',
#        'Sport Club Corinthians Paulista', 'SC Braga', 'FC Famalicão',
#        'Vitória Guimarães SC', 'CD Santa Clara', 'GD Estoril Praia',
#        'Boavista FC', 'Portimonense SC', 'CS Marítimo', 'Casa Pia AC',
#        'FC Paços de Ferreira', 'FC Arouca', 'FC Vizela', 'Rio Ave FC',
#        'GD Chaves', 'Gil Vicente FC', 'FC Porto', 'Sporting CP',
#        'SL Benfica', 'Santos Laguna', 'Club León FC', 'FC Juárez',
#        'Club Tijuana', 'Atlético de San Luis', 'Club Necaxa', 'Puebla FC',
#        'Mazatlán FC', 'Querétaro FC', 'CF América', 'CF Monterrey',
#        'Atlas Guadalajara', 'UNAM Pumas', 'Deportivo Toluca',
#        'Tigres UANL', 'Deportivo Guadalajara', 'CD Cruz Azul',
#        'CF Pachuca', 'Dynamo Moscow', 'Lokomotiv Moscow', 'FK Rostov',
#        'Krylya Sovetov Samara', 'FC Sochi', 'Akhmat Grozny',
#        'Ural Yekaterinburg', 'FK Orenburg', 'FC Pari Nizhniy Novgorod',
#        'FK Khimki', 'Torpedo Moscow', 'Fakel Voronezh', 'Spartak Moscow',
#        'CSKA Moscow', 'FK Krasnodar', 'Zenit St. Petersburg',
#        'West Bromwich Albion', 'Sunderland AFC', 'Hull City',
#        'Preston North End', 'Stoke City', 'Queens Park Rangers',
#        'Birmingham City', 'Cardiff City', 'Millwall FC', 'Reading FC',
#        'Blackpool FC', 'Bristol City', 'Huddersfield Town',
#        'Rotherham United', 'Wigan Athletic', 'Middlesbrough FC',
#        'Coventry City', 'Luton Town', 'Swansea City', 'Burnley FC',
#        'Watford FC', 'Sheffield United', 'Blackburn Rovers',
#        'Norwich City', 'Trabzonspor', 'Besiktas JK', 'Basaksehir FK',
#        'Antalyaspor', 'Adana Demirspor', 'Alanyaspor', 'Kasimpasa',
#        'Konyaspor', 'MKE Ankaragücü', 'Sivasspor', 'Kayserispor',
#        'Giresunspor', 'Istanbulspor', 'Hatayspor', 'Gaziantep FK',
#        'Fatih Karagümrük', 'Ümraniyespor', 'Fenerbahce', 'Galatasaray',
#        'SK Sturm Graz', 'LASK', 'SCR Altach', 'SC Austria Lustenau',
#        'SV Ried', 'TSV Hartberg', 'WSG Tirol', 'Rapid Vienna',
#        'Austria Vienna', 'SK Austria Klagenfurt', 'Wolfsberger AC',
#        'Red Bull Salzburg', 'Philadelphia Union', 'FC Cincinnati',
#        'FC Dallas', 'Orlando City SC', 'Los Angeles Galaxy',
#        'New England Revolution', 'D.C. United', 'New York Red Bulls',
#        'Portland Timbers', 'Columbus Crew', 'Charlotte FC',
#        'Sporting Kansas City', 'Colorado Rapids',
#        'Vancouver Whitecaps FC', 'Chicago Fire FC', 'Inter Miami CF',
#        'Minnesota United FC', 'Houston Dynamo FC', 'St. Louis CITY SC',
#        'CF Montréal', 'Real Salt Lake City', 'Nashville SC',
#        'San Jose Earthquakes', 'Seattle Sounders FC', 'Atlanta United FC',
#        'New York City FC', 'Austin FC', 'Los Angeles FC', 'Toronto FC',
#        'CA Vélez Sarsfield', 'CA San Lorenzo de Almagro',
#        'Club Atlético Lanús', 'Defensa y Justicia',
#        'Club Estudiantes de La Plata', "CA Newell's Old Boys", 'CA Colon',
#        'CA Rosario Central', 'CA Banfield',
#        'Club de Gimnasia y Esgrima La Plata', 'Club Atlético Tucumán',
#        'CD Godoy Cruz Antonio Tomba', 'Club Atlético Unión',
#        'Club Atlético Platense', 'Instituto AC Córdoba',
#        'CA Sarmiento (Junin)', 'CA Central Córdoba (SdE)',
#        'CA Barracas Central', 'Arsenal Fútbol Club',
#        'Club Atlético Talleres', 'Club Atlético Belgrano',
#        'AA Argentinos Juniors', 'CA Independiente', 'Club Atlético Tigre',
#        'CA River Plate', 'CA Boca Juniors', 'CA Huracán', 'Racing Club',
#        'Kawasaki Frontale', 'Yokohama F. Marinos', 'Cerezo Osaka',
#        'Kyoto Sanga', 'FC Tokyo', 'Nagoya Grampus', 'Kashiwa Reysol',
#        'Yokohama FC', 'Avispa Fukuoka', 'Sagan Tosu', 'Vissel Kobe',
#        'Hokkaido Consadole Sapporo', 'Shonan Bellmare', 'Albirex Niigata',
#        'Kashima Antlers', 'Sanfrecce Hiroshima', 'Urawa Red Diamonds',
#        'Gamba Osaka', 'Al-Shabab Club (Riyadh)', 'Ettifaq FC',
#        'Al-Taawoun FC', 'Al-Wehda FC', 'Damac FC', 'Al-Tai',
#        'Al-Fayha FC', 'Abha Club', 'Al-Khaleej', 'Al-Raed SFC',
#        'Al-Batin FC', 'Al-Adalah FC', 'Al-Ittihad Club (Jeddah)',
#        'Al-Fateh SC', 'Al-Hilal Saudi FC', 'Al-Nassr FC',
#        'Suwon Samsung Bluewings', 'Jeju United', 'Incheon United',
#        'Gangwon FC', 'Daejeon Hana Citizen', 'Gwangju FC', 'Daegu FC',
#        'Suwon FC', 'Pohang Steelers', 'FC Seoul',
#        'Jeonbuk Hyundai Motors', 'Ulsan Hyundai', 'Sekhukhune United FC',
#        'AmaZulu FC', 'Lamontville Golden Arrows', 'Stellenbosch FC',
#        'Swallows FC', 'Maritzburg United FC', 'Royal AM FC',
#        'TS Galaxy FC', 'Richards Bay FC', 'Marumo Gallants FC',
#        'Cape Town City FC', 'Orlando Pirates', 'SuperSport United',
#        'Chippa United', 'Mamelodi Sundowns FC', 'Kaizer Chiefs',
#        'Melbourne Victory', 'Western United FC', 'Newcastle United Jets',
#        'Perth Glory', 'Macarthur FC', 'Brisbane Roar',
#        'Central Coast Mariners', 'Wellington Phoenix',
#        'Melbourne City FC', 'Sydney FC', 'Adelaide United',
#        'Western Sydney Wanderers'], dtype=object)

# %%
football_df['position'].unique()
# Out:
# array(['Goalkeeper', 'Defender Centre-Back', 'Defender Left-Back',
#        'Defender Right-Back', 'midfield-DefensiveMidfield',
#        'midfield-CentralMidfield', 'midfield-AttackingMidfield',
#        'Attack-LeftWinger', 'Attack-RightWinger', 'Attack Centre-Forward',
#        'midfield-RightMidfield', 'midfield-LeftMidfield',
#        'Attack-SecondStriker', 'midfield', 'Attack', 'Defender'],
#       dtype=object)

# %%
football_df['goals'].unique()
# Out:
# array([0.        , 0.02808989, 0.01788909, ..., 0.22670025, 0.17595308,
#        0.31213873])

# %% [markdown]
# The process of profiling differs slightly for categorical and numerical variables due to their inherent differences.
#
# **The two main types of data are:**
# - Quantitative (numerical) data
# - Qualitative (categorical) data

# %% [markdown]
# ### Data Quality Checks
# Data quality checks involve the process of ensuring that the data is accurate, complete, consistent, relevant, and reliable.
#
#
# **Here are typical steps involved in checking data quality:**

# %% [markdown]
# #### 1. Reliability:
# Evaluate the data's source and collection process to determine its trustworthiness.

# %% [raw]
# The dataset was sourced from Kaggle 'https://www.kaggle.com/datasets/khanghunhnguyntrng/football-players-transfer-fee-prediction-dataset/data'
# But they collected the data from different leagues, which are:
# 11 European leagues, including the Premier League and Championship in England, Bundesliga in Germany, La Liga in Spain, Serie A in Italy, Ligue 1 in France, Eredivisie in the Netherlands, Liga NOS in Portugal, Premier Liga in Russia, Super Lig in Turkey, and Bundesliga in Austria.
#
# 4 American leagues, including Brasileiro in Brazil, Major League Soccer in the United States, Primera División in Argentina, and Liga MX in Mexico.
#
# 1 African league, namely the DStv Premiership in South Africa.
#
# 4 Asian leagues, comprising J-League in Japan, Saudi Pro League in Saudi Arabia, K-League 1 in South Korea, and A-League in Australia.

# %% [markdown]
# #### 2. Timeliness:
# Ensure the data is up-to-date and reflective of the current situation or the period of interest for the analysis.

# %% [raw]
# According to the source "Kaggle" This dataset was generated by scraping data from Transfermarkt using Selenium and BeautifulSoup on June 10, 2023.
# It shows the performance of the players over two seasons
# It meets the time period we supposed work in

# %% [markdown]
# #### 3. Consistency:
#
# Confirm that the data is consistent within the dataset and across multiple data sources. For example, the same data point should not have different values in different places.

# %% [raw]
# Only one dataset so it's consistent

# %% [markdown]
# #### 4. Relevance:

# %% [raw]
# 1. Sample Relevance: The dataset represents players from various top leagues across different continents, capturing diverse market trends and transfer dynamics for better model accuracy.
# 2. Variable Relevance: It covers key factors influencing transfer value, such as age, height, position, goals, assists, injuries, and awards, which directly impact a player's market worth.

# %% [markdown]
# #### 5. Uniqueness:
# Check for and remove duplicate records to prevent skewed analysis results.

# %%
football_df.duplicated().sum()
# Out:
# 0

# %%
# I think all the values may be duplicated unless the whole row is identical it can't be duplicated
football_df.columns
# Out:
# Index(['player', 'team', 'name', 'position', 'height', 'age', 'appearance',
#        'goals', 'assists', 'yellow cards', 'second yellow cards', 'red cards',
#        'goals conceded', 'clean sheets', 'minutes played', 'days_injured',
#        'games_injured', 'award', 'current_value', 'highest_value',
#        'position_encoded', 'winger'],
#       dtype='object')

# %%
# go to delete duplicates columns

# %% [markdown]
# #### 6. Completeness:
# Ensure that no critical data is missing. This might mean checking for null values or required fields that are empty.
#
# We will start by checking the dataset for missing or null values. For this, we can use the isna() method which returns a dataframe of boolean values indicating if a field is null or not. To group all missing values by column, we can include the sum() method.

# %%
football_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10754 entries, 0 to 10753
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   player               10754 non-null  object
#  1   team                 10754 non-null  object
#  2   name                 10754 non-null  object
#  3   position             10754 non-null  object
#  4   height               10754 non-null  float64
#  5   age                  10754 non-null  float64
#  6   appearance           10754 non-null  int64
#  7   goals                10754 non-null  float64
#  8   assists              10754 non-null  float64
#  9   yellow cards         10754 non-null  float64
#  10  second yellow cards  10754 non-null  float64
#  11  red cards            10754 non-null  float64
#  12  goals conceded       10754 non-null  float64
#  13  clean sheets         10754 non-null  float64
#  14  minutes played       10754 non-null  int64
#  15  days_injured         10754 non-null  int64
#  16  games_injured        10754 non-null  int64
#  17  award                10754 non-null  int64
#  18  current_value        10754 non-null  int64
#  19  highest_value        10754 non-null  int64
#  20  position_encoded     10754 non-null  int64
#  21  winger               10754 non-null  int64
# dtypes: float64(9), int64(9), object(4)
# memory usage: 1.8+ MB

# %%
# NO missing values

# %%
# go to clean them

# %% [markdown]
# #### 7. Check Accuracy:
#
# Verify that the data is correct and precise. This could involve comparing data samples with known sources or using validation rules.
#
# **The process includes:**
# 1. Validating the appropriateness of data types for the dataset.
# 2. Identifying outliers  using established validation  rule

# %%
football_df.dtypes
# Out:
# player                  object
# team                    object
# name                    object
# position                object
# height                 float64
# age                    float64
# appearance               int64
# goals                  float64
# assists                float64
# yellow cards           float64
# second yellow cards    float64
# red cards              float64
# goals conceded         float64
# clean sheets           float64
# minutes played           int64
# days_injured             int64
# games_injured            int64
# award                    int64
# current_value            int64
# highest_value            int64
# position_encoded         int64
# winger                   int64
# dtype: object

# %%
# The data type of each column suits their logical meaning

# %% [markdown]
# ## 2. Data Cleaning:
#
# Preliminary findings from data profiling can lead to cleaning the data by:
# - Handling missing values
# - Correcting errors.
# - Dealing with outliers.
#
# -------------------

# %% [markdown]
# ### Correcting errors
#
# -------------------

# %%
# go back to 7th dimension Accuracy

# %% [markdown]
# ##### Dealing with outliers:

# %% [markdown]
# **How to remove Outliers?**
# Most of the ways to deal with outliers are similar to the methods of missing values like deleting rows, transforming them, binning them, treat them as a separate group, imputing values and other statistical methods. Here, we will discuss the common techniques used to deal with outliers:
#
# 1. Deleting rows: We delete outlier values if it is due to data entry error, data processing error or outlier rows are very small in numbers. We can also use trimming at both ends to remove outliers.
#
# 2. Imputing: Like imputation of missing values, we can also impute outliers. We can use mean, median, mode imputation methods. Before imputing values, we should analyse if it is natural outlier or artificial. If it is artificial, we can go with imputing values. We can also use statistical model to predict values of outlier rows and after that we can impute it with predicted values.
#
# 3. Treat separately: If there are significant number of outliers, we should treat them separately in the statistical model. One of the approach is to treat both groups as two different groups and build individual model for both groups and then combine the output.

# %% [markdown]
# ##### football_df - age column's outliers

# %%
filtered_age = football_df[(football_df["age"] >= 16) &(football_df["age"] <= 39)]

plt.figure(figsize=(10, 6))
plt.hist(filtered_age["age"], bins=15, color="navy", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Age", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Players' Age (17 =< Age <= 39)", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
# I tried multiple values and I saw that this gave the most normal distribution

# %%
filtered_age.shape
# Out:
# (10715, 22)

# %%
football_df.shape
# Out:
# (10754, 22)

# %%
# Droping the outliers
football_df=football_df[(football_df["age"] >= 16) &(football_df["age"] <= 39)]

# %%
football_df.shape
# Out:
# (10715, 22)

# %% [markdown]
# ##### football_df - height column's outliers

# %%
zscore(football_df['height'])

football_df['height_z_score'] = zscore(football_df['height'])

football_df[(football_df['height_z_score'] > 2.9) | (football_df['height_z_score']< -2.9)].sort_values(by='height')
# Out:
#                                                   player  \
# 7563               /nahuel-barrios/profil/spieler/503377
# 8288                  /maxi-moralez/profil/spieler/30687
# 6894             /steven-sserwadda/profil/spieler/568840
# 10258             /kajally-drammeh/profil/spieler/863824
# 9341     /al-mutasim-sediq-hassan/profil/spieler/1057847
# 9019            /sumaihan-al-nabit/profil/spieler/478531
# 8647               /taichi-kikuchi/profil/spieler/683325
# 8472            /teruhito-nakagawa/profil/spieler/345326
# 8143              /braian-martinez/profil/spieler/739995
# 8085                 /mariano-mino/profil/spieler/538092
# 6725               /luciano-acosta/profil/spieler/315169
# 10612               /joshua-nisbet/profil/spieler/603863
# 5951                /erhun-oztumer/profil/spieler/326843
# 4625               /edgar-alaffita/profil/spieler/264104
# 4402             /misael-dominguez/profil/spieler/451221
# 3236             /yeferson-soteldo/profil/spieler/312294
# 10285     /ndabayithethwa-ndlondlo/profil/spieler/636981
# 8601            /katsuki-nishimura/profil/spieler/914625
# 8610                 /kazuya-konno/profil/spieler/654348
# 6884               /matthew-nocita/profil/spieler/972457
# 5031                 /stefan-sapic/profil/spieler/429243
# 3039              /andries-noppert/profil/spieler/276853
# 9472                 /fejsal-mulic/profil/spieler/226194
# 6394          /pape-alioune-ndiaye/profil/spieler/433219
# 1656   /vanja-milinkovi%C4%87-savi%C4%87/profil/spiel...
# 3770                /carlos-miguel/profil/spieler/641458
# 2700               /kjell-scherpen/profil/spieler/463527
# 2439                  /isaak-toure/profil/spieler/708678
#
#                                   team                     name  \
# 7563         CA San Lorenzo de Almagro           Nahuel Barrios
# 8288                       Racing Club             Maxi Moralez
# 6894                New York Red Bulls         Steven Sserwadda
# 10258                Cape Town City FC          Kajally Drammeh
# 9341          Al-Ittihad Club (Jeddah)  Al-Mutasim Sediq Hassan
# 9019                     Al-Taawoun FC        Sumaihan Al-Nabit
# 8647                        Sagan Tosu           Taichi Kikuchi
# 8472                          FC Tokyo        Teruhito Nakagawa
# 8143                  CA Independiente          Braian Martínez
# 8085            Club Atlético Belgrano             Mariano Miño
# 6725                     FC Cincinnati           Luciano Acosta
# 10612           Central Coast Mariners            Joshua Nisbet
# 5951                   Adana Demirspor            Erhun Öztümer
# 4625                        UNAM Pumas           Édgar Alaffita
# 4402                      Club Tijuana         Misael Domínguez
# 3236                         Santos FC         Yeferson Soteldo
# 10285                  Orlando Pirates  Ndabayithethwa Ndlondlo
# 8601                    Avispa Fukuoka        Katsuki Nishimura
# 8610                    Avispa Fukuoka             Kazuya Konno
# 6884                New York Red Bulls           Matthew Nocita
# 5031                    Torpedo Moscow             Stefan Sapic
# 3039                     SC Heerenveen          Andries Noppert
# 9472           Suwon Samsung Bluewings             Fejsal Mulic
# 6394                        SCR Altach      Pape-Alioune Ndiaye
# 1656                         Torino FC   Vanja Milinković-Savić
# 3770   Sport Club Corinthians Paulista            Carlos Miguel
# 2700                    Vitesse Arnhem           Kjell Scherpen
# 2439                        AJ Auxerre              Isaak Touré
#
#                          position  height   age  appearance     goals  \
# 7563            Attack-LeftWinger   156.0  25.0           4  0.000000
# 8288   midfield-AttackingMidfield   159.0  36.0          17  0.205950
# 6894     midfield-CentralMidfield   160.0  20.0           0  0.000000
# 10258          Attack-RightWinger   160.0  19.0          19  0.130435
# 9341                       Attack   160.0  21.0           0  0.000000
# 9019            Attack-LeftWinger   160.0  27.0          63  0.231720
# 8647   midfield-AttackingMidfield   160.0  24.0          16  0.000000
# 8472           Attack-RightWinger   160.0  30.0          22  0.256959
# 8143            Attack-LeftWinger   160.0  23.0          10  0.000000
# 8085   midfield-AttackingMidfield   160.0  29.0           3  0.000000
# 6725   midfield-AttackingMidfield   160.0  29.0          16  0.576461
# 10612  midfield-DefensiveMidfield   160.0  23.0          56  0.061728
# 5951   midfield-AttackingMidfield   160.0  32.0          38  0.324519
# 4625     midfield-CentralMidfield   160.0  26.0          61  0.106846
# 4402   midfield-AttackingMidfield   160.0  23.0          29  0.000000
# 3236            Attack-LeftWinger   160.0  25.0          24  0.094937
# 10285  midfield-AttackingMidfield   161.0  28.0          63  0.214844
# 8601                     midfield   161.0  18.0           2  0.000000
# 8610           Attack-RightWinger   161.0  25.0          14  0.078125
# 6884         Defender Centre-Back   202.0  23.0           3  0.000000
# 5031         Defender Centre-Back   202.0  26.0          45  0.049628
# 3039                   Goalkeeper   202.0  29.0          40  0.000000
# 9472        Attack Centre-Forward   202.0  28.0           7  0.300000
# 6394         Defender Centre-Back   202.0  25.0          39  0.000000
# 1656                   Goalkeeper   202.0  26.0          70  0.000000
# 3770                   Goalkeeper   204.0  24.0           0  0.000000
# 2700                   Goalkeeper   206.0  23.0          39  0.000000
# 2439         Defender Centre-Back   206.0  20.0          42  0.032597
#
#         assists  yellow cards  second yellow cards  red cards  goals conceded  \
# 7563   0.283912      0.000000             0.000000   0.000000        0.000000
# 8288   0.308924      0.308924             0.000000   0.000000        0.000000
# 6894   0.000000      0.000000             0.000000   0.000000        0.000000
# 10258  0.000000      0.130435             0.000000   0.000000        0.000000
# 9341   0.000000      0.000000             0.000000   0.000000        0.000000
# 9019   0.092688      0.301236             0.023172   0.000000        0.000000
# 8647   0.000000      0.000000             0.000000   0.000000        0.000000
# 8472   0.192719      0.128480             0.000000   0.000000        0.000000
# 8143   0.171103      0.171103             0.000000   0.000000        0.000000
# 8085   0.000000      0.000000             0.000000   0.000000        0.000000
# 6725   0.144115      0.288231             0.000000   0.000000        0.000000
# 10612  0.041152      0.041152             0.000000   0.000000        0.000000
# 5951   0.162260      0.162260             0.000000   0.000000        0.000000
# 4625   0.089038      0.089038             0.000000   0.017808        0.000000
# 4402   0.096257      0.096257             0.000000   0.096257        0.000000
# 3236   0.284810      0.094937             0.189873   0.000000        0.000000
# 10285  0.019531      0.136719             0.000000   0.000000        0.000000
# 8601   0.000000      0.000000             0.000000   0.000000        0.000000
# 8610   0.156250      0.000000             0.000000   0.000000        0.000000
# 6884   0.000000      0.407240             0.000000   0.000000        0.000000
# 5031   0.000000      0.248139             0.024814   0.000000        0.000000
# 3039   0.000000      0.025000             0.000000   0.000000        1.100000
# 9472   0.000000      0.300000             0.000000   0.000000        0.000000
# 6394   0.000000      0.206287             0.000000   0.000000        0.000000
# 1656   0.000000      0.113208             0.000000   0.000000        1.075472
# 3770   0.000000      0.000000             0.000000   0.000000        0.000000
# 2700   0.000000      0.000000             0.000000   0.025766        1.288291
# 2439   0.000000      0.260775             0.032597   0.000000        0.000000
#
#        clean sheets  minutes played  days_injured  games_injured  award  \
# 7563       0.000000             317            13              2      0
# 8288       0.000000             874           137             25      3
# 6894       0.000000               0             0              0      0
# 10258      0.000000             690             0              0      0
# 9341       0.000000               0             0              0      1
# 9019       0.000000            3884             0              0      0
# 8647       0.000000            1166             0              0      0
# 8472       0.000000            1401           176             25      6
# 8143       0.000000             526             0              0      0
# 8085       0.000000              23           225             20      1
# 6725       0.000000            1249            42              5      0
# 10612      0.000000            4374             0              0      1
# 5951       0.000000            1664             0              0      0
# 4625       0.000000            5054             0              0      0
# 4402       0.000000             935            22              2      5
# 3236       0.000000             948           157             21      0
# 10285      0.000000            4608             0              0      1
# 8601       0.000000              90             0              0      0
# 8610       0.000000            1152           218             43      1
# 6884       0.000000             221             0              0      0
# 5031       0.000000            3627             0              0      0
# 3039       0.375000            3600           507             27      0
# 9472       0.000000             300           205             24      0
# 6394       0.000000            3054            20              2      0
# 1656       0.268868            6360            63             15      2
# 3770       0.000000               0             0              0      0
# 2700       0.283424            3493            78              9      2
# 2439       0.000000            2761           129              1      0
#
#        current_value  highest_value  position_encoded  winger  height_z_score
# 7563         3500000        3500000                 4       1       -3.620520
# 8288          400000        6000000                 3       0       -3.190029
# 6894          200000         200000                 3       0       -3.046532
# 10258         250000         250000                 4       1       -3.046532
# 9341           25000          25000                 4       0       -3.046532
# 9019         1200000        1200000                 4       1       -3.046532
# 8647          400000         400000                 3       0       -3.046532
# 8472         1400000        2800000                 4       1       -3.046532
# 8143          400000         425000                 4       1       -3.046532
# 8085          350000         425000                 3       0       -3.046532
# 6725         4500000        6000000                 3       0       -3.046532
# 10612         400000         400000                 3       0       -3.046532
# 5951          150000         750000                 3       0       -3.046532
# 4625          600000         600000                 3       0       -3.046532
# 4402          300000         600000                 3       0       -3.046532
# 3236         6000000       10000000                 4       1       -3.046532
# 10285         750000         750000                 3       0       -2.903035
# 8601               0              0                 3       0       -2.903035
# 8610          400000         400000                 4       1       -2.903035
# 6884          100000         100000                 2       0        2.980341
# 5031          500000        1600000                 2       0        2.980341
# 3039         5000000        5000000                 1       0        2.980341
# 9472          700000         750000                 4       0        2.980341
# 6394          250000         900000                 2       0        2.980341
# 1656         3500000        4500000                 1       0        2.980341
# 3770         1000000        1000000                 1       0        3.267335
# 2700         2000000        2800000                 1       0        3.554329
# 2439         5000000        5000000                 2       0        3.554329

# %%
# Filter data
filtered_height = football_df[(football_df["height"] > 161) & (football_df["height"] < 202)]

# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(filtered_height["height"], bins=15, color="navy", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Height (cm)", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Players' Height (160 cm < Height < 204 cm)", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
# The chart looks pretty normally distributed after excluding these values so I will drop them
football_df=football_df[(football_df["height"] > 161) & (football_df["height"] < 202)]

# %%
football_df.shape
# Out:
# (10687, 23)

# %% [markdown]
# ##### football_df - days_injuref column's outliers

# %%
zscore(football_df['days_injured'])

football_df['days_injured_z_score'] = zscore(football_df['days_injured'])
# The column didnt show up so I wanted to know where did it start
football_df[(football_df['days_injured_z_score'] > 3.5) | (football_df['days_injured_z_score']< -3)].sort_values(by='days_injured')['days_injured'].min()
# Out:
# 732

# %%
indexs=football_df[(football_df['days_injured_z_score'] > 3.5) | (football_df['days_injured_z_score']< -3)].sort_values(by='days_injured').index
football_df.drop(indexs,inplace=True)

# %%
football_df.shape
# Out:
# (10565, 24)

# %% [markdown]
# ##### football_df - games_injured columns outliers

# %%
# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(football_df["games_injured"], bins=15, color="red", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Games Injured", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Games Injured", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
filtered_games=football_df[football_df["games_injured"]<90]
# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(filtered_games["games_injured"], bins=15, color="red", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Games Injured", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Games Injured", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
# Well obviously the chart won't help so I'll try zscore

# %%
zscore(football_df['games_injured'])

football_df['games_injured_z_score'] = zscore(football_df['games_injured'])

football_df[(football_df['games_injured_z_score'] > 3.5) | (football_df['games_injured_z_score']< -3.5)].sort_values(by='games_injured')
# Out:
#                                           player                 team  \
# 3115        /justin-bijlow/profil/spieler/315121  Feyenoord Rotterdam
# 37          /angelo-ogbonna/profil/spieler/48002      West Ham United
# 10563       /daniel-arzani/profil/spieler/399997         Macarthur FC
# 1619   /giacomo-bonaventura/profil/spieler/57280       ACF Fiorentina
# 1317       /clement-grenier/profil/spieler/72479         RCD Mallorca
# ...                                          ...                  ...
# 355            /rico-henry/profil/spieler/339556         Brentford FC
# 8291   /maximiliano-romero/profil/spieler/365758          Racing Club
# 440        /benjamin-mendy/profil/spieler/157495      Manchester City
# 783          /tolga-cigerci/profil/spieler/94199           Hertha BSC
# 5745        /jack-robinson/profil/spieler/128909     Sheffield United
#
#                       name                    position  height   age  \
# 3115         Justin Bijlow                  Goalkeeper   188.0  25.0
# 37          Angelo Ogbonna        Defender Centre-Back   191.0  35.0
# 10563        Daniel Arzani           Attack-LeftWinger   175.0  24.0
# 1619   Giacomo Bonaventura    midfield-CentralMidfield   180.0  33.0
# 1317       Clément Grenier    midfield-CentralMidfield   186.0  32.0
# ...                    ...                         ...     ...   ...
# 355             Rico Henry          Defender Left-Back   170.0  25.0
# 8291    Maximiliano Romero       Attack Centre-Forward   180.0  24.0
# 440         Benjamin Mendy          Defender Left-Back   185.0  28.0
# 783          Tolga Cigerci  midfield-DefensiveMidfield   185.0  31.0
# 5745         Jack Robinson          Defender Left-Back   180.0  29.0
#
#        appearance     goals   assists  yellow cards  second yellow cards  \
# 3115           69  0.000000  0.000000      0.014375             0.000000
# 37             42  0.027060  0.000000      0.108238             0.000000
# 10563          39  0.201162  0.321860      0.362092             0.040232
# 1619           84  0.171221  0.233483      0.202352             0.000000
# 1317           29  0.185950  0.000000      0.743802             0.000000
# ...           ...       ...       ...           ...                  ...
# 355            76  0.043028  0.028685      0.086056             0.000000
# 8291           37  0.336000  0.240000      0.000000             0.000000
# 440             2  0.000000  0.000000      0.000000             0.000000
# 783            60  0.057545  0.095908      0.268542             0.000000
# 5745           64  0.100784  0.033595      0.218365             0.000000
#
#        red cards  goals conceded  clean sheets  minutes played  days_injured  \
# 3115    0.014375         0.94873      0.416866            6261           560
# 37      0.000000         0.00000      0.000000            3326           664
# 10563   0.000000         0.00000      0.000000            2237           524
# 1619    0.031131         0.00000      0.000000            5782           535
# 1317    0.000000         0.00000      0.000000             968           587
# ...          ...             ...           ...             ...           ...
# 355     0.000000         0.00000      0.000000            6275           608
# 8291    0.000000         0.00000      0.000000            1875           726
# 440     0.000000         0.00000      0.000000             169           696
# 783     0.000000         0.00000      0.000000            4692           591
# 5745    0.000000         0.00000      0.000000            5358           687
#
#        games_injured  award  current_value  highest_value  position_encoded  \
# 3115              87      5       13000000       13000000                 1
# 37                87      5        1000000       13000000                 2
# 10563             87      3         450000        1500000                 4
# 1619              87      2        2500000       24000000                 3
# 1317              87      4         800000       12000000                 3
# ...              ...    ...            ...            ...               ...
# 355              117      0       22000000       22000000                 2
# 8291             120      3        2800000        7500000                 4
# 440              121     13              0       45000000                 2
# 783              139      3        1500000        4500000                 3
# 5745             140      1         700000        2500000                 2
#
#        winger  height_z_score  days_injured_z_score  games_injured_z_score
# 3115        0        0.971383              2.526314               3.512632
# 37          0        1.401874              3.120418               3.512632
# 10563       1       -0.894078              2.320663               3.512632
# 1619        0       -0.176593              2.383501               3.512632
# 1317        0        0.684389              2.680553               3.512632
# ...       ...             ...                   ...                    ...
# 355         1       -1.611562              2.800516               4.969552
# 8291        0       -0.176593              3.474595               5.115244
# 440         1        0.540892              3.303219               5.163808
# 783         0        0.540892              2.703403               6.037960
# 5745        1       -0.176593              3.251806               6.086524
#
# [92 rows x 25 columns]

# %%
# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(football_df["games_injured_z_score"], bins=15, color="purple", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Z-score of Games Injured", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Games Injured (Z-score)", fontsize=14)
plt.axvline(0, color='red', linestyle='dashed', linewidth=2, label="Mean (0)")
plt.axvline(3.5, color='green', linestyle='dashed', linewidth=2, label="Upper Outlier Threshold (+3.5)")
plt.axvline(-3.5, color='orange', linestyle='dashed', linewidth=2, label="Lower Outlier Threshold (-3.5)")
plt.legend()
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
indexs=football_df[(football_df['games_injured_z_score'] > 3.5) | (football_df['games_injured_z_score']< -3.5)].sort_values(by='days_injured').index
football_df.drop(indexs,inplace=True)

# %%
football_df.shape
# Out:
# (10473, 25)

# %% [markdown]
# ##### football_df - award column's outliers

# %%
plt.figure(figsize=(12, 6))
plt.hist(football_df["award"], bins=10, color="gold", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Number of Awards", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Awards Won by Players", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
filter_award=football_df[football_df["award"]<20]
# Plot histogram
plt.figure(figsize=(12, 6))
plt.hist(filter_award["award"], bins=10, color="gold", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Number of Awards", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Awards Won by Players", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
filter_award.shape
# Out:
# (10414, 25)

# %%
football_df.shape
# Out:
# (10473, 25)

# %%
# Feels like the tail is never ending I'll try zscore

# %%
zscore(football_df['award'])

football_df['award_z_score'] = zscore(football_df['award'])

football_df[(football_df['award_z_score'] > 3.5) | (football_df['award_z_score']< -3.5)].sort_values(by='award')
# Out:
#                                         player  \
# 4080         /nico-gaitan/profil/spieler/75442
# 1022         /leroy-sane/profil/spieler/192565
# 3296         /felipe-melo/profil/spieler/35537
# 945         /niklas-sule/profil/spieler/166601
# 3786            /paulinho/profil/spieler/57229
# ...                                        ...
# 1507         /david-alaba/profil/spieler/59016
# 1525       /karim-benzema/profil/spieler/18922
# 1549  /robert-lewandowski/profil/spieler/38253
# 9433    /cristiano-ronaldo/profil/spieler/8198
# 2643        /lionel-messi/profil/spieler/28003
#
#                                  team                name  \
# 4080             FC Paços de Ferreira         Nico Gaitán
# 1022                    Bayern Munich          Leroy Sané
# 3296         Fluminense Football Club         Felipe Melo
# 945                 Borussia Dortmund         Niklas Süle
# 3786  Sport Club Corinthians Paulista            Paulinho
# ...                               ...                 ...
# 1507                      Real Madrid         David Alaba
# 1525                      Real Madrid       Karim Benzema
# 1549                     FC Barcelona  Robert Lewandowski
# 9433                      Al-Nassr FC   Cristiano Ronaldo
# 2643              Paris Saint-Germain        Lionel Messi
#
#                         position  height   age  appearance     goals  \
# 4080  midfield-AttackingMidfield   174.0  35.0          35  0.198151
# 1022          Attack-RightWinger   183.0  27.0          89  0.438871
# 3296  midfield-DefensiveMidfield   183.0  39.0           4  0.000000
# 945         Defender Centre-Back   195.0  27.0          79  0.048043
# 3786    midfield-CentralMidfield   183.0  34.0           8  0.450000
# ...                          ...     ...   ...         ...       ...
# 1507        Defender Centre-Back   180.0  30.0          85  0.063649
# 1525       Attack Centre-Forward   185.0  35.0          89  0.894040
# 1549       Attack Centre-Forward   185.0  34.0          92  0.938442
# 9433       Attack Centre-Forward   187.0  38.0          74  0.617780
# 2643          Attack-RightWinger   170.0  35.0          75  0.442464
#
#        assists  yellow cards  second yellow cards  red cards  goals conceded  \
# 4080  0.158520      0.118890             0.000000        0.0             0.0
# 1022  0.391850      0.141066             0.000000        0.0             0.0
# 3296  0.000000      0.649819             0.000000        0.0             0.0
# 945   0.096085      0.112100             0.000000        0.0             0.0
# 3786  0.000000      0.225000             0.000000        0.0             0.0
# ...        ...           ...                  ...        ...             ...
# 1507  0.089109      0.101839             0.000000        0.0             0.0
# 1525  0.250331      0.023841             0.000000        0.0             0.0
# 1549  0.169598      0.067839             0.011307        0.0             0.0
# 9433  0.105475      0.256153             0.000000        0.0             0.0
# 2643  0.483945      0.013827             0.000000        0.0             0.0
#
#       clean sheets  minutes played  days_injured  games_injured  award  \
# 4080           0.0            2271           307             54     15
# 1022           0.0            5742           447             75     15
# 3296           0.0             277           189             40     15
# 945            0.0            5620           360             53     15
# 3786           0.0             400           276             57     15
# ...            ...             ...           ...            ...    ...
# 1507           0.0            7070           123             26     43
# 1525           0.0            7550           156             26     53
# 1549           0.0            7960           139             22     65
# 9433           0.0            5973           168             27     90
# 2643           0.0            6509           167             30     92
#
#       current_value  highest_value  position_encoded  winger  height_z_score  \
# 4080         300000       30000000                 3       0       -1.037575
# 1022       70000000      100000000                 4       1        0.253898
# 3296         150000       19000000                 3       0        0.253898
# 945        35000000       60000000                 2       0        1.975862
# 3786        1200000       40000000                 3       0        0.253898
# ...             ...            ...               ...     ...             ...
# 1507       40000000       65000000                 2       0       -0.176593
# 1525       25000000       60000000                 4       0        0.540892
# 1549       30000000       90000000                 4       0        0.540892
# 9433       15000000      120000000                 4       0        0.827886
# 2643       45000000      180000000                 4       1       -1.611562
#
#       days_injured_z_score  games_injured_z_score  award_z_score
# 4080              1.081044               1.910020       3.587764
# 1022              1.880798               2.929864       3.587764
# 3296              0.406966               1.230124       3.587764
# 945               1.383808               1.861456       3.587764
# 3786              0.903956               2.055712       3.587764
# ...                    ...                    ...            ...
# 1507              0.029939               0.550228      11.257960
# 1525              0.218452               0.550228      13.997316
# 1549              0.121339               0.355972      17.284544
# 9433              0.287002               0.598792      24.132934
# 2643              0.281290               0.744484      24.680805
#
# [131 rows x 26 columns]

# %%
# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(football_df["award_z_score"], bins=15, color="gold", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Z-score of Awards", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Awards (Z-score)", fontsize=14)
plt.axvline(0, color='red', linestyle='dashed', linewidth=2, label="Mean (0)")
plt.axvline(3.5, color='green', linestyle='dashed', linewidth=2, label="Upper Outlier Threshold (+3.5)")
plt.axvline(-3.5, color='orange', linestyle='dashed', linewidth=2, label="Lower Outlier Threshold (-3.5)")
plt.legend()
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
# I think the best decision is to drop values above 20 because excluding more values will affect the results causing misleading

# %%
football_df.drop(columns=["award_z_score"],inplace=True)

# %% [markdown]
# ##### football_df - current_value column's outliers

# %%
# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(football_df["current_value"], bins=15, color="blue", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Current Value", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Players' Current Value", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
# The chart doesn't give a detailed information

# %%
zscore(football_df['current_value'])

football_df['current_value_z_score'] = zscore(football_df['current_value'])

football_df[(football_df['current_value_z_score'] > 3) | (football_df['current_value_z_score']< -3)].sort_values(by='current_value')
# Out:
#                                        player                        team  \
# 5731        /joao-pedro/profil/spieler/626724                  Watford FC
# 275   /joachim-andersen/profil/spieler/260827              Crystal Palace
# 162     /robert-sanchez/profil/spieler/403151  Brighton &amp; Hove Albion
# 124         /pedro-neto/profil/spieler/487465     Wolverhampton Wanderers
# 1508    /antonio-rudiger/profil/spieler/86202                 Real Madrid
# ...                                       ...                         ...
# 1017     /jamal-musiala/profil/spieler/580195               Bayern Munich
# 960    /jude-bellingham/profil/spieler/581678           Borussia Dortmund
# 1521   /vinicius-junior/profil/spieler/371998                 Real Madrid
# 453     /erling-haaland/profil/spieler/418560             Manchester City
# 2644     /kylian-mbappe/profil/spieler/342229         Paris Saint-Germain
#
#                   name                    position  height   age  appearance  \
# 5731        João Pedro       Attack Centre-Forward   182.0  21.0          64
# 275   Joachim Andersen        Defender Centre-Back   192.0  26.0          72
# 162     Robert Sánchez                  Goalkeeper   197.0  25.0          63
# 124         Pedro Neto          Attack-RightWinger   172.0  23.0          34
# 1508   Antonio Rüdiger        Defender Centre-Back   190.0  30.0         107
# ...                ...                         ...     ...   ...         ...
# 1017     Jamal Musiala  midfield-AttackingMidfield   184.0  20.0          87
# 960    Jude Bellingham    midfield-CentralMidfield   186.0  19.0          86
# 1521   Vinicius Junior           Attack-LeftWinger   176.0  22.0         107
# 453     Erling Haaland       Attack Centre-Forward   195.0  22.0          83
# 2644     Kylian Mbappé       Attack Centre-Forward   178.0  24.0          89
#
#          goals   assists  yellow cards  second yellow cards  red cards  \
# 5731  0.300000  0.100000      0.160000                  0.0   0.000000
# 275   0.014428  0.043283      0.158705                  0.0   0.000000
# 162   0.000000  0.000000      0.078947                  0.0   0.015789
# 124   0.116129  0.058065      0.232258                  0.0   0.000000
# 1508  0.071106  0.040632      0.142212                  0.0   0.000000
# ...        ...       ...           ...                  ...        ...
# 1017  0.431655  0.395683      0.071942                  0.0   0.000000
# 960   0.244798  0.257038      0.269278                  0.0   0.000000
# 1521  0.448356  0.408502      0.229160                  0.0   0.009963
# 453   1.118270  0.234699      0.124252                  0.0   0.000000
# 2644  0.963082  0.433387      0.204655                  0.0   0.000000
#
#       goals conceded  clean sheets  minutes played  days_injured  \
# 5731        0.000000           0.0            4500            74
# 275         0.000000           0.0            6238            83
# 162         1.184211           0.3            5700             0
# 124         0.000000           0.0            1550           498
# 1508        0.000000           0.0            8860           466
# ...              ...           ...             ...           ...
# 1017        0.000000           0.0            5004            66
# 960         0.000000           0.0            7353            19
# 1521        0.000000           0.0            9033            70
# 453         0.000000           0.0            6519           204
# 2644        0.000000           0.0            7476           139
#
#       games_injured  award  current_value  highest_value  position_encoded  \
# 5731             15      0       32000000       32000000                 4
# 275              12      0       32000000       32000000                 2
# 162               0      0       32000000       32000000                 1
# 124              68      2       32000000       38000000                 4
# 1508             66      9       32000000       50000000                 2
# ...             ...    ...            ...            ...               ...
# 1017              6     11      110000000      110000000                 3
# 960               4      2      120000000      120000000                 3
# 1521             12     12      150000000      150000000                 4
# 453              36     17      170000000      170000000                 4
# 2644             23     37      180000000      200000000                 4
#
#       winger  height_z_score  days_injured_z_score  games_injured_z_score  \
# 5731       0        0.110401             -0.249975               0.016024
# 275        0        1.545371             -0.198563              -0.129668
# 162        0        2.262856             -0.672703              -0.712436
# 124        1       -1.324568              2.172138               2.589916
# 1508       0        1.258377              1.989337               2.492788
# ...      ...             ...                   ...                    ...
# 1017       0        0.397395             -0.295676              -0.421052
# 960        0        0.684389             -0.564165              -0.518180
# 1521       1       -0.750581             -0.272826              -0.129668
# 453        0        1.975862              0.492654               1.035868
# 2644       0       -0.463587              0.121339               0.404536
#
#       current_value_z_score
# 5731               3.097237
# 275                3.097237
# 162                3.097237
# 124                3.097237
# 1508               3.097237
# ...                     ...
# 1017              11.615150
# 960               12.707190
# 1521              15.983310
# 453               18.167391
# 2644              19.259431
#
# [201 rows x 26 columns]

# %%
# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(football_df["current_value_z_score"], bins=15, color="blue", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Z-score of Current Value", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Players' Current Value (Z-score)", fontsize=14)
plt.axvline(0, color='red', linestyle='dashed', linewidth=2, label="Mean (0)")
plt.axvline(3, color='green', linestyle='dashed', linewidth=2, label="Upper Outlier Threshold (+3)")
plt.axvline(-3, color='orange', linestyle='dashed', linewidth=2, label="Lower Outlier Threshold (-3)")
plt.legend()
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
indexs=football_df[(football_df['current_value_z_score'] > 3) | (football_df['current_value_z_score']< -3)].index
football_df.drop(indexs,inplace=True)

# %%
football_df.shape
# Out:
# (10272, 26)

# %% [markdown]
# ##### football_df - current_value column's outliers

# %%
# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(football_df["highest_value"], bins=15, color="green", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Highest Value", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Players' Highest Value", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
zscore(football_df['highest_value'])

football_df['highest_value_z_score'] = zscore(football_df['highest_value'])

football_df[(football_df['highest_value_z_score'] > 4) | (football_df['highest_value_z_score']< -4)].sort_values(by='highest_value')
# Out:
#                                         player                team  \
# 1052        /andre-silva/profil/spieler/198008          RB Leipzig
# 4298        /david-neres/profil/spieler/469822          SL Benfica
# 3756        /arturo-vidal/profil/spieler/37666         CR Flamengo
# 519       /denis-zakaria/profil/spieler/334526          Chelsea FC
# 970    /sebastien-haller/profil/spieler/181375   Borussia Dortmund
# ...                                        ...                 ...
# 518         /ngolo-kante/profil/spieler/225083          Chelsea FC
# 1575       /paulo-dybala/profil/spieler/206050             AS Roma
# 9433    /cristiano-ronaldo/profil/spieler/8198         Al-Nassr FC
# 1501  /antoine-griezmann/profil/spieler/125781  Atlético de Madrid
# 1522         /eden-hazard/profil/spieler/50202         Real Madrid
#
#                    name                    position  height   age  appearance  \
# 1052        André Silva       Attack Centre-Forward   185.0  27.0          95
# 4298        David Neres          Attack-RightWinger   176.0  26.0          70
# 3756       Arturo Vidal    midfield-CentralMidfield   180.0  36.0          49
# 519       Denis Zakaria  midfield-DefensiveMidfield   190.0  26.0          44
# 970    Sébastien Haller       Attack Centre-Forward   191.0  28.0          65
# ...                 ...                         ...     ...   ...         ...
# 518        N'Golo Kanté  midfield-DefensiveMidfield   171.0  32.0          51
# 1575       Paulo Dybala        Attack-SecondStriker   177.0  29.0          77
# 9433  Cristiano Ronaldo       Attack Centre-Forward   187.0  38.0          74
# 1501  Antoine Griezmann        Attack-SecondStriker   176.0  32.0          87
# 1522        Eden Hazard           Attack-LeftWinger   175.0  32.0          33
#
#          goals   assists  yellow cards  second yellow cards  red cards  \
# 1052  0.403379  0.263748      0.077573                  0.0   0.000000
# 4298  0.381659  0.405513      0.143122                  0.0   0.000000
# 3756  0.104227  0.208454      0.416908                  0.0   0.000000
# 519   0.117188  0.058594      0.175781                  0.0   0.000000
# 970   0.784036  0.255267      0.127634                  0.0   0.000000
# ...        ...       ...           ...                  ...        ...
# 518   0.052972  0.158917      0.105945                  0.0   0.000000
# 1575  0.580418  0.246238      0.175884                  0.0   0.000000
# 9433  0.617780  0.105475      0.256153                  0.0   0.000000
# 1501  0.351391  0.380673      0.087848                  0.0   0.014641
# 1522  0.138996  0.277992      0.138996                  0.0   0.000000
#
#       goals conceded  clean sheets  minutes played  days_injured  \
# 1052             0.0           0.0            5801           221
# 4298             0.0           0.0            3773           415
# 3756             0.0           0.0            1727           250
# 519              0.0           0.0            3072           487
# 970              0.0           0.0            4936           287
# ...              ...           ...             ...           ...
# 518              0.0           0.0            3398           510
# 1575             0.0           0.0            5117           308
# 9433             0.0           0.0            5973           168
# 1501             0.0           0.0            6147           108
# 1522             0.0           0.0            1295           400
#
#       games_injured  award  current_value  highest_value  position_encoded  \
# 1052             15      4       20000000       45000000                 4
# 4298             49      7       22000000       45000000                 4
# 3756             41     27        1200000       45000000                 3
# 519              59      0       20000000       45000000                 3
# 970              40      6       30000000       45000000                 4
# ...             ...    ...            ...            ...               ...
# 518              76     13       20000000      100000000                 3
# 1575             57     17       30000000      110000000                 4
# 9433             27     90       15000000      120000000                 4
# 1501             18     11       25000000      150000000                 4
# 1522             59     19        5000000      150000000                 4
#
#       winger  height_z_score  days_injured_z_score  games_injured_z_score  \
# 1052       0        0.540892              0.589767               0.016024
# 4298       1       -0.750581              1.697997               1.667200
# 3756       0       -0.176593              0.755430               1.278688
# 519        0        1.258377              2.109300               2.152840
# 970        0        1.401874              0.966794               1.230124
# ...      ...             ...                   ...                    ...
# 518        0       -1.468065              2.240688               2.978428
# 1575       0       -0.607084              1.086757               2.055712
# 9433       0        0.827886              0.287002               0.598792
# 1501       0       -0.750581             -0.055749               0.161716
# 1522       1       -0.894078              1.612310               2.152840
#
#       current_value_z_score  highest_value_z_score
# 1052               1.786789               4.253117
# 4298               2.005197               4.253117
# 3756              -0.266246               4.253117
# 519                1.786789               4.253117
# 970                2.878829               4.253117
# ...                     ...                    ...
# 518                1.786789              10.081170
# 1575               2.878829              11.140816
# 9433               1.240769              12.200462
# 1501               2.332809              15.379401
# 1522               0.148729              15.379401
#
# [123 rows x 27 columns]

# %%
# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(football_df["highest_value_z_score"], bins=15, color="green", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Z-score of Highest Value", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Players' Highest Value (Z-score)", fontsize=14)
plt.axvline(0, color='red', linestyle='dashed', linewidth=2, label="Mean (0)")
plt.axvline(4, color='green', linestyle='dashed', linewidth=2, label="Upper Outlier Threshold (+4)")
plt.axvline(-4, color='orange', linestyle='dashed', linewidth=2, label="Lower Outlier Threshold (-4)")
plt.legend()
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
indexs=football_df[(football_df['highest_value_z_score'] > 4) | (football_df['highest_value_z_score']< -4)].index
football_df.drop(indexs,inplace=True)

# %%
football_df.shape
# Out:
# (10149, 27)

# %% [markdown]
# ## 3. Univariate Analysis:

# %% [markdown]
# ### 1. Univariate Graphical Analysis:
# Method to perform uni-variate analysis will depend on whether the variable type is categorical or numerical.

# %% [markdown]
# #### I. Categorical Variables:
#
# we’ll use frequency table to understand distribution of each category
# - Bar Chart (Ordinal) - Orderd
# - Pie Chart (Nominal) - non Orderd

# %%
team_counts = football_df["team"].value_counts().head(10)  # استخراج أعلى 10 فرق

# رسم المخطط الشريطي
plt.figure(figsize=(10, 6))
team_counts.plot(kind="bar", color="#52796F")

# تخصيص المخطط
plt.xlabel("Team", fontsize=12)
plt.ylabel("How frequent it showed up", fontsize=12)
plt.title("Top 10 Teams ", fontsize=14)
plt.xticks(rotation=45)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# عرض المخطط
plt.show()

# %%
# I thought that maybe the top-showing teams would affect the player's value but none of these teams are well-known ones 
# So I thought the exact opposite thing is that maybe the players with high values don't change their teams frequently(?) *Neymar is a special case

# %%
position_counts = football_df["position"].value_counts()  # حساب تكرار كل مركز

# رسم المخطط الشريطي
plt.figure(figsize=(12, 6))
position_counts.plot(kind="bar", color="darkgreen")

# تخصيص المخطط
plt.xlabel("Position", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Player Distribution by Position", fontsize=14)
plt.xticks(rotation=45)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# عرض المخطط
plt.show()

# %%
# Defender Center-Back is the most showing position it's more by almost 500 than the nearest position in the list

# %% [markdown]
# #### II. Numerical Variables:
#
# we need to understand the central tendency and spread of the variable (Descriptive Analysis) using:
#    - Box plot
#    - Histogram

# %%
football_df.dtypes
# Out:
# player                    object
# team                      object
# name                      object
# position                  object
# height                   float64
# age                      float64
# appearance                 int64
# goals                    float64
# assists                  float64
# yellow cards             float64
# second yellow cards      float64
# red cards                float64
# goals conceded           float64
# clean sheets             float64
# minutes played             int64
# days_injured               int64
# games_injured              int64
# award                      int64
# current_value              int64
# highest_value              int64
# position_encoded           int64
# winger                     int64
# height_z_score           float64
# days_injured_z_score     float64
# games_injured_z_score    float64
# current_value_z_score    float64
# highest_value_z_score    float64
# dtype: object

# %%
# رسم الهيستوغرام لعمر اللاعبين
plt.figure(figsize=(10, 6))
plt.hist(football_df["age"], bins=15, color="navy", edgecolor="black", alpha=0.7)

# تخصيص المخطط
plt.xlabel("Age", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Players' Age", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# عرض المخطط
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(football_df["goals"], fill=True, color="royalblue", alpha=0.6)

plt.xlabel("Goals Scored", fontsize=12)
plt.ylabel("Density", fontsize=12)
plt.title("KDE Plot for Goals Scored", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

plt.show()

# %%
# Since  the values are super close to each other, it didn't  make any sense seeing this in an univariate chart

# %%
plt.figure(figsize=(10, 6))
plt.hist(football_df["appearance"], bins=15, color="navy", edgecolor="black", alpha=0.7)

# تخصيص المخطط
plt.xlabel("Appearance", fontsize=12)
plt.ylabel("Number of Appearances", fontsize=12)
plt.title("Distribution of Players' Appearance", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# عرض المخطط
plt.show()

# %%
plt.figure(figsize=(10, 6))
filtered_appearance=football_df[(football_df["appearance"]<=85)]
plt.hist(filtered_appearance["appearance"], bins=15, color="navy", edgecolor="black", alpha=0.7)

# تخصيص المخطط
plt.xlabel("Appearance", fontsize=12)
plt.ylabel("Number of Appearances", fontsize=12)
plt.title("Distribution of Players' Appearance", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# عرض المخطط
plt.show()

# %%
filtered_appearance.shape
# Out:
# (9957, 27)

# %%
# Droping outliers
football_df=football_df[(football_df["appearance"]<=85)]

# %%
# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(football_df["height"], bins=15, color="navy", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("Height (cm)", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Players' Height", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(football_df["minutes played"], bins=15, color="navy", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("minutes played", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Players' minutes played", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(football_df["games_injured"], bins=15, color="navy", edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("games_injured", fontsize=12)
plt.ylabel("Number of Players", fontsize=12)
plt.title("Distribution of Players' games_injured", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %% [markdown]
# ### 2. Univariate Non-Graphical analysis:
#
# - Where is the center of the data? (location) --> **Measures of central tendency**
# - How much does the data vary? (scale) --> **Measure of variability**
# - What is the shape of the data? (shape) --> **Measures of variation combined with an average (measure of center) gives a good picture of the distribution of the data.**

# %%
football_df.describe().T
# Out:
#                         count          mean           std         min  \
# height                 9957.0  1.811811e+02  6.901045e+00  162.000000
# age                    9957.0  2.586880e+01  4.726208e+00   16.000000
# appearance             9957.0  3.416139e+01  2.487130e+01    0.000000
# goals                  9957.0  1.203574e-01  2.334925e-01    0.000000
# assists                9957.0  8.375292e-02  1.433721e-01    0.000000
# yellow cards           9957.0  1.918474e-01  4.479808e-01    0.000000
# second yellow cards    9957.0  4.718104e-03  2.563057e-02    0.000000
# red cards              9957.0  6.959828e-03  8.392591e-02    0.000000
# goals conceded         9957.0  1.345797e-01  4.495117e-01    0.000000
# clean sheets           9957.0  4.604313e-02  9.596290e-01    0.000000
# minutes played         9957.0  2.295206e+03  1.867407e+03    0.000000
# days_injured           9957.0  1.005292e+02  1.423424e+02    0.000000
# games_injured          9957.0  1.333404e+01  1.876024e+01    0.000000
# award                  9957.0  1.610023e+00  2.670440e+00    0.000000
# current_value          9957.0  2.312758e+06  4.215659e+06    0.000000
# highest_value          9957.0  3.958622e+06  6.537467e+06    0.000000
# position_encoded       9957.0  2.700613e+00  9.867812e-01    1.000000
# winger                 9957.0  3.099327e-01  4.624888e-01    0.000000
# height_z_score         9957.0 -7.114434e-03  9.902791e-01   -2.759538
# days_injured_z_score   9957.0 -9.842674e-02  8.131354e-01   -0.672703
# games_injured_z_score  9957.0 -6.488181e-02  9.110721e-01   -0.712436
# current_value_z_score  9957.0 -1.447286e-01  4.603669e-01   -0.397291
# highest_value_z_score  9957.0 -9.581672e-02  6.927402e-01   -0.515291
#
#                                  25%           50%           75%           max
# height                    176.000000  1.812404e+02  1.860000e+02  2.000000e+02
# age                        22.000000  2.500000e+01  2.900000e+01  3.900000e+01
# appearance                 11.000000  3.300000e+01  5.600000e+01  8.500000e+01
# goals                       0.000000  4.127178e-02  1.622352e-01  1.125000e+01
# assists                     0.000000  3.615910e-02  1.269841e-01  4.000000e+00
# yellow cards                0.048833  1.505017e-01  2.500000e-01  3.000000e+01
# second yellow cards         0.000000  0.000000e+00  0.000000e+00  1.000000e+00
# red cards                   0.000000  0.000000e+00  0.000000e+00  6.923077e+00
# goals conceded              0.000000  0.000000e+00  0.000000e+00  9.000000e+00
# clean sheets                0.000000  0.000000e+00  0.000000e+00  9.000000e+01
# minutes played            617.000000  1.915000e+03  3.707000e+03  7.648000e+03
# days_injured                0.000000  2.900000e+01  1.590000e+02  7.300000e+02
# games_injured               0.000000  4.000000e+00  2.100000e+01  8.600000e+01
# award                       0.000000  1.000000e+00  2.000000e+00  3.300000e+01
# current_value          275000.000000  7.000000e+05  2.500000e+06  3.000000e+07
# highest_value          400000.000000  1.200000e+06  4.000000e+06  4.200000e+07
# position_encoded            2.000000  3.000000e+00  4.000000e+00  4.000000e+00
# winger                      0.000000  0.000000e+00  1.000000e+00  1.000000e+00
# height_z_score             -0.750581  1.394214e-03  6.843892e-01  2.693347e+00
# days_injured_z_score       -0.672703 -5.070393e-01  2.355896e-01  3.497445e+00
# games_injured_z_score      -0.712436 -5.181800e-01  3.074081e-01  3.464068e+00
# current_value_z_score      -0.367260 -3.208482e-01 -1.242810e-01  2.878829e+00
# highest_value_z_score      -0.472905 -3.881330e-01 -9.143213e-02  3.935223e+00

# %% [markdown]
# ## 4. Bivariate/Multivariate Analysis:
#
# Here, you look at the relationships between two or more variables. This can involve looking for correlations, patterns, and trends that suggest a relationship or an association.
#
# We can perform bi-variate analysis for any combination of categorical and numerical variables. The combination can be:
# | bi-variate variables   | Plot type |
# | ------------- | ------------- |
# | Categorical & Categorical| Stacked Bar Chart |
# | Categorical & numerical  | scatter plot, histogram, box plot|
# | numerical  & numerical  | Scatter plot, line chart|
#
#
# Multivariate Analysis:
# - Heat map
# - Bar Chart
# - Scatter Chart
# - Line Chart

# %%
# تحديد الأعمدة العددية فقط
numeric_df = football_df.select_dtypes(include=["number"])

# حساب مصفوفة الارتباط
correlation_matrix = numeric_df.corr()
# رسم الخريطة الحرارية
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)

# تخصيص المخطط
plt.title("Correlation Heatmap of Football Data", fontsize=14)
plt.show()

# %%
correlation = football_df[["age", "current_value"]].corr().iloc[0, 1]
print(f"Correlation between Age and Current Value: {correlation:.2f}")

# Plot scatter plot with regression line
plt.figure(figsize=(8, 6))
sns.regplot(x=football_df["age"], y=football_df["current_value"], scatter_kws={"alpha": 0.6}, line_kws={"color": "red"})

# Customize plot
plt.xlabel("Age", fontsize=12)
plt.ylabel("Current Value", fontsize=12)
plt.title(f"Age vs. Current Value (Correlation: {correlation:.2f})", fontsize=14)
plt.grid(True)

# Show plot
plt.show()
# Out:
# Correlation between Age and Current Value: -0.07

# %%
# Seems like the age and current value relationship is weak but its still when the age is larger the less the value

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=football_df["award"], y=football_df["current_value"], alpha=0.6)

plt.xlabel("Number of Awards", fontsize=12)
plt.ylabel("Current Market Value", fontsize=12)
plt.title("Relationship Between Awards and Current Value", fontsize=14)
plt.grid(True)

# Show the plot
plt.show()

# %%
# I see players with higher market values spread across different award counts.
# This means that having a high current value doesn't necessarily mean having a lot of awards.

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=football_df["appearance"], y=football_df["current_value"], alpha=0.6, label="Players")
sns.regplot(x=football_df["appearance"], y=football_df["current_value"], scatter=False, color="red", line_kws={"linewidth":2}, label="Trend Line")

# تخصيص المخطط
plt.xlabel("Number of Appearances", fontsize=12)
plt.ylabel("Current Market Value", fontsize=12)
plt.title("Relationship Between Appearances and Current Value", fontsize=14)
plt.legend()
plt.grid(True)

# عرض المخطط
plt.show()

# %%
# Players with many appearances may have high current value but not necessarily

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Feature Selection

# %%
football_df.dtypes
# Out:
# player                    object
# team                      object
# name                      object
# position                  object
# height                   float64
# age                      float64
# appearance                 int64
# goals                    float64
# assists                  float64
# yellow cards             float64
# second yellow cards      float64
# red cards                float64
# goals conceded           float64
# clean sheets             float64
# minutes played             int64
# days_injured               int64
# games_injured              int64
# award                      int64
# current_value              int64
# highest_value              int64
# position_encoded           int64
# winger                     int64
# height_z_score           float64
# days_injured_z_score     float64
# games_injured_z_score    float64
# current_value_z_score    float64
# highest_value_z_score    float64
# dtype: object

# %%
categorical_features = ['team', 'name', 'position']

# %%
# Need to drop these columns cuz feature engineering didn't work so I want to make the load less
football_df = football_df.drop(columns=[
    "height_z_score",
    "days_injured_z_score",
    "games_injured_z_score",
    "current_value_z_score",
    "highest_value_z_score",
    "player"
])

# %%
football_df = pd.get_dummies(football_df, columns=categorical_features)

# %%
football_df.shape
# Out:
# (9957, 10223)

# %%
correlation = football_df.corr()
print(correlation['current_value'].sort_values(ascending=False))
# Out:
# current_value          1.000000
# highest_value          0.790057
# appearance             0.417712
# minutes played         0.400049
# games_injured          0.173203
#                          ...
# position_Attack       -0.039025
# position_midfield     -0.046545
# age                   -0.069682
# goals conceded        -0.074137
# position_Goalkeeper   -0.097639
# Name: current_value, Length: 10223, dtype: float64

# %%
# Set the correlation threshold
threshold = 0.1

# Filter the correlations
# We use `abs()` for absolute value to consider both strong positive and negative correlations
selected_features = correlation[abs(correlation['current_value']) > threshold]['current_value'].index
selected_features
# Out:
# Index(['appearance', 'assists', 'minutes played', 'days_injured',
#        'games_injured', 'award', 'current_value', 'highest_value',
#        'team_Arsenal FC', 'team_Aston Villa', 'team_Atalanta BC',
#        'team_Chelsea FC', 'team_Everton FC', 'team_Leeds United',
#        'team_Leicester City', 'team_Southampton FC',
#        'team_Wolverhampton Wanderers'],
#       dtype='object')

# %%
selected_features =['appearance', 'assists', 'minutes played', 'days_injured',
       'games_injured', 'award', 'current_value', 'highest_value',
       'team_Arsenal FC', 'team_Aston Villa', 'team_Atalanta BC',
       'team_Chelsea FC', 'team_Everton FC', 'team_Leeds United',
       'team_Leicester City', 'team_Southampton FC',
       'team_Wolverhampton Wanderers']

# %%
football_df = football_df[selected_features]
football_df.head()
# Out:
#     appearance   assists  minutes played  days_injured  games_injured  award  \
# 1           15  0.000000            1304           510             58      1
# 2            4  0.000000             292           697             84      4
# 6           70  0.032901            5471            95             19     10
# 8           34  0.000000            2758            47             13      0
# 11          34  0.033507            2686           175             28      1
#
#     current_value  highest_value  team_Arsenal FC  team_Aston Villa  \
# 1         1500000       22000000            False             False
# 2          600000        6000000            False             False
# 6        15000000       35000000            False             False
# 8         2000000        2000000            False             False
# 11       10000000       12000000            False             False
#
#     team_Atalanta BC  team_Chelsea FC  team_Everton FC  team_Leeds United  \
# 1              False            False            False              False
# 2              False            False            False              False
# 6              False            False            False              False
# 8              False            False            False              False
# 11             False            False            False              False
#
#     team_Leicester City  team_Southampton FC  team_Wolverhampton Wanderers
# 1                 False                False                         False
# 2                 False                False                         False
# 6                 False                False                         False
# 8                 False                False                         False
# 11                False                False                         False

# %%
football_df.shape
# Out:
# (9957, 17)

# %% [markdown]
# ## Prepare Train and Test Data

# %%
# Prepare data
X = football_df.drop(['current_value'], axis=1)
y = football_df['current_value']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.2,
                                                    shuffle=True,
                                                    random_state=42)

# scale the data
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X.shape
# Out:
# (9957, 16)

# %% [markdown]
# # Building The Model

# %%
model = LinearRegression()

# %%
ridge_model = Ridge()

# %%
lasso_model = Lasso()

# %%
param_grid = {
    'alpha': [0, 0.003, 0.0002, 0.0001, 0.01, 0.5, 1, 5]  # Regularization strength
}
grid_search_ridge = GridSearchCV(estimator=ridge_model,
                           param_grid=param_grid,
                           cv=5,
                           scoring='neg_mean_squared_error', 
                           verbose=1)

grid_search_lasso = GridSearchCV(estimator=lasso_model,
                           param_grid=param_grid,
                           cv=5,
                           scoring='neg_mean_squared_error', 
                           verbose=1)

# %% [markdown]
# # Regularization

# %%
# Fit GridSearchCV on the training data
grid_search_ridge.fit(X_train_scaled, y_train)
grid_search_lasso.fit(X_train_scaled, y_train)

# Get the best parameters and best model

# Ridge
best_params_ridge = grid_search_ridge.best_params_
best_model_ridge = grid_search_ridge.best_estimator_

# Lasso
best_params_lasso = grid_search_lasso.best_params_
best_model_lasso = grid_search_lasso.best_estimator_

print("Best Parameters for ridge model:", best_params_ridge)
print("Best Parameters for lasso model:", best_params_lasso)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# Best Parameters for ridge model: {'alpha': 1}
# Best Parameters for lasso model: {'alpha': 0}

# %%
# Predict and evaluate the model

y_pred = model.predict(X_test_scaled)                  # Linear regression model
y_pred_ridge = best_model_ridge.predict(X_test_scaled) # Ridge model
y_pred_lasso = best_model_lasso.predict(X_test_scaled) # Lasso model

# %%
coeff_df = pd.DataFrame(model.coef_,X.columns,columns=['Coefficient'])                  # Linear model cofficients
coeff_df_ridge = pd.DataFrame(best_model_ridge.coef_,X.columns,columns=['Coefficient']) # Ridge model cofficients
coeff_df_lasso = pd.DataFrame(best_model_lasso.coef_,X.columns,columns=['Coefficient']) # Lasso model cofficients

# %%
coeff_df
# Out:
#                                Coefficient
# appearance                   -1.710825e+05
# assists                       1.501824e+05
# minutes played                6.712557e+05
# days_injured                  2.924883e+05
# games_injured                -6.846912e+05
# award                        -5.350150e+05
# highest_value                 3.287675e+06
# team_Arsenal FC               2.537974e+05
# team_Aston Villa              1.745037e+05
# team_Atalanta BC              1.602954e+05
# team_Chelsea FC               1.636565e+05
# team_Everton FC               1.446771e+05
# team_Leeds United             2.754231e+05
# team_Leicester City           1.998838e+05
# team_Southampton FC           2.632366e+05
# team_Wolverhampton Wanderers  1.855408e+05

# %%
coeff_df_ridge
# Out:
#                                Coefficient
# appearance                   -1.699251e+05
# assists                       1.501137e+05
# minutes played                6.702867e+05
# days_injured                  2.911937e+05
# games_injured                -6.832334e+05
# award                        -5.348223e+05
# highest_value                 3.286930e+06
# team_Arsenal FC               2.537918e+05
# team_Aston Villa              1.745644e+05
# team_Atalanta BC              1.603320e+05
# team_Chelsea FC               1.636817e+05
# team_Everton FC               1.447465e+05
# team_Leeds United             2.754494e+05
# team_Leicester City           1.998915e+05
# team_Southampton FC           2.632535e+05
# team_Wolverhampton Wanderers  1.855669e+05

# %%
coeff_df_lasso
# Out:
#                                Coefficient
# appearance                   -1.710825e+05
# assists                       1.501824e+05
# minutes played                6.712557e+05
# days_injured                  2.924883e+05
# games_injured                -6.846912e+05
# award                        -5.350150e+05
# highest_value                 3.287675e+06
# team_Arsenal FC               2.537974e+05
# team_Aston Villa              1.745037e+05
# team_Atalanta BC              1.602954e+05
# team_Chelsea FC               1.636565e+05
# team_Everton FC               1.446771e+05
# team_Leeds United             2.754231e+05
# team_Leicester City           1.998838e+05
# team_Southampton FC           2.632366e+05
# team_Wolverhampton Wanderers  1.855408e+05

# %% [markdown]
# # Train The Model

# %%
# Fit the model on the training data
model.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Test The Model

# %%
# Predict and evaluate the model
y_pred = model.predict(X_test_scaled)      # Linear regression model

# %% [markdown]
# # Interpretation of the Model

# %%
coeff_df = pd.DataFrame(model.coef_,X.columns,columns=['Coefficient'])   # Linear model cofficients

# %%
coeff_df
# Out:
#                                Coefficient
# appearance                   -1.710825e+05
# assists                       1.501824e+05
# minutes played                6.712557e+05
# days_injured                  2.924883e+05
# games_injured                -6.846912e+05
# award                        -5.350150e+05
# highest_value                 3.287675e+06
# team_Arsenal FC               2.537974e+05
# team_Aston Villa              1.745037e+05
# team_Atalanta BC              1.602954e+05
# team_Chelsea FC               1.636565e+05
# team_Everton FC               1.446771e+05
# team_Leeds United             2.754231e+05
# team_Leicester City           1.998838e+05
# team_Southampton FC           2.632366e+05
# team_Wolverhampton Wanderers  1.855408e+05

# %%
print(f" Linear regression intercept: {model.intercept_}")
# Out:
#  Linear regression intercept: 2303042.0590081606

# %% [markdown]
# # Evaluating The Model

# %% [markdown]
# ### Mean Square Error

# %%
y_base = [y_train.mean()] * len(y_test)

# %%
y_base
# Out:
# [2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  2303042.0590081606,
#  ...]

# %%
# our benchmark model
mse_base = mean_squared_error(y_test, y_base )
print(f'Mean Squared Error of base model: {mse_base:2e}')
# Out:
# Mean Squared Error of base model: 1.919862e+13

# %%
r2_base = r2_score(y_test, y_base)
print(f'R Square for base model: {r2_base}')
# Out:
# R Square for base model: -0.00012286237134651046

# %%
print(f" Linear regression intercept: {model.intercept_}") 
print(f" Ridge model intercept: {best_model_ridge.intercept_}") 
print(f" Lasso model intercept: {best_model_lasso.intercept_}")
# Out:
#  Linear regression intercept: 2303042.0590081606
#  Ridge model intercept: 2303042.0590081606
#  Lasso model intercept: 2303042.0590081606

# %% [markdown]
# ### Mean Square Error

# %%
# MSE for Linear model
mse_train = mean_squared_error(y_train, model.predict(X_train_scaled))
mse_test = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error for training: {mse_train:2e}')
print(f'Mean Squared Error for testing: {mse_test:2e}')
# Out:
# Mean Squared Error for training: 5.423987e+12
# Mean Squared Error for testing: 6.422032e+12

# %%
# MSE for Ridge model
mse_train_ridge = mean_squared_error(y_train, best_model_ridge.predict(X_train_scaled))
mse_test_ridge = mean_squared_error(y_test, y_pred_ridge)
print(f'Mean Squared Error for training ridge model: {mse_train_ridge:2e}')
print(f'Mean Squared Error for testing ridge model: {mse_test_ridge:2e}')
# Out:
# Mean Squared Error for training ridge model: 5.423988e+12
# Mean Squared Error for testing ridge model: 6.422377e+12

# %%
# MSE Lasso model
mse_train_lasso = mean_squared_error(y_train, best_model_lasso.predict(X_train_scaled))
mse_test_lasso = mean_squared_error(y_test, y_pred_lasso)
print(f'Mean Squared Error for training lasso model: {mse_train_lasso:2e}')
print(f'Mean Squared Error for testing lasso model: {mse_test_lasso:2e}')
# Out:
# Mean Squared Error for training lasso model: 5.423987e+12
# Mean Squared Error for testing lasso model: 6.422032e+12

# %% [markdown]
# ### Mean Absolute Error

# %%
# our benchmark model
mae_base = mean_absolute_error(y_test, y_base )
print(f'Mean Absolute  Error of base model: {mae_base:2e}')
# Out:
# Mean Absolute  Error of base model: 2.554059e+06

# %%
# Linear model
mae_train = mean_absolute_error(y_train, model.predict(X_train_scaled))
mae_test = mean_absolute_error(y_test, y_pred)
print(f'Mean Absolute Error for training: {mae_train:2e}')
print(f'Mean Absolute Error for testing: {mae_test:2e}')
# Out:
# Mean Absolute Error for training: 1.272488e+06
# Mean Absolute Error for testing: 1.328939e+06

# %%
# MSE for Ridge model
mae_train_ridge = mean_absolute_error(y_train, best_model_ridge.predict(X_train_scaled))
mae_test_ridge = mean_absolute_error(y_test, y_pred_ridge)
print(f'Mean Absolute Error for training ridge model: {mae_train_ridge:2e}')
print(f'Mean Absolute Error for testing ridge model: {mae_test_ridge:2e}')
# Out:
# Mean Absolute Error for training ridge model: 1.272475e+06
# Mean Absolute Error for testing ridge model: 1.328936e+06

# %%
# Lasso model
mae_train_lasso = mean_absolute_error(y_train, best_model_lasso.predict(X_train_scaled))
mae_test_lasso = mean_absolute_error(y_test, y_pred_lasso)
print(f'Mean Absolute Error for training lasso model: {mae_train_lasso:2e}')
print(f'Mean Absolute Error for testing lasso model: {mae_test_lasso:2e}')
# Out:
# Mean Absolute Error for training lasso model: 1.272488e+06
# Mean Absolute Error for testing lasso model: 1.328939e+06

# %% [markdown]
# ### Root Mean Squared Error

# %%
# our benchmark model
print(f'Root Mean Squared  Error of base model: {np.sqrt(mse_base):2e}')
# Out:
# Root Mean Squared  Error of base model: 4.381623e+06

# %%
# RMSE for Linear model

print(f'Root Mean Squared Error for training: {np.sqrt(mse_train):2e}')
print(f'Root Mean Squared Error for testing: {np.sqrt(mse_test):2e}')
# Out:
# Root Mean Squared Error for training: 2.328946e+06
# Root Mean Squared Error for testing: 2.534173e+06

# %%
# RMSE for Ridge model

print(f'Root Mean Squared Error for training ridge model: {np.sqrt(mse_train_ridge):2e}')
print(f'Root Mean Squared Error for testing ridge model: {np.sqrt(mse_test_ridge):2e}')
# Out:
# Root Mean Squared Error for training ridge model: 2.328946e+06
# Root Mean Squared Error for testing ridge model: 2.534241e+06

# %%
# RMSE Lasso model

print(f'Root Mean Squared Error for training lasso model: {np.sqrt(mse_train_lasso):2e}')
print(f'Root Mean Squared Error for testing lasso model: {np.sqrt(mse_test_lasso):2e}')
# Out:
# Root Mean Squared Error for training lasso model: 2.328946e+06
# Root Mean Squared Error for testing lasso model: 2.534173e+06

# %% [markdown]
# ### Predictions vs. Real Values

# %%
predictions = model.predict(X_test_scaled)
#predictions

# %%
predictions
# Out:
# array([ 761867.00272055,  328846.24387507,  888066.81304212, ...,
#         234251.0771541 ,  459869.996186  , 1994030.52866583])

# %%
Real_Values = np.array(y_test)
# Real_Values

# %%
plt.scatter(Real_Values, predictions)
plt.plot([Real_Values.min(), Real_Values.max()], [Real_Values.min(), Real_Values.max()], color='red', lw=1)
plt.xlabel('Real Values')
plt.ylabel('Predictions')
plt.title('Real Values vs Predictions')
plt.show()

# %%
sns.histplot((y_test - predictions), bins=50, kde=True)
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Distribution of Residuals")
plt.show()

# %% [markdown]
# # R-Square

# %%
r2_score_train = r2_score(y_train, model.predict(X_train_scaled))
r2_score_test = r2_score(y_test, y_pred)
print(f'R Square for training: {r2_score_train}')
print(f'R Square for testing: {r2_score_test}')
# Out:
# R Square for training: 0.6885061643536927
# R Square for testing: 0.665453957259351

# %%
# Ridge model r2 score
r2_score_train_ridge = r2_score(y_train, best_model_ridge.predict(X_train_scaled))
r2_score_test_ridge = r2_score(y_test, y_pred_ridge)
print(f'R Square for training ridge model: {r2_score_train_ridge}')
print(f'R Square for testing ridge model: {r2_score_test_ridge}')
# Out:
# R Square for training ridge model: 0.6885061302010334
# R Square for testing ridge model: 0.6654359916660644

# %%
# Lasso model r2 score
r2_score_train_lasso = r2_score(y_train, best_model_lasso.predict(X_train_scaled))
r2_score_test_lasso = r2_score(y_test, y_pred_lasso)
print(f'R Square for training lasso model: {r2_score_train_lasso}')
print(f'R Square for testing lasso model: {r2_score_test_lasso}')
# Out:
# R Square for training lasso model: 0.6885061643536927
# R Square for testing lasso model: 0.665453957259351

# %%
alpha_values = np.logspace(-6, 1, 20) 

# Ridge Regression
ridge_grid = GridSearchCV(ridge, {'alpha': alpha_values}, cv=5, scoring='r2')
ridge_grid.fit(X_train, y_train)

# Lasso Regression
lasso_grid = GridSearchCV(lasso, {'alpha': alpha_values}, cv=5, scoring='r2')
lasso_grid.fit(X_train, y_train)

print(f"best Alpha for Ridge: {ridge_grid.best_params_['alpha']}")
print(f"best Alpha for Lasso: {lasso_grid.best_params_['alpha']}")

best_ridge = ridge_grid.best_estimator_
best_lasso = lasso_grid.best_estimator_
# Out:
# best Alpha for Ridge: 1.8329807108324339
# best Alpha for Lasso: 10.0

# %%
# Linear Model
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.scatter(y_test, y_pred)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', lw=1)
plt.xlabel('Real Values')
plt.ylabel('Predictions')
plt.title('Linear Model: Real Values vs Predictions')

# Ridge Model
plt.subplot(1, 3, 2)
plt.scatter(y_test, y_pred_ridge)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', lw=1)
plt.xlabel('Real Values')
plt.ylabel('Predictions')
plt.title('Ridge Model: Real Values vs Predictions')

# Lasso Model
plt.subplot(1, 3, 3)
plt.scatter(y_test, y_pred_lasso)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', lw=1)
plt.xlabel('Real Values')
plt.ylabel('Predictions')
plt.title('Lasso Model: Real Values vs Predictions')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
sns.distplot((y_test - y_pred), bins=50)
plt.title('Linear Model Residuals')

plt.subplot(1, 3, 2)
sns.distplot((y_test - y_pred_ridge), bins=50)
plt.title('Ridge Model Residuals')

plt.subplot(1, 3, 3)
sns.distplot((y_test - y_pred_lasso), bins=50)
plt.title('Lasso Model Residuals')

plt.tight_layout()
plt.show()

# %% [raw]
# Lasso and Ridge are doing zero difference

# %% [markdown]
# # Logistic Regression

# %%
# Calculate the 35th and 75th percentiles of the price
p35 = football_df['current_value'].quantile(0.35)
p75 = football_df['current_value'].quantile(0.75)

# Function to categorize prices
def categorize_price(current_value):
    if current_value < p35:
        return 'Low Market Price'
    elif current_value < p75:
        return 'Good Market Price'
    else:
        return 'High Market Price'

# Apply the function to create a new column
football_df["player's_current_value_category"] = football_df['current_value'].apply(categorize_price)

football_df.drop('current_value', axis=1, inplace=True)

# Verify the distribution of the new categories
print(football_df["player's_current_value_category"].value_counts())
# Out:
# player's_current_value_category
# Good Market Price    4225
# Low Market Price     3239
# High Market Price    2493
# Name: count, dtype: int64

# %%
p35, p75
# Out:
# (400000.0, 2500000.0)

# %%
football_df.dtypes
# Out:
# appearance                                   int64
# assists                                    float64
# minutes played                               int64
# days_injured                                 int64
# games_injured                                int64
# award                                        int64
# highest_value                                int64
# team_Arsenal FC                               bool
# team_Aston Villa                              bool
# team_Atalanta BC                              bool
# team_Chelsea FC                               bool
# team_Everton FC                               bool
# team_Leeds United                             bool
# team_Leicester City                           bool
# team_Southampton FC                           bool
# team_Wolverhampton Wanderers                  bool
# player's_current_value_category             object
# player's_current_value_category_encoded      int32
# dtype: object

# %%
encoder = LabelEncoder()
football_df["player's_current_value_category_encoded"]= encoder.fit_transform(football_df["player's_current_value_category"])

# %%
correlation = football_df.corr(numeric_only=True)
#print(correlation['Price'].sort_values(ascending=False))
print(correlation["player's_current_value_category_encoded"].sort_values(ascending=False))
# Out:
# player's_current_value_category_encoded    1.000000
# team_Atalanta BC                           0.007972
# team_Southampton FC                        0.005891
# team_Everton FC                            0.005293
# team_Arsenal FC                            0.003463
# team_Wolverhampton Wanderers               0.002931
# team_Chelsea FC                            0.000634
# team_Leicester City                       -0.000051
# team_Leeds United                         -0.004530
# team_Aston Villa                          -0.006552
# highest_value                             -0.076741
# assists                                   -0.091043
# award                                     -0.115768
# days_injured                              -0.144729
# games_injured                             -0.152388
# minutes played                            -0.234516
# appearance                                -0.253232
# Name: player's_current_value_category_encoded, dtype: float64

# %%
threshold = 0.2 

selected_features = correlation[abs(correlation["player's_current_value_category_encoded"]) > \
threshold]["player's_current_value_category_encoded"].index
selected_features
# Out:
# Index(['appearance', 'minutes played',
#        'player's_current_value_category_encoded'],
#       dtype='object')

# %%
selected_features = ['appearance', 'minutes played',
       "player's_current_value_category_encoded"]

# %%
categorical_features = ["player's_current_value_category"]

# %%
football_df = pd.get_dummies(football_df, columns=categorical_features)

# %%
# Prepare data
X = football_df.drop(["player's_current_value_category_encoded"], axis=1)
y = football_df["player's_current_value_category_encoded"]

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.2,
                                                    shuffle=True,
                                                    random_state=42)

# sacle the data
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Building The Model

# %%
model1 = LogisticRegression()

# %%
model1.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
# Predict and evaluate the model
y_pred_test = model1.predict(X_test_scaled)

# %%
coeff_df = pd.DataFrame(model1.coef_[2],X.columns,columns=['Coefficient'])
coeff_df
# Out:
#                                                    Coefficient
# appearance                                           -0.155353
# assists                                              -0.050475
# minutes played                                       -0.117216
# days_injured                                         -0.035568
# games_injured                                        -0.037946
# award                                                -0.008314
# highest_value                                        -0.314521
# team_Arsenal FC                                      -0.001235
# team_Aston Villa                                     -0.009324
# team_Atalanta BC                                      0.009146
# team_Chelsea FC                                      -0.012038
# team_Everton FC                                      -0.003909
# team_Leeds United                                    -0.012982
# team_Leicester City                                  -0.011383
# team_Southampton FC                                  -0.005200
# team_Wolverhampton Wanderers                          0.001048
# player's_current_value_category_Good Market Price    -1.402522
# player's_current_value_category_High Market Price    -1.055994
# player's_current_value_category_Low Market Price      2.457068

# %%
model1.coef_
# Out:
# array([[ 3.42541977e-02,  1.38210991e-02,  1.15727521e-02,
#          2.61659944e-02,  3.07185492e-02,  4.56384825e-02,
#         -1.24569421e-01, -1.99293295e-02,  9.58205002e-03,
#         -3.57724496e-02, -1.00800680e-02, -3.24073062e-02,
#         -8.62702179e-03, -5.15462906e-03, -3.35516161e-02,
#         -1.93955328e-02,  2.55411077e+00, -1.31007336e+00,
#         -1.47916832e+00],
#        [ 1.21098659e-01,  3.66538528e-02,  1.05643678e-01,
#          9.40160999e-03,  7.22712260e-03, -3.73241499e-02,
#          4.39090080e-01,  2.11647557e-02, -2.58221471e-04,
#          2.66259948e-02,  2.21184042e-02,  3.63164744e-02,
#          2.16090117e-02,  1.65375295e-02,  3.87519036e-02,
#          1.83479679e-02, -1.15158864e+00,  2.36606724e+00,
#         -9.77900059e-01],
#        [-1.55352857e-01, -5.04749518e-02, -1.17216430e-01,
#         -3.55676044e-02, -3.79456718e-02, -8.31433251e-03,
#         -3.14520658e-01, -1.23542612e-03, -9.32382855e-03,
#          9.14645483e-03, -1.20383363e-02, -3.90916823e-03,
#         -1.29819899e-02, -1.13829005e-02, -5.20028748e-03,
#          1.04756488e-03, -1.40252213e+00, -1.05599388e+00,
#          2.45706838e+00]])

# %%
# Evaluating The Model

# %%
# our benchmark model
base_model = round(football_df["player's_current_value_category_encoded"].value_counts()[1]/football_df.shape[0]*100, 2)
base_model
# Out:
# 25.04

# %%
# Train score
y_pred_train = model1.predict(X_train_scaled)
accuracy_Train = accuracy_score(y_train, y_pred_train)
accuracy_Train
# Out:
# 1.0

# %%
# Test score
accuracy_test = accuracy_score(y_test, y_pred_test)
accuracy_test
# Out:
# 1.0

# %%
conf_matrix = confusion_matrix(y_test, y_pred_test)
conf_matrix
# Out:
# array([[858,   0,   0],
#        [  0, 487,   0],
#        [  0,   0, 647]], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_predictions(y_test, y_pred_test,
                                        display_labels=model1.classes_,
                                        cmap="Blues",
                                        xticks_rotation='vertical')
plt.title('Confusion Matrix')
plt.show()

# %%
# Precision

# %%
# Train score
precision_train = precision_score(y_train, y_pred_train, average='macro')
print(f"Precision in train: {precision_train:.2f}")

# Test score
precision_test = precision_score(y_test, y_pred_test, average='macro')
print(f"Precision in test: {precision_test:.2f}")
# Out:
# Precision in train: 1.00
# Precision in test: 1.00

# %%
# Recall

# %%
# Train score
recall_train = recall_score(y_train, y_pred_train, average='macro')
print(f"Recall in train: {recall_train:.2f}")

# Test score
recall_test = recall_score(y_test, y_pred_test, average='macro')
print(f"Recall in test: {recall_test:.2f}")
# Out:
# Recall in train: 1.00
# Recall in test: 1.00

# %%
# F1 Score

# %%
# Train score
f1_train = f1_score(y_train, y_pred_train, average='macro')
print(f"f1-score in train: {f1_train:.2f}")

# Test score
f1_test = precision_score(y_test, y_pred_test, average='macro')
print(f"f1-score in test: {f1_test:.2f}")
# Out:
# f1-score in train: 1.00
# f1-score in test: 1.00

# %%
from sklearn.metrics import classification_report

print('Train report: ')
print(classification_report(y_train, y_pred_train))

print('Test report: ')
print(classification_report(y_test, y_pred_test))
# Out:
# Train report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3367
#            1       1.00      1.00      1.00      2006
#            2       1.00      1.00      1.00      2592
#
#     accuracy                           1.00      7965
#    macro avg       1.00      1.00      1.00      7965
# weighted avg       1.00      1.00      1.00      7965
#
# Test report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       858
#            1       1.00      1.00      1.00       487
#            2       1.00      1.00      1.00       647
#
#     accuracy                           1.00      1992
#    macro avg       1.00      1.00      1.00      1992
# weighted avg       1.00      1.00      1.00      1992

# %% [raw]
# I Tried all I know to get better results in linear regression, changed the threshold larger smaller none worked tried again with removing more outliers same results
# some of my changes may not be included because I reruned every thing everytime it comes out don't making any improves BUT I REALLY tried

# %% [markdown]
# # Other Models

# %% [markdown]
# ## Building The Model

# %%
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)

# %% [markdown]
# ## Train The Model

# %%
# It was working till I did the rerun :)
rf_model.fit(X_test_scaled, y_train)

# %% [markdown]
# ## Test The Model

# %%
predictions = rf_model.predict(X_test_scaled)

# %% [markdown]
# ## Evaluating The Model

# %% [markdown]
# ### Mean Square Error

# %%
y_base = [y_train.mean()] * len(y_test)

# %%
y_base

# %%
# our benchmark model
mse_base = mean_squared_error(y_test, y_base)
print(f'Mean Squared Error of base model: {mse_base:2e}')
# Out:
# Mean Squared Error of base model: 1.885992e+13

# %% [markdown]
# ### Mean Square Error

# %%
mse_train = mean_squared_error(y_train, rf_model.predict(X_train_scaled))
mse_test = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error for training: {mse_train:2e}')
print(f'Mean Squared Error for testing: {mse_test:2e}')

# %% [markdown]
# ### Mean Absolute Error

# %%
# our benchmark model
mae_base = mean_absolute_error(y_test, y_base )
print(f'Mean Absolute  Error of base model: {mae_base:2e}')

# %%
mae_train = mean_absolute_error(y_train, rf_model.predict(X_train_scaled))
mae_test = mean_absolute_error(y_test, y_pred)
print(f'Mean Absolute Error for training: {mae_train:2e}')
print(f'Mean Absolute Error for testing: {mae_test:2e}')

# %% [markdown]
# ### Root Mean Squared Error

# %%
# our benchmark model
print(f'Root Mean Squared  Error of base model: {np.sqrt(mse_base):2e}')

# %%
print(f'Root Mean Squared Error for training: {np.sqrt(mse_train):2e}')
print(f'Root Mean Squared Error for testing: {np.sqrt(mse_test):2e}')

# %% [markdown]
# ### Predictions vs. Real Values

# %%
predictions = rf_model.predict(X_test_scaled)
#predictions

# %%
predictions

# %%
Real_Values = np.array(y_test)
# Real_Values

# %%
importances = rf_model.feature_importances_
feature_importance_df = pd.DataFrame({'Feature': X_train.columns, 'Importance': importances})
print(feature_importance_df.sort_values(by='Importance', ascending=False))

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_test, predictions, alpha=0.6)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linestyle='--')
plt.xlabel('Actual Values')
plt.ylabel('Predictions')
plt.title('Predictions vs Actual Values')
plt.grid()
plt.show()

# %%
# Plotting Distribution of Residuals
plt.figure(figsize=(10, 6))
sns.histplot((y_test - predictions), bins=50, kde=True)
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.title('Distribution of Residuals')
plt.grid()
plt.show()

# %% [markdown]
# ### R- Square

# %%
r2_score_train = r2_score(y_train, rf_model.predict(X_train_scaled))
r2_score_test = r2_score(y_test, y_pred)
print(f'R Square for training: {r2_score_train}')
print(f'R Square for testing: {r2_score_test}')

# %% [markdown]
# ## Building The Model

# %%
# Initialize the XGBoost model
xg_model = XGBRegressor(n_estimators=100, random_state=42)

# %% [markdown]
# ## Train Model

# %%
# Fit the model using the scaled training data
xg_model.fit(X_train_scaled, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %% [markdown]
# ## Test The Model

# %%
# Make predictions on the scaled test data
predictions_xg = xg_model.predict(X_test_scaled)

# %% [markdown]
# ## Evaluating The Model

# %% [markdown]
# ### Mean Square Error

# %%
y_base = [y_train.mean()] * len(y_test)

# %%
y_base
# Out:
# [2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  2479058.917786269,
#  ...]

# %%
# our benchmark model
mse_base = mean_squared_error(y_test, y_base)
print(f'Mean Squared Error of base model: {mse_base:2e}')
# Out:
# Mean Squared Error of base model: 1.885992e+13

# %% [markdown]
# ### Mean Square Error

# %%
# MSE 
mse_train = mean_squared_error(y_train, xg_model.predict(X_train_scaled))
mse_test = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error for training: {mse_train:2e}')
print(f'Mean Squared Error for testing: {mse_test:2e}')
# Out:
# Mean Squared Error for training: 5.086670e+11
# Mean Squared Error for testing: 6.273010e+12

# %% [markdown]
# ### Mean Absolute Error

# %%
# our benchmark model
mae_base = mean_absolute_error(y_test, y_base )
print(f'Mean Absolute  Error of base model: {mae_base:2e}')
# Out:
# Mean Absolute  Error of base model: 2.645631e+06

# %%
mae_train = mean_absolute_error(y_train, xg_model.predict(X_train_scaled))
mae_test = mean_absolute_error(y_test, y_pred)
print(f'Mean Absolute Error for training: {mae_train:2e}')
print(f'Mean Absolute Error for testing: {mae_test:2e}')
# Out:
# Mean Absolute Error for training: 4.133219e+05
# Mean Absolute Error for testing: 1.387276e+06

# %% [markdown]
# ### Root Mean Squared Error

# %%
# our benchmark model
print(f'Root Mean Squared  Error of base model: {np.sqrt(mse_base):2e}')
# Out:
# Root Mean Squared  Error of base model: 4.342801e+06

# %%
# RMSE 

print(f'Root Mean Squared Error for training: {np.sqrt(mse_train):2e}')
print(f'Root Mean Squared Error for testing: {np.sqrt(mse_test):2e}')
# Out:
# Root Mean Squared Error for training: 7.132089e+05
# Root Mean Squared Error for testing: 2.504598e+06

# %% [markdown]
# ### Predictions vs. Real Values

# %%
predictions = xg_model.predict(X_test_scaled)
#predictions

# %%
predictions
# Out:
# array([2618934.5  ,  120362.266,  604862.56 , ..., 1080096.9  ,
#         528805.56 ,  553520.4  ], dtype=float32)

# %%
Real_Values = np.array(y_test)
# Real_Values

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_test, predictions, alpha=0.6)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linestyle='--')
plt.xlabel('Actual Values')
plt.ylabel('Predictions')
plt.title('Predictions vs Actual Values')
plt.grid()
plt.show()

# %%
# Plotting Distribution of Residuals
plt.figure(figsize=(10, 6))
sns.histplot((y_test - predictions), bins=50, kde=True)
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.title('Distribution of Residuals')
plt.grid()
plt.show()

# %% [markdown]
# ## R- Square

# %%
r2_score_train = r2_score(y_train, xg_model.predict(X_train_scaled))
r2_score_test = r2_score(y_test, y_pred)
print(f'R Square for training: {r2_score_train}')
print(f'R Square for testing: {r2_score_test}')
# Out:
# R Square for training: 0.9753183126449585
# R Square for testing: 0.6673882835628302

# %% [markdown]
# ##### What I Understood

# %% [raw]
# -
